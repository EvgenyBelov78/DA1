# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgenyBelov78/DA1/blob/main/egrn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from tqdm.auto import tqdm
# !pip install tabula-py 
import requests
import tabula
from google.colab import data_table
import re
import math
df=pd.DataFrame()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 58.3 MB/s eta 0:00:00
# ...

# %%
df=pd.DataFrame()

# %%
i=300
while i<=399:
  url='https://raw.githubusercontent.com/EvgenyBelov78/DA1/main/Lesson4/hometask/report-b9694e48-e694-4fe8-b061-f5992f1cdff7-OfSite-2023-05-15-885025-63-01['+str(i+1)+'].pdf'
  try:
    tables = tabula.read_pdf(url, pages='all', pandas_options={'header': None})
    df.loc[i,'file']=url[74:]
    df.loc[i,'adres']=tables[2][0][4]
    df.loc[i,'nomer']=tables[1][1][1]
    df.loc[i,'sq']=tables[2][0][5]
    df.loc[i,'type']=tables[2][0][6]
    df.loc[i,'vid']=tables[2][0][10]  
  except:
    pass
  i=i+1
  print(i)
# Out:
# 301
# 302
# 303
# 304
# 305
# 306
# 307
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# 325
# 326
# 327
# 328
# 329
# 330
# 331
# 332
# 333
# 334
# 335
# 336
# 337
# 338
# 339
# 340
# 341
# 342
# 343
# 344
# 345
# 346
# 347
# 348
# 349
# 350
# 351
# 352
# 353
# 354
# 355
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# 364
# 365
# 366
# 367
# 368
# 369
# 370
# 371
# 372
# 373
# 374
# 375
# 376
# 377
# 378
# 379
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# 388
# 389
# 390
# 391
# 392
# 393
# 394
# 395
# 396
# 397
# 398
# 399
# 400

# %%
data_table.DataTable.max_columns = 110
data_table.DataTable(df, include_index=False, num_rows_per_page=1000)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>file</th>
#       <th>adres</th>
#       <th>nomer</th>
#       <th>sq</th>
#       <th>type</th>
#       <th>vid</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>300</th>
#       <td>report-b9694e48-e694-4fe8-b061-f5992f1cdff7-Of...</td>
#       <td>район, город Самара, Южное шоссе, д. 9, кв 369</td>
#       <td>63:01:0407002:1917</td>
#       <td>Площадь, м2: 37.3</td>
#       <td>Назначение: Жилое</td>
#       <td>Вид жилого помещения: Квартира</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td>report-b9694e48-e694-4fe8-b061-f5992f1cdff7-Of...</td>
# ...
