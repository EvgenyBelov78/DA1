# %%
# !pip install tabula-py
import requests
import pandas as pd
import time
import tabula
from google.colab import data_table
import re
import math
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.9.0-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tabula-py) (1.25.2)
# Requirement already satisfied: distro in /usr/lib/python3/dist-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.3->tabula-py) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=0.25.3->tabula-py) (1.16.0)
# Installing collected packages: tabula-py
# Successfully installed tabula-py-2.9.0

# %%
# !pip install fake_useragent
# Out:
# Collecting fake_useragent
#   Downloading fake_useragent-1.5.1-py3-none-any.whl (17 kB)
# Installing collected packages: fake_useragent
# Successfully installed fake_useragent-1.5.1

# %%
from fake_useragent import UserAgent
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'

# %%
df=pd.DataFrame()
dffull=pd.DataFrame()

i=0
offset_ = 0
limit_ = 100
user_agent = {'User-agent': 'Mozilla/5.0'}
#response  = requests.get(url, headers = user_agent ) #, config=debug)
while i<4:
#  url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
  url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?objStatus=0&offset={offset_}&limit=100&place=63&residentialBuildings=1'
  res = requests.get(url, headers={'User-Agent': UserAgent().chrome}) #,params=params)
  print(str(res)+''+str(offset_))
  if str(res)!='<Response [200]>': break
  offset_ = offset_ + 99
  objects_data = res.json()
  objects_list = objects_data.get('data')#.get('list')
  df = pd.json_normalize(objects_list)
  dffull=pd.concat([dffull,df],ignore_index=True)
  time.sleep(6)
  i=i+1
# Out:
# <Response [200]>0
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-5-10268f00e070> in <cell line: 9>()
#      14   if str(res)!='<Response [200]>': break
#      15   offset_ = offset_ + 99
# ---> 16   objects_data = res.json()
#      17   objects_list = objects_data.get('data')#.get('list')
#      18   df = pd.json_normalize(objects_list)
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in json(self, **kwargs)
#     973             # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#     977     @property
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df=pd.DataFrame()
dffull=pd.DataFrame()

# %%
qqq={
  "data" : {
    "id" : 50522,
    "hobjId" : 131163,
    "pdId" : 682905,
    "developer" : {
      "devId" : 12137,
      "devShortCleanNm" : "СЗ ССК-ЮГ",
      "devShortNm" : "СЗ ССК-ЮГ",
      "devFullCleanNm" : "СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ССК-ЮГ",
      "problObjCnt" : 0,
      "buildObjCnt" : 3,
      "comissObjCnt" : 0,
      "regRegionDesc" : "Самарская область",
      "devPhoneNum" : "+7 (846) 279-25-53",
      "devSite" : "viktorco.ru",
      "devEmail" : "szssk-ug@mega-samara.ru",
      "devInn" : "6312183713",
      "devOgrn" : "1186313023819",
      "devKpp" : "631201001",
      "devLegalAddr" : "Самарская область, город Самара, улица Ново-Садовая дом влд.160Д строение 1 офис 4",
      "devFactAddr" : "Самарская обл, город Самара, улица Ново-Садовая, влд. 160Д, стр.1, оф.4",
      "lastRpdId" : 742889,
      "fundGuarantyFlg" : 0,
      "devOrgRegRegionCd" : 63,
      "devEmplMainFullNm" : "Говоров Владимир Сергеевич",
      "orgForm" : {
        "id" : 4,
        "fullForm" : "Общество с ограниченной ответственностью",
        "shortForm" : "ООО"
      },
      "objGuarantyEscrowFlg" : 1,
      "govFundFlg" : 0
    },
    "region" : 63,
    "address" : "г Самара, район Куйбышевский р-н",
    "nameObj" : "ЖК \"Легенда\"",
    "floorMin" : 24,
    "floorMax" : 24,
    "objElemLivingCnt" : 158,
    "objReady100PercDt" : "2025-03-31",
    "wallMaterialShortDesc" : "Монолит-кирпич",
    "objLkFinishTypeDesc" : "По желанию заказчика",
    "objLkFreePlanDesc" : "Нет",
    "objElemParkingCnt" : 0,
    "objSquareLiving" : 7205.26,
    "rpdNum" : "63-000800",
    "rpdPdfLink" : "https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A46F6E090BCAA4300ABBAA40F87D40B8D",
    "rpdIssueDttm" : "07-08-2023 14:46",
    "objLkLatitude" : "53.1322",
    "objLkLongitude" : "50.1482",
    "objCompensFundFlg" : 0,
    "objProblemFlg" : 0,
    "objLkClassDesc" : "Типовой",
    "loadDttm" : "17-08-2023 01:32",
    "photoRenderDTO" : [ {
      "objId" : 50522,
      "pdId" : 682905,
      "rpdId" : 742889,
      "devId" : 12137,
      "ordNum" : 1,
      "objRenderPhotoSize" : 2998454,
      "objRenderPhotoUrl" : "https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A53B302E58E424850B086AEA40CCB7E71",
      "objRenderPhotoDttm" : "07-08-2023 16:01",
      "objRenderPhotoHiddenFlg" : 0,
      "objRenderPhotoNm" : "3.jpg",
      "objReadyDesc" : "Строится",
      "objBuildTypeShortDesc" : "Жилое",
      "knFlg" : 1,
      "loadDttm" : "17-08-2023 01:11"
    } ],
    "objGuarantyEscrowFlg" : 1,
    "objectType" : "normal",
    "miniUrl" : "https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70726F6A6465636C2E646F63732E697A643A6E89BA26E915423AA7B4B32A215EE320",
    "residentialBuildings" : 1,
    "newBuildingId" : 131163,
    "objFloorCnt" : 24,
    "objFlatCnt" : 158,
    "objFlatSq" : "7205.26",
    "objNonlivElemCnt" : 0,
    "quartography" : {
      "objLivElem1KCnt" : 113,
      "objLivElem2KCnt" : 23,
      "objLivElem3KCnt" : 22,
      "objLivElem4KCnt" : 0,
      "objLivElemCnt" : 158,
      "objLivElemEntrCnt" : 1,
      "objLivElemEntrFloorAvg" : 7
    },
    "objStatus" : 0,
    "isAvailableWantLiveHere" : 'true',
    "objTransferPlanDt" : "28-08-2025 12:00",
    "objLivCeilingHeight" : "2,7",
    "objInfrstrBicycleLaneFlg" : 0,
    "objInfrstrPlaygrndCnt" : 1,
    "objInfrstrSportGroundCnt" : 1,
    "objInfrstrTrashAreaCnt" : 2,
    "objInfrstrObjPrkngCnt" : 158,
    "objInfrstrNotObjPrkngCnt" : 0,
    "objInfrstrRampFlg" : 0,
    "objInfrstrCurbLoweringFlg" : 1,
    "objElevatorWheelchairCnt" : 0,
    "objElevatorPassengerCnt" : 1,
    "objElevatorCargoCnt" : 1,
    "objElevatorCargoPassengerCnt" : 1,
    "soldOutPerc" : 0.00824120156663326,
    "objPriceAvg" : 83036,
    "nonlivFirstFloor" : 0,
    "objectTransportInfo" : [ ],
    "conclusion" : 'true',
    "objLkSaleDepEmail" : "szssk-ug@mega-samara.ru",
    "objGreenHouseFlg" : 1,
    "objEnergyEffShortDesc" : "A",
    "infrastructureIndexValue" : 3
  },
  "errcode" : "0"
}

# %%
df = pd.json_normalize(qqq['data'])
dffull=pd.concat([dffull,df],ignore_index=True)
print(len(dffull))
# Out:
# 151

# %%
df
# Out:
#       id  hobjId    pdId  region                           address  \
# 0  50522  131163  682905      63  г Самара, район Куйбышевский р-н
#
#         nameObj  floorMin  floorMax  objElemLivingCnt objReady100PercDt  ...  \
# 0  ЖК "Легенда"        24        24               158        2025-03-31  ...
#
#   developer.orgForm.shortForm developer.objGuarantyEscrowFlg  \
# 0                         ООО                              1
#
#   developer.govFundFlg  quartography.objLivElem1KCnt  \
# 0                    0                           113
#
#    quartography.objLivElem2KCnt quartography.objLivElem3KCnt  \
# 0                            23                           22
#
#   quartography.objLivElem4KCnt quartography.objLivElemCnt  \
# 0                            0                        158
#
#   quartography.objLivElemEntrCnt quartography.objLivElemEntrFloorAvg
# 0                              1                                   7
#
# [1 rows x 91 columns]

# %%
data_table.DataTable.max_columns = 110
data_table.DataTable(dffull, include_index=False, num_rows_per_page=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8e445d9c810d> in <cell line: 2>()
#       1 data_table.DataTable.max_columns = 110
# ----> 2 data_table.DataTable(dffull, include_index=False, num_rows_per_page=1)
#
# NameError: name 'dffull' is not defined

# %%
dffull
# Out:
#   errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0       0     4023        23665       2200                  1087
# 1       0     4024        23666       2200                  1087
# 2       0     4025        23664       2200                  1087
#
#   data.developer.devShortCleanNm data.developer.devShortNm  \
# 0                         АРНИКА                    АРНИКА
# 1                         АРНИКА                    АРНИКА
# 2                         АРНИКА                    АРНИКА
#
#   data.developer.devFullCleanNm  data.developer.problObjCnt  \
# 0                        АРНИКА                           0
# 1                        АРНИКА                           0
# 2                        АРНИКА                           0
#
#    data.developer.buildObjCnt  ...            data.generalContractorNm  \
# 0                           4  ...  ООО "МЖК "Центр" (ИНН: 6317011330)
# 1                           4  ...  ООО "МЖК "Центр" (ИНН: 6317011330)
# 2                           4  ...  ООО "МЖК "Центр" (ИНН: 6317011330)
#
#   data.nonlivFirstFloor data.transportDistIndex data.objectTransportInfo  \
# 0                     0                  8 / 10                       []
# 1                     0                  8 / 10                       []
# 2                     0                  8 / 10                       []
#
#   data.conclusion  data.objLkSaleDepEmail data.objGreenHouseFlg  \
# 0           False  dogovor@gradholding.ru                     0
# 1           False  dogovor@gradholding.ru                     0
# 2           False  dogovor@gradholding.ru                     0
#
#   data.objEnergyEffShortDesc data.transportDistIndexValue  \
# 0                          C                            8
# 1                          C                            8
# 2                          C                            8
#
#   data.infrastructureIndexValue
# 0                             8
# 1                             8
# 2                             8
#
# [3 rows x 98 columns]
# Warning: Total number of columns (98) exceeds max_columns (20) limiting to first (20) columns.

# %%
dffull.reset_index(inplace=True)
ser= dffull['list']
zastr=pd.DataFrame(ser[0])
i=0
while i<len(ser):
  zastr=pd.concat([zastr,pd.DataFrame(ser[i])],ignore_index=True)
  i=i+1
zastr=zastr[zastr['rpdRegionCd']==63]
zastr.reset_index(inplace=True)

# %%
documents = []
i=0
dffull=pd.DataFrame()
df=dffull
url_doc_list = 'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/4023'
response = requests.get(url_doc_list, headers={'User-Agent': UserAgent().chrome})
qq=html_to_json.convert(response.text)

# %%
type(qqq)
# Out:
# dict

# %%
dffull.head()
# Out:
#    index                                               list  total
# 0      0  [{'hobjId': 18187, 'objId': 3402, 'developer':...    173
# 1      1  [{'hobjId': 18187, 'objId': 3402, 'developer':...    173
# 2      2  [{'hobjId': 18187, 'objId': 3402, 'developer':...    173

# %%
x=0
i=0
documents=[]
dfrasp=pd.DataFrame()
dfraspfull=pd.DataFrame()
while i<len(dffull):
 url_doc_list = 'https://наш.дом.рф/сервисы/api/object/'+str(dffull['id'].unique()[i])+'/sales_agg'
 response = requests.get(url_doc_list, headers={'User-Agent': UserAgent().chrome})
 documents = response.json()
 documents = documents['data']
 dfrasp = pd.json_normalize(documents)
 try:
   dffull.loc[i,'raspr']=dfrasp['apartmentsAggData.realised'][0]
 except KeyError:
   qq=True
# dfraspfull=pd.concat([dfraspfull,dfrasp],ignore_index=True)
 time.sleep(5)
 i=i+1

# %%
dfrasp = pd.json_normalize(qqq['data'])

# %%
dfrasp
# Out:
#      id  hobjId  pdId  region                          address  \
# 0  4023   23665  2200      63  г Самара, район Октябрьский р-н
#
#                                            nameObj  floorMin  floorMax  \
# 0  Жилой комплекс "Акварель" (ЖК "Акварель") дом 8         5         5
#
#    objElemLivingCnt objReady100PercDt  ... developer.companyGroupId  \
# 0                48        2023-06-30  ...                     5847
#
#   developer.objGuarantyEscrowFlg developer.govFundFlg  \
# 0                              0                    0
#
#    quartography.objLivElem1KCnt  quartography.objLivElem2KCnt  \
# 0                            24                            15
#
#   quartography.objLivElem3KCnt quartography.objLivElem4KCnt  \
# 0                            9                            0
#
#   quartography.objLivElemCnt quartography.objLivElemEntrCnt  \
# 0                         48                              3
#
#   quartography.objLivElemEntrFloorAvg
# 0                                   4
#
# [1 rows x 97 columns]

# %%
dd[dd['objElemLivingCnt']==0]
# Out:
#         id  hobjId    pdId  region  \
# 8    24540   19966   69105      63
# 18   27564   24976   97303      63
# 26   24083   41346   62935      63
# 37   47035  127666  535315      63
# 42   40735  121247  467911      63
# 72   39646  120080  447927      63
# 74   39645  120081  447927      63
# 78   43062  123637  512412      63
# 80   43678  124261  506436      63
# 89   38153  118556  406303      63
# 93   40238  120723  461547      63
# 148  40129  120605  452246      63
# 151  40128  120606  452246      63
# 165  49194  129831  637384      63
# 166  40094  120568  428844      63
# 167  40093  120569  428844      63
#
#                                                address  floorMin  floorMax  \
# 8                                г Самара, Белорусская         1         1
# 18   г Самара, район Ленинский, улица Галактионовск...         9         9
# 26   Самара, улица Красных Коммунаров/Двадцать втор...         3         4
# 37     г Самара, Пятая просека, строение Гараж-стоянка         6         7
# 42                  г Самара, улица Санфировой, д. 95В         9         9
# 72   г Самара, ул Георгия Димитрова, блок-секция Тр...         1         1
# 74   г Самара, ул Георгия Димитрова, блок-секция Па...         2         2
# 78                        г Самара, ул Советской Армии         1         1
# 80         г Самара, границы улиц, блок-секция ПАРКИНГ         1         1
# 89            г Самара, район Кировский, ш Ракитовское         1         1
# 93   г Самара, ул Физкультурная, д. 103, блок-секци...         2         2
# 148  г Самара, ул Желябова, д. 7, блок-секция Транс...         1         1
# 151  г Самара, ул Желябова, д. 7, блок-секция Парки...         1         1
# 165                         г Новокуйбышевск, литера 1         2         2
# 166  г Самара, Кубышева/Пионерская/Фрунзе/Комсомоль...         2         2
# 167  г Самара, Кубышева/Пионерская/Фрунзе/Комсомоль...         2         2
#
#      objElemLivingCnt objReady100PercDt wallMaterialShortDesc  ... metro.id  \
# 8                   0        2022-12-31                Другое  ...      NaN
# 18                  0        2023-03-31        Монолит-кирпич  ...   54.509
# 26                  0        2023-06-30        Монолит-кирпич  ...   54.313
# 37                  0        2024-09-30        Монолит-кирпич  ...      NaN
# 42                  0        2023-06-30        Монолит-кирпич  ...   54.309
# 72                  0        2023-09-30                Другое  ...      NaN
# 74                  0        2023-09-30        Монолит-кирпич  ...      NaN
# 78                  0        2023-12-31                Другое  ...   54.308
# 80                  0        2024-09-30        Монолит-кирпич  ...   54.309
# 89                  0        2024-09-30                Другое  ...      NaN
# 93                  0        2024-06-30        Монолит-кирпич  ...   54.313
# 148                 0        2024-03-31                Другое  ...   54.308
# 151                 0        2024-03-31        Монолит-кирпич  ...   54.308
# 165                 0        2025-12-31        Монолит-кирпич  ...      NaN
# 166                 0        2022-12-31        Монолит-кирпич  ...      NaN
# 167                 0        2022-12-31        Монолит-кирпич  ...      NaN
#
#       metro.name  metro.line  metro.color metro.time metro.isWalk  \
# 8            NaN         NaN          NaN        NaN          NaN
# 18    Алабинская      Первая      #CD0505  15.516667         True
# 26     Безымянка      Первая      #CD0505  11.933333         True
# 37           NaN         NaN          NaN        NaN          NaN
# 42   Гагаринская      Первая      #CD0505  21.383333        False
# 72           NaN         NaN          NaN        NaN          NaN
# 74           NaN         NaN          NaN        NaN          NaN
# 78    Московская      Первая      #CD0505  20.983333        False
# 80   Гагаринская      Первая      #CD0505   9.366667         True
# 89           NaN         NaN          NaN        NaN          NaN
# 93     Безымянка      Первая      #CD0505  13.383333         True
# 148   Московская      Первая      #CD0505  20.633333        False
# 151   Московская      Первая      #CD0505  20.750000        False
# 165          NaN         NaN          NaN        NaN          NaN
# 166          NaN         NaN          NaN        NaN          NaN
# 167          NaN         NaN          NaN        NaN          NaN
#
#     metro.colors                                          nameObj  \
# 8            NaN                                    ЖК "Две реки"
# 18     [#CD0505]                             ЖК "Гранд Империалъ"
# 26     [#CD0505]  ФОК со вспомогательной инфраструктурой "Рекорд"
# 37           NaN                                ЖК Радужный Омега
# 42     [#CD0505]                                     ЖК "КАПИТАЛ"
# 72           NaN                                   ЖК Приволжский
# 74           NaN                                   ЖК Приволжский
# 78     [#CD0505]                           "Олимп" Жилой комплекс
# 80     [#CD0505]                           Жилой комплекс "СОКОЛ"
# 89           NaN                                              NaN
# 93     [#CD0505]                                        ЖК Рекорд
# 148    [#CD0505]                                        ЖК Зодиак
# 151    [#CD0505]                                        ЖК Зодиак
# 165          NaN           Клубный дом "Западный" (КД "Западный")
# 166          NaN                                              NaN
# 167          NaN                                              NaN
#
#     complexShortNm  raspr
# 8              NaN    NaN
# 18             NaN    0.0
# 26             NaN    0.0
# 37             NaN    NaN
# 42             NaN    0.0
# 72             NaN    NaN
# 74             NaN    0.0
# 78             NaN    NaN
# 80             NaN    NaN
# 89             NaN    NaN
# 93             NaN    NaN
# 148            NaN    NaN
# 151            NaN    NaN
# 165            NaN    NaN
# 166            NaN    NaN
# 167            NaN    NaN
#
# [16 rows x 105 columns]

# %%
dd=dd.drop(dd[dd['objElemLivingCnt']==0].index)

# %%
dfull=dd

# %%
dffull.reset_index(inplace=True)

# %%
dffull.drop('index',axis=1,inplace=True)

# %%
dffull.head(10)
# Out:
#   errcode  data.id  data.hobjId  data.pdId  data.developer.devId  \
# 0       0     4023        23665       2200                  1087
# 1       0     4024        23666       2200                  1087
# 2       0     4025        23664       2200                  1087
#
#   data.developer.devShortCleanNm data.developer.devShortNm  \
# 0                         АРНИКА                    АРНИКА
# 1                         АРНИКА                    АРНИКА
# 2                         АРНИКА                    АРНИКА
#
#   data.developer.devFullCleanNm  data.developer.problObjCnt  \
# 0                        АРНИКА                           0
# 1                        АРНИКА                           0
# 2                        АРНИКА                           0
#
#    data.developer.buildObjCnt  ...  data.objectTransportInfo data.conclusion  \
# 0                           4  ...                        []           False
# 1                           4  ...                        []           False
# 2                           4  ...                        []           False
#
#    data.objLkSaleDepEmail data.objGreenHouseFlg data.objEnergyEffShortDesc  \
# 0  dogovor@gradholding.ru                     0                          C
# 1  dogovor@gradholding.ru                     0                          C
# 2  dogovor@gradholding.ru                     0                          C
#
#   data.transportDistIndexValue data.infrastructureIndexValue  num_d  \
# 0                            8                             8  452.0
# 1                            8                             8  452.0
# 2                            8                             8  452.0
#
#           num_r     num_m
# 0  1.890548e+09  35844.73
# 1  1.890548e+09  35844.73
# 2  1.890548e+09  35844.73
#
# [3 rows x 101 columns]

# %%
rpdPdfLink
# Out:
# 'https://github.com/EvgenyBelov78/datasets/blob/master/obj51299-pd63-000812.pdf'

# %%
qqq=('obj16733_pd63-000266.pdf','obj18136_pd63-000283.pdf','obj25813_pd63-000538.pdf','obj27566_pd63-000565.pdf','obj33908_pd63-000612.pdf','obj38152_pd63-000654.pdf','obj40126_pd63-000684.pdf','obj40736_pd63-000695.pdf','obj42532_pd63-000712.pdf','obj42839_pd63-000714.pdf','obj43207_pd63-000716.pdf','obj43653_pd63-000718.pdf','obj43677_pd63-000719.pdf','obj44133_pd63-000722.pdf','obj44163_pd63-000724.pdf','obj44369_pd63-000726.pdf','obj44983_pd63-000728.pdf','obj45106_pd63-000729.pdf','obj45120_pd63-000730.pdf','obj45689_pd63-000735.pdf','obj45825_pd63-000737.pdf','obj47604_pd63-000770.pdf','obj48034_pd63-000774.pdf','obj48686_pd63-000775.pdf','obj48939_pd63-000776.pdf','obj49595_pd63-000783.pdf','obj49773_pd63-000789.pdf','obj49848_pd63-000791.pdf','obj49882_pd63-000792.pdf','obj49948_pd63-000794.pdf','obj50305_pd63-000798.pdf','obj50520_pd63-000800.pdf','obj50647_pd63-000801.pdf','obj50705_pd63-000803.pdf','obj50772_pd63-000804.pdf','obj50830_pd63-000805.pdf','obj50874_pd63-000806.pdf','obj51054_pd63-000808.pdf','obj51150_pd63-000809.pdf','obj51177_pd63-000810.pdf','obj51187_pd63-000811.pdf','obj51299_pd63-000812.pdf','obj51318_pd63-000813.pdf','obj51805_pd63-000816.pdf','obj51900_pd63-000817.pdf','obj51951_pd63-000818.pdf','obj52277_pd63-000821.pdf','obj52336_pd63-000823.pdf','obj52379_pd63-000825.pdf','obj52380_pd63-000826.pdf','obj52399_pd63-000827.pdf','obj52701_pd63-000828.pdf','obj52852_pd63-000829.pdf','obj52886_pd63-000831.pdf','obj53134_pd63-000836.pdf','obj53263_pd63-000837.pdf','obj53769_pd63-000841.pdf','obj53838_pd63-000843.pdf','obj54071_pd63-000845.pdf','obj54256_pd63-000847.pdf','obj54471_pd63-000849.pdf','obj55292_pd63-000853.pdf','obj55354_pd63-000854.pdf','obj55529_pd63-000855.pdf','obj55892_pd63-000857.pdf','obj56885_pd63-000859.pdf','obj56911_pd63-000860.pdf','obj57768_pd63-000861.pdf','obj58210_pd63-000864.pdf','obj6159_pd63-000088.pdf')

# %%
qqq=('obj16735-pd63-000266.pdf','obj18136-pd63-000283.pdf','obj21336-pd63-000430.pdf','obj25813-pd63-000538.pdf','obj27561-pd63-000564.pdf','obj27566-pd63-000565.pdf','obj28625-pd63-000572.pdf','obj33908-pd63-000612.pdf','obj38152-pd63-000654.pdf','obj39643-pd63-000678.pdf','obj40126-pd63-000684.pdf','obj4023-pd63-000027.pdf','obj40236-pd63-000689.pdf','obj40241-pd63-000688.pdf','obj40499-pd63-000692.pdf','obj40734-pd63-000695.pdf','obj41832-pd63-000703.pdf','obj42025-pd63-000704.pdf','obj42403-pd63-000710.pdf','obj42443-pd63-000711.pdf','obj42532-pd63-000712.pdf','obj42767-pd63-000713.pdf','obj42839-pd63-000714.pdf','obj43061-pd63-000715.pdf','obj43207-pd63-000716.pdf','obj43489-pd63-000717.pdf','obj43653-pd63-000718.pdf','obj43677-pd63-000719.pdf','obj44077-pd63-000721.pdf','obj44133-pd63-000722.pdf','obj44163-pd63-000724.pdf','obj44323-pd63-000725.pdf','obj44369-pd63-000726.pdf','obj44501-pd63-000727.pdf','obj44983-pd63-000728.pdf','obj45106-pd63-000729.pdf','obj45120-pd63-000730.pdf','obj45689-pd63-000735.pdf','obj45825-pd63-000737.pdf','obj46150-pd63-000739.pdf','obj47034-pd63-000751.pdf','obj47604-pd63-000770.pdf','obj48034-pd63-000774.pdf','obj48686-pd63-000775.pdf','obj48941-pd63-000776.pdf','obj49595-pd63-000783.pdf','obj49773-pd63-000789.pdf','obj49848-pd63-000791.pdf','obj49882-pd63-000792.pdf','obj49948-pd63-000794.pdf','obj50076-pd63-000796.pdf','obj50305-pd63-000798.pdf','obj50520-pd63-000800.pdf','obj50647-pd63-000801.pdf','obj50705-pd63-000803.pdf','obj50773-pd63-000804.pdf','obj50830-pd63-000805.pdf','obj50874-pd63-000806.pdf','obj51054-pd63-000808.pdf','obj51150-pd63-000809.pdf','obj51177-pd63-000810.pdf','obj51187-pd63-000811.pdf','obj51299-pd63-000812.pdf','obj51318-pd63-000813.pdf','obj51805-pd63-000816.pdf','obj51900-pd63-000817.pdf','obj51951-pd63-000818.pdf','obj52277-pd63-000821.pdf','obj52336-pd63-000823.pdf','obj52379-pd63-000825.pdf','obj52380-pd63-000826.pdf','obj52399-pd63-000827.pdf','obj52701-pd63-000828.pdf','obj52852-pd63-000829.pdf','obj52886-pd63-000831.pdf','obj53134-pd63-000836.pdf','obj53263-pd63-000837.pdf')

# %%
len(qqq)
# Out:
# 70

# %%
url='https://raw.githubusercontent.com/EvgenyBelov78/datasets/master/WorldDBTables/obj16732-pd63-000266.pdf'

# %%
url='https://raw.githubusercontent.com/EvgenyBelov78/datasets/master/'+str(qqq[0])

# %%
qqq[69]
# Out:
# 'obj6159_pd63-000088.pdf'

# %%
dffull=pd.DataFrame()

# %%
tables = tabula.read_pdf(url, pages='all', pandas_options={'header': None})

# %%
x=69
dffull.fillna(0)
while x<len(qqq):
  rpdPdfLink='https://raw.githubusercontent.com/EvgenyBelov78/AN2/main/'+str(qqq[x])
  new=True
  print(str(qqq[x]))
 # print(str(x)+':'+str(dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)].id.count()))
  tables = tabula.read_pdf(rpdPdfLink, pages='all', pandas_options={'header': None})
  i=0
  j=0
  k=0
  str_d=''
  str_m=''
  str_r=''
  num_d=0
  num_m=0
  num_r=0
  while (k<len(tables))&(new==True):
   #print('True!')
   i=0
   while i<len(tables[k].axes[1]):
    j=0
    while j<len(tables[k]):
   #  print('RRR')
#2=186m|m1|52|19.7.1.1.1.1 кроу:
#2=187m|m0|1|19.7.1.1.1.2 зательных от числе ний (взно сов) в компенса ци онный фонд:
#2=187m|m0|4|19.7.1.1.1.3 собов обес печ ения граж дан ской от ветственности зас тройщика:
     ffindr=0
     ffindm=0
     ffindd=0
     if str(tables[k][i][j])!='nan' and  str(type(tables[k][i][j]))!="<class 'numpy.float64'>" and  str(type(tables[k][i][j]))!="<class 'numpy.int64'>" :
      if ((str(tables[k][i][j].replace('\r', '').replace('-','')).find('Количество договоров, заключенных с использованием счетов эскроу:')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных при условии уплаты обязательных')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных с использованием иных')>-1))&(str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
    #     print("1="+str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
         str_d=str(str(tables[k][i][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','').replace('-','')
         print(str(k)+'+'+str(i)+'+'+str(j)+'||'+str(len(str_d))+'^^^'+str_d)
         if len(str_d)>0:
          if math.isnan(float(str_d))==False:
           num_d=num_d+float(str_d)
           ffindd=1
         if ffindd==0:
          str_d=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False:
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
          str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False:
            num_d=num_d+float(str_d)
            ffindd=1
      if (str(tables[k][i][j].replace('\r', '').replace('-','')).find('Количество договоров, заключенных ')==-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
     #   print("2="+str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
        try:
         str_d=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
         str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
         str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
         str_d=str_d.replace('кроу:', '')
         str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
         if len(str_d)>0:
           if math.isnan(float(str_d))==False:
   #         print('111')
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
         # print('222')
          str_d=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
          str_d=str_d.replace('кроу:', '')
          str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
      #   print('222   '+str(str_d))
          if len(str_d)>0:
           if math.isnan(float(str_d))==False:
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
        #  print('333')
          str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
          str_d=str_d.replace('кроу:', '')
          str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
      #    print('333   '+str(str_d))
          if len(str_d)>0:
           if math.isnan(float(str_d))==False:
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
    #      print('333')
          str_d=str(str(tables[k][i][j+2]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
          str_d=str_d.replace('кроу:', '')
          str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
       #   print('0+2   '+str(str_d))
          if len(str_d)>0:
           if math.isnan(float(str_d))==False:
            num_d=num_d+float(str_d)
            ffindd=1
        except (KeyError, ValueError):
      #   print('444')
         try:
          str_d=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
          str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
          str_d=str_d.replace('кроу:', '')
          str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
      #    print('try 2+0  '+str(str_d))
          if len(str_d)>0:
           if math.isnan(float(str_d))==False:
            num_d=num_d+float(str_d)
            ffindd=1
          if ffindd==0:
        #  print('333')
           str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
           str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
           str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
           str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
           str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
           str_d=str_d.replace('кроу:', '')
           str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
      #     print('try 1+1   '+str(str_d))
           if len(str_d)>0:
            if math.isnan(float(str_d))==False:
             num_d=num_d+float(str_d)
             ffindd=1
          if ffindd==0:
    #      print('333')
           str_d=str(str(tables[k][i][j+2]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
           str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
           str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
           str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
           str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
           str_d=str_d.replace('кроу:', '')
           str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
      #     print('try 0+2   '+str(str_d))
           if len(str_d)>0:
            if math.isnan(float(str_d))==False:
             num_d=num_d+float(str_d)
             ffindd=1
         except (KeyError, ValueError):
      #    print('error')
          try:
          # print('try 1+1')
           str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
           str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
           str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
           str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
           str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
           str_d=str_d.replace('кроу:', '')
           str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
      #     print('error1'+str(str_d))
           if len(str_d)>0:
            if math.isnan(float(str_d))==False:
             num_d=num_d+float(str_d)
             ffindd=1
          except (KeyError, ValueError):
          # print('error2')
           try:
            str_d=str(str(tables[k][i][j+2]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
            str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
            str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
            str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
            str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
            str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
            str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
            str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
            str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
            str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
            str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
            str_d=str_d.replace('кроу:', '')
            str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
            str_d=str_d.replace('', '')
            print('error2'+str(str_d))
            if len(str_d)>0:
             if math.isnan(float(str_d))==False:
              num_d=num_d+float(str_d)
              ffindd=1
           except:
            pass
          if ffindd==0:
    #      print('333')
           try:
            str_d=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3','').replace('-',''))
            str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
            str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
            str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
            str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
            str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
            str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
            str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
            str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиемсчетовэс', '')
            str_d=str_d.replace('Количестводоговоров.заключенныхсиспользованиеминыхспо', '')
            str_d=str_d.replace('Количестводоговоров.заключенныхприусловииуплатыобя', '')
            str_d=str_d.replace('кроу:', '')
            str_d=str_d.replace('19.7.1.1.2Нежилыепомещения:', '')
          #  print('error3   '+str(str_d))
            if len(str_d)>0:
             if math.isnan(float(str_d))==False:
              num_d=num_d+float(str_d)
              ffindd=1
           except:
            pass
    #  if len(str(str_d))>1:
    #   print(str(str_d))
# ПЛОЩАДЬ Количестводоговоров.заключенныхприусловииуплатыобя
      if ((str(tables[k][i][j].replace('\r', '').replace('-','')).find('Площадь объектов, в отношении которых договор участия в долевом строительстве')>-1))&(str(tables[k][i][j].replace('\r', '')).find('19.7.2.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
     #    print(str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
         str_m=str(str(tables[k][i][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         if len(str_m)>0:
           if math.isnan(float(str_m))==False:
            num_m=num_m+float(str_m)
            ffindm=1
         if ffindm==0:
          str_m=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False:
            num_m=num_m+float(str_m)
            ffindm=1
         if ffindm==0:
          str_m=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False:
            num_m=num_m+float(str_m)
            ffindm=1
      if (str(tables[k][i][j].replace('\r', '').replace('-', '')).find('Площадь объектов, в отношении которых договор участия в долевом строительстве')==-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.2.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
      #  print('2    ||| '+str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
      # print(str(tables[k][i+1][j].replace('\r', '')))
      #  print(str(tables[k][i+2][j].replace('\r', '')))
        try:
         str_m=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
         str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
     #    print(str_m)
         if len(str_m)>0:
           if math.isnan(float(str_m))==False:
            num_m=num_m+float(str_m)
            ffindm=1
         if ffindm==0:
          str_m=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False:
            num_m=num_m+float(str_m)
            ffindm=1
        except (KeyError, ValueError):
         try:
          str_m=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
    #      print(str_m)
          if len(str_m)>0:
           if math.isnan(float(str_m))==False:
            num_m=num_m+float(str_m)
            ffindm=1
         except (KeyError, ValueError):
          if ffindm==0:
           try:
      #      print('долет!!!')
            str_m=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
            str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
      #      print('долет!!!'+str(str_m))
            if len(str_m)>0:
             if math.isnan(float(str_m))==False:
              num_m=num_m+float(str_m)
              ffindm=1
           except (KeyError, ValueError):
            pass
          if ffindm==0:
           try:
     #       print('долет2!!!')
            str_m=str(str(tables[k][i][j+2]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2','').replace('-','').replace('м 2',''))
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
            str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
            str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
     #       print('долет2!!!'+str(str_m))
            if len(str_m)>0:
             if math.isnan(float(str_m))==False:
              num_m=num_m+float(str_m)
              ffindm=1
           except (KeyError, ValueError):
            pass
# РУБЛИ
      ffindr=0
      if ((str(tables[k][i][j].replace('\r', '').replace('-','')).find('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных с использованием счетов эскроу')>-1))&(str(tables[k][i][j].replace('\r', '')).find('19.7.3.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
     #    print(str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
         str_r=str(str(tables[k][i][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
         str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
         str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
         if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         if ffindr==0:
          str_r=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         if ffindr==0:
          str_r=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
      if (str(tables[k][i][j].replace('\r', '').replace('-','')).find('Суммарная цена договоров, заключенных')==-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.3.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
       # print('2222    '+str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
        try:
         str_r=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
         str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
         str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
         if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         if ffindr==0:
          str_r=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
        except (KeyError, ValueError):
      #   print('erorr!')
         try:
          str_r=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
        #  print('try!!! '+str(str_r))
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         except (KeyError, ValueError):
           pass
        if ffindr==0:
         try:
          str_r=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
       #   print('долет000!!! '+str(str_r))
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         except:
           pass
        if ffindr==0:
         try:
          str_r=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
     #     print('долет111!!! '+str(str_r))
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         except:
           pass
        if ffindr==0:
         try:
          str_r=str(str(tables[k][i][j+2]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб','').replace('-',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиемсчетовэскроу:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:', '')
          str_r=str_r.replace('Суммарнаяценадоговоров.заключенныхсиспользованиеминыхспособовобеспечениягражданскойответственностизастройщика:', '')
   #       print('долет222!!! '+str(str_r))
          if len(str_r)>0:
           if math.isnan(float(str_r))==False:
            num_r=num_r+float(str_r)
            ffindr=1
         except:
           pass
     #print(str(k)+'|'+str(i)+'|'+str(j))
     j=j+1
    i=i+1
#   print(str(k))
   k=k+1
  print(str(qqq[x])+'=='+str(num_d)+'|'+str(num_m)+'|'+str(num_r))
  if new==True:
   dffull.loc[x,'num_d']=num_d
   dffull.loc[x,'num_r']=num_r
   dffull.loc[x,'num_m']=num_m
  x=x+1
#  print(dffull.objId[x])
#  print(num_r)
#  print(num_m)
# 42767, 43489, 40237, 40238,40236,40733,41623-ЮГ, 48688, 48686, 48687, 46470, 46469
# 40733
# Out:
# obj6159_pd63-000088.pdf
# error2
# error2
# error2
# error2
# obj6159_pd63-000088.pdf==555.0|43261.04|2012334274.26

# %%
str(tables[k][i][j])
# Out:
# '19.7.1.1.1.2'

# %%
str(tables[188][2][9])
# Out:
# 'Суммарная це на до говоров, зак люч енных при усло вии уплат ы обя -\rзатель ных отчисле ний (взно сов) в компенса ционный фонд:\r249 581 380 руб.'

# %%
dffull.tail()
# Out:
#     num_d       num_r   num_m
# 64   23.0  96416468.0  961.67
# 65   11.0  42551477.0  465.02
# 66    0.0         0.0    0.00
# 67    0.0         0.0    0.00
# 68    0.0         0.0    0.00

# %%
data_table.DataTable.max_columns = 110
data_table.DataTable(dffull, include_index=False, num_rows_per_page=200)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>num_d</th>
#       <th>num_r</th>
#       <th>num_m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>244.0</td>
#       <td>1.426929e+09</td>
#       <td>22235.32</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>34.0</td>
#       <td>4.617147e+08</td>
#       <td>9998.24</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>50.0</td>
#       <td>6.902604e+07</td>
#       <td>3112.95</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>61.0</td>
#       <td>1.733101e+09</td>
#       <td>18338.95</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>102.0</td>
#       <td>5.935609e+08</td>
#       <td>7516.07</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>23.0</td>
#       <td>9.641647e+07</td>
#       <td>961.67</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>11.0</td>
#       <td>4.255148e+07</td>
#       <td>465.02</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>0.0</td>
#       <td>0.000000e+00</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>0.0</td>
#       <td>0.000000e+00</td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>0.0</td>
#       <td>0.000000e+00</td>
#       <td>0.00</td>
#     </tr>
#   </tbody>
# </table>
# <p>69 rows × 3 columns</p>
# </div>
