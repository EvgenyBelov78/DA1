# %% [markdown]
# <a href="https://colab.research.google.com/github/EvgenyBelov78/DA1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22without_pandas_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/da-python/python-for-data-analytics/blob/main/Lesson1/hometask/without_pandas.ipynb)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('lyDLAutA88s', width=800, height=300)

# %%
# 1. Посмотрите видео Дэвида Бизли про встроенные инструменты Python
# 2. Попробуйте используя встроенные инструменты Python проанализировать таблицу из файла "Vacancy.csv"
# 3. Попробуйте ответить на вопросы:
# Сколько вакансий, которые вам нравятся?
# За какие периоды эти вакансии?
# Сколько вакансий с такими позициями, на которых вы работаете?
# Сколько вакансий для аналитика данных?
# Сколько вакансий для аналитика данных с использованием Python?

# В задании важно не использовать pandas и numpy, а встроенные инструменты python
# Counter, CSV, defaultdict, sorted

# %%
# Colab Version
# !pip install wget
# !wget https://raw.githubusercontent.com/da-python/python-for-data-analytics/main/Lesson1/hometask/vacancy.csv.zip
# !unzip vacancy.csv.zip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=962bc4060ce6e0b84cab402fe03fdcb906792dac943645de0501ec7e0d3217bb
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...
# --2022-08-25 11:09:25--  https://raw.githubusercontent.com/da-python/python-for-data-analytics/main/Lesson1/hometask/vacancy.csv.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3029239 (2.9M) [application/zip]
# Saving to: ‘vacancy.csv.zip’
#
# vacancy.csv.zip     100%[===================>]   2.89M  --.-KB/s    in 0.08s
#
# ...

# %%
import csv
import sys
from collections import Counter, defaultdict

# %%
# csv.field_size_limit(sys.maxsize)

# %%
file_path = 'vacancy.csv'
vacs = list(csv.DictReader(open(file_path, encoding='utf-8')))

# %%
len(vacs)
# Out:
# 4002

# %%
vacs[0].keys()
# Out:
# odict_keys(['id', 'created_at', 'updated_at', 'vacid', 'vactitle', 'vacdescription', 'vacdate', 'vacstatus', 'vaclink'])

# %%
c = Counter([x.get('vactitle') for x in vacs if x.get('vactitle').lower().find('java') > -1])

# %%
for i in range(len(vacs)):
    print(vacs[i].get('id'), vacs[i].get('vactitle'))
# Out:
# 383479 Senior java-разработчик (в команду Онбординга)
# 383480 Дизайнер мобильных приложений
# 383481 Старший специалист отдела мониторинга залогового обеспечения
# 383482 Аналитик/разработчик  (Программа 'Миграция Legacy АС на Фабрику Данных')
# 383483 Java разработчик (Команда Functions)
# 383484 Главный инженер (NGFW)
# 383485 Ведущий инженер по кибербезопасности (защита контейнеров)
# 383486 Тестировщик-автоматизатор (QA)
# 383487 Ведущий специалист (отдел технических средств охраны)
# 383488 Инженер поддержки тестирования
# 383489 Data - аналитик
# 383490 Ведущий специалист (Управление комплаенс)
# 383491 Клиентский менеджер по работе с корпоративными клиентами
# 383492 Главный инженер (Pentest)
# 383493 DevOps (центр снабжения)
# 383494 QA
# 383495 Data engineer (BigData и ML)
# 383496 Лидер АС
# 383497 Системный аналитик. Сервис Автокредитование
# 383498 Руководитель направления ABAP
# 383499 ABAP разработчик под АСУС EWM
# 383500 Аналитик (информационная безопасность)
# ...

# %%
vacs[0]
# Out:
# OrderedDict([('id', '383479'),
#              ('created_at', '2021-03-14 09:39:21.854462'),
#              ('updated_at', '2021-03-14 09:39:21.854584'),
#              ('vacid', '1474941'),
#              ('vactitle', 'Senior java-разработчик (в команду Онбординга)'),
#              ('vacdescription',
# ...

# %%
c.most_common(10)
# Out:
# [('Java разработчик', 40),
#  ('Java-разработчик', 24),
#  ('Senior Java-разработчик', 10),
#  ('Senior Java Developer', 7),
#  ('Разработчик Java', 7),
#  ('Java Developer', 6),
#  ('Главный Java разработчик', 4),
#  ('Middle Java Developer', 4),
#  ('Senior Java разработчик', 4),
#  ('Java developer', 3)]

# %%
'Исполнительный директор по операционной эффективности блока риски'.lower().find('директор')
# Out:
# 15

# %%
а

# %%
[x.get('vacdate') for x in vacs if x.get('vactitle').lower().find('директор') > -1]
# Out:
# [('2021-03-12', 'https://my.sbertalents.ru/#/job-requisition/1543515'),
#  ('2021-03-09', 'https://my.sbertalents.ru/#/job-requisition/1513501'),
#  ('2021-03-05', 'https://my.sbertalents.ru/#/job-requisition/1546124'),
#  ('2021-03-05', 'https://my.sbertalents.ru/#/job-requisition/1513609'),
#  ('2021-03-04', 'https://my.sbertalents.ru/#/job-requisition/1540170'),
#  ('2021-03-04', 'https://my.sbertalents.ru/#/job-requisition/1545994'),
#  ('2021-02-18', 'https://my.sbertalents.ru/#/job-requisition/1533389'),
#  ('2021-02-17', 'https://my.sbertalents.ru/#/job-requisition/1531754'),
#  ('2021-02-16', 'https://my.sbertalents.ru/#/job-requisition/1492380'),
#  ('2021-02-08', 'https://my.sbertalents.ru/#/job-requisition/1524351'),
#  ('2021-02-01', 'https://my.sbertalents.ru/#/job-requisition/1514461'),
#  ('2020-12-28', 'https://my.sbertalents.ru/#/job-requisition/1425281'),
#  ('2020-12-07', 'https://my.sbertalents.ru/#/job-requisition/1392915'),
# ...

# %%
c=[]
risk=[]
ad=[]
adpyt=[]
id=[]
pyt=[]
i=0
while i<len(vacs):
 c.append(vacs[i]['vactitle']);
 if vacs[i]['vactitle'].lower().find(' риск') > -1 and vacs[i]['vactitle'].lower().find('операционны') > -1  : risk.append(vacs[i]['vactitle']);
 if vacs[i]['vactitle'].lower().find('испол') > -1 and vacs[i]['vactitle'].lower().find('директор') > -1  : id.append(vacs[i]['vactitle']);
 if (vacs[i]['vactitle'].lower().find('аналитик данных') > -1)|(vacs[i]['vactitle'].lower().find('data analist') > -1)  : ad.append(vacs[i]['vactitle']);
 if ((vacs[i]['vactitle'].lower().find('аналитик данных') > -1)|(vacs[i]['vactitle'].lower().find('data analist') > -1) )  and vacs[i]['vacdescription'].lower().find('python') > -1   : adpyt.append(vacs[i]['vactitle']);
 if  vacs[i]['vacdescription'].lower().find('python') > -1   : pyt.append(vacs[i]['vactitle']);
 i=i+1

# %%
print('Вакансии с ипользованием python: '+str(len(pyt)))
#print(pyt)
print('Вакансии, связанные с операционным риском: '+str(len(risk)))
print(risk)
print('Вакансии уровня исполнительный директор: '+str(len(id)))
print(id)
print('Вакансии аналитик данных: '+str(len(ad)))
print(ad)
print('Вакансии аналитик данных с ипользованием python: '+str(len(adpyt)))
print(adpyt)
# Out:
# Вакансии с ипользованием python: 503
# Вакансии, связанные с операционным риском: 2
# ['Ведущий специалист управление операционных рисков', 'Аналитик по управленческой отчетности (операционные риски)']
# Вакансии уровня исполнительный директор: 5
# ['Исполнительный директор (ДомКлик)', 'Исполнительный директор управление нестраховыми рисками', 'Исполнительный директор-начальник отдела экономической безопасности', 'Исполнительный директор по операционной эффективности блока риски', 'ИТ Лидер кластера «Каналы» (Исполнительный директор)']
# Вакансии аналитик данных: 22
# ...

# %%
#За какие периоды эти вакансии?
x=Counter([x.get('vacdate') for x in vacs])
y=min(x for x in x if len(x)>0)
print('Вакансии размещены за период: с '+str(y)+' по '+str(max(x)))
#print(y)
#print(x)
#print(min(x for x!=NaN))
# Out:
# Вакансии размещены за период: с 2020-10-15 по 2021-03-17
