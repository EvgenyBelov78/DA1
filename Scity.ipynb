# %% [markdown]
# ### Задание
# - Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# - Cохранить ее в pandas dataframe
# - Cохранить pandas dataframe в excel
# - Cохранить pandas dataframe в pickle
# - Cохранить pandas dataframe в БД

# %%
import requests
import pandas as pd
import time

# %%
import json

# %%
import time

# %%
# !pip install html_to_json
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting html_to_json
#   Downloading html_to_json-2.0.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.8/dist-packages (from html_to_json) (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from bs4->html_to_json) (4.6.3)
# Installing collected packages: html-to-json
# Successfully installed html-to-json-2.0.0

# %%
import html_to_json

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import lxml

# %%
df=pd.DataFrame()

# %%
https://southerncity.ru/choose/params/flat-12743/

# %%
i=11000
while i<=12000:
  url_doc_list = 'https://southerncity.ru/choose/params/flat-'+str(i)+'/'
#  print(url_doc_list)
  response = requests.get(url_doc_list)
#  print(response)
  if str(response)=='<Response [200]>':
 #  print('ok')
   qq=html_to_json.convert(response.text)
   ww=pd.json_normalize(qq)
   zz=pd.DataFrame(ww._values[0][4][3].items())
   id=zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][1]['div'][1]['div'][0]['_attributes']['data-flat-id']
   num=zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][1]['div'][0]['_value']
   plan=zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][0]['a'][0]['_value']
   kvartal=zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][2]['a'][0]['_value']
   zz=pd.DataFrame(zz[1][1][0].items())
   zz=pd.DataFrame(zz[1][2][0].items())
   zz=pd.DataFrame(zz[1][1][0].items())
   zz=pd.DataFrame(zz[1][2][1].items())
   zz=pd.DataFrame(zz[1][1][1].items())
   zz=pd.DataFrame(zz[1][1][0].items())
   zzflat=zz[1][2][0]['div'][0]['div'][2]['_value']
   zzprice=zz[1][1][1]['_attributes']['value']
   zzm=zz[1][2][0]['div'][1]['div'][2]['_value']
   zzsrok=zz[1][2][0]['div'][2]['div'][2]['_value']
   zzotname1=zz[1][2][2]['div'][1]['div'][0]['input'][0]['_attributes']['data-flat-finish']
   zzotprice1=zz[1][2][2]['div'][1]['div'][0]['input'][0]['_attributes']['value']
   zzotname2=zz[1][2][2]['div'][2]['div'][0]['input'][0]['_attributes']['data-flat-finish']
   zzotprice2=zz[1][2][2]['div'][2]['div'][0]['input'][0]['_attributes']['value']
   zzotname3=zz[1][2][2]['div'][3]['div'][0]['input'][0]['_attributes']['data-flat-finish']
   zzotprice3=zz[1][2][2]['div'][3]['div'][0]['input'][0]['_attributes']['value']
   zzotname4=zz[1][2][2]['div'][4]['div'][0]['input'][0]['_attributes']['data-flat-finish']
   zzotprice4=zz[1][2][2]['div'][4]['div'][0]['input'][0]['_attributes']['value']
   new_row = {'id':id, 'num':num, 'plan':plan,'kvartal':kvartal,'zzflat':zzflat,'zzprice':zzprice,'zzm':zzm,'zzsrok':zzsrok,'zzotname1':zzotname1,'zzotprice1':zzotprice1,'zzotname2':zzotname2,'zzotprice2':zzotprice2,'zzotname3':zzotname3,'zzotprice3':zzotprice3,'zzotname4':zzotname4,'zzotprice4':zzotprice4}  
   df=df.append(new_row, ignore_index=True)
   time.sleep(4)
  i=i+1

# %%
 zz=pd.DataFrame(ww._values[0][4][3].items())

# %%
zz[1][1]
# Out:
# [{'_attributes': {'class': ['Main']},
#   'script': [{'_attributes': {'type': 'text/javascript'},
#     '_value': 'const eventParams = {\n\t\t\t"products" : [{"id":"03210379-df03-11eb-8166-00155d070804"}],\n\t\t\t"category_ids" : 13,\n\t\t\t"total_price" : 5947121\n\t\t\t};\n\t\t\twindow.vkAsyncInit = function() {\n\t\t\tVK.Retargeting.ProductEvent(227583, "view_product", eventParams);\n\t\t\t}'}],
#   'div': [{'_attributes': {'class': ['Flat']},
#     'div': [{'_attributes': {'class': ['container']},
#       'h1': [{'_attributes': {'class': ['H2', 'FlatTlt']},
#         'div': [{'_attributes': {'class': ['FlatTlt_type']},
#           'a': [{'_attributes': {'href': '/choose/params/type-10475/'},
#             '_value': 'Планировка Тип 330з'}]},
#          {'_attributes': {'class': ['Flat_row']},
#           'div': [{'_attributes': {'class': ['Flat_num']},
#             '_value': 'Квартира 113'},
#            {'_attributes': {'class': ['Flat_fav']},
#             'div': [{'_attributes': {'class': ['FavBtn'],
#                'data-favorite-flat': '',
#                'data-flat-id': '11989'}}]}]},
#          {'_attributes': {'class': ['FlatTlt_position']},
#           'a': [{'_attributes': {'href': '/choose/genplan/quarter-2664/'},
#             'span': [{'_attributes': {'class': ['_mob']}},
#              {'_attributes': {'class': ['_desc']}}],
#             '_value': 'Перспективный'},
#            {'_attributes': {'href': '/choose/genplan/house-2665/'},
#             'span': [{'_attributes': {'class': ['_mob']}, '_value': '.'},
#              {'_attributes': {'class': ['_desc']}, '_value': 'ом'},
#              {'_attributes': {'class': ['_mob']}, '_value': '.'},
#              {'_attributes': {'class': ['_desc']}, '_value': 'ция'}],
#             '_values': ['Д', '1, Сек', '2']},
#            {'_attributes': {'href': '/choose/genplan/house-2665/floor-9/'},
#             'span': [{'_attributes': {'class': ['_mob']}, '_value': '.'},
#              {'_attributes': {'class': ['_desc']}, '_value': 'аж'}],
#             '_values': ['Эт', '9']}],
#           'span': [{'_attributes': {'class': ['_separ']}, '_value': '/'},
#            {'_attributes': {'class': ['_separ']}, '_value': '/'}]}]}],
#       'div': [{'_attributes': {'class': ['Flat_links']},
#         'div': [{'_attributes': {'class': ['AccessLinks']},
#           'div': [{'_attributes': {'class': ['AccessLinks_item']},
#             'a': [{'_attributes': {'class': ['AccessBtn', 'ShareBtn'],
#                'href': '#'},
#               'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#                  'width': '16',
#                  'height': '16',
#                  'viewbox': '0 0 16 16',
#                  'fill': 'none'},
#                    'fill': 'var(--colorAccessBtn)'}},
#                  {'_attributes': {'fill-rule': 'evenodd',
#                    'clip-rule': 'evenodd',
#                    'd': 'M4 4.5H14V1H4V4.5ZM3 5H15V1C15 0.447 14.552 0 14 0H4C3.448 0 3 0.447 3 1V5Z',
#                    'fill': 'var(--colorAccessBtn)'}},
#                  {'_attributes': {'fill-rule': 'evenodd',
#                    'clip-rule': 'evenodd',
#                    'd': 'M15 7.5H3L3 15C3 15.553 3.448 16 4 16H14C14.552 16 15 15.553 15 15V7.5ZM4 15H14V8.5H4V15Z',
#                    'fill': 'var(--colorAccessBtn)'}}],
#                 'rect': [{'_attributes': {'x': '6',
#                    'y': '10.5',
#                    'width': '6',
#                    'height': '1',
#                    'rx': '0.5',
#                    'fill': 'var(--colorAccessBtn)'}},
#                  {'_attributes': {'x': '6',
#                    'y': '12.5',
#                    'width': '6',
#                    'height': '1',
#                    'rx': '0.5',
#                    'fill': 'var(--colorAccessBtn)'}}]}],
#               'span': [{'_attributes': {'class': ['AccessBtn_txt']},
#                 '_value': 'Напечатать'}]}]},
#            {'_attributes': {'class': ['AccessLinks_item']},
#             'a': [{'_attributes': {'class': ['AccessBtn'],
#                'href': '/choose/params/flat-11989/pdf/',
#                'data-href': '/choose/params/flat-11989/pdf/',
#                'data-flat-print-pdf': ''},
#               'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#                  'width': '16',
#                  'height': '18',
#                  'viewbox': '0 0 16 18',
#                  'fill': 'none'},
#                 'path': [{'_attributes': {'d': 'M15 12V15C15 16.104 14.104 17 13 17H3C1.896 17 1 16.104 1 15V12',
#                    'stroke': 'var(--colorAccessBtn)',
#                    'stroke-linecap': 'round',
#                    'stroke-linejoin': 'round'}},
#                  {'_attributes': {'d': 'M4 7L8 11L12 7',
#                    'stroke': 'var(--colorAccessBtn)',
#                    'stroke-linecap': 'round',
#                    'stroke-linejoin': 'round'}},
#                  {'_attributes': {'d': 'M8 11V1',
#                    'stroke': 'var(--colorAccessBtn)',
#                    'stroke-linecap': 'round',
#                    'stroke-linejoin': 'round'}},
#                  {'_attributes': {'d': 'M4 14H12',
#                    'stroke': 'var(--colorAccessBtn)',
#                    'stroke-linecap': 'round',
#                    'stroke-linejoin': 'round'}}]}],
#               'span': [{'_attributes': {'class': ['AccessBtn_txt']},
#                 '_value': 'Скачать PDF'}]}]}]}]},
#        {'_attributes': {'class': ['FlatTop']},
#         'div': [{'_attributes': {'class': ['FlatTop_item', '_left']},
#           'div': [{'_attributes': {'class': ['FlatPlan']},
#             'div': [{'_attributes': {'class': ['FlatPlanTabs']},
#               'ul': [{'_attributes': {'class': ['FlatPlanTabs_list']},
#                 'li': [{'_attributes': {'class': ['FlatPlanTabs_item']},
#                   'a': [{'_attributes': {'class': ['_active'],
#                      'href': '#planTab-1'},
#                     '_value': 'Планировка'}]},
#                  {'_attributes': {'class': ['FlatPlanTabs_item']},
#                   'a': [{'_attributes': {'href': '#planTab-2'},
#                     '_value': 'На этаже'}]},
#                  {'_attributes': {'class': ['FlatPlanTabs_item']},
#                   'a': [{'_attributes': {'href': '#planTab-3'},
#                     '_value': 'В секции'}]},
#                  {'_attributes': {'class': ['FlatPlanTabs_item']},
#                   'a': [{'_attributes': {'href': '#planTab-4'},
#                     '_value': 'На генплане'}]}]}]},
#              {'_attributes': {'class': ['FlatPlanImg', '_type'],
#                'id': 'planTab-1'},
#               'div': [{'_attributes': {'class': ['FlatPlanImg_wrap', '_type']},
#                 'img': [{'_attributes': {'class': ['FlatPlanImg_img'],
#                    'src': '/upload/shop_3/1/1/9/item_11989/shop_property_file_11989_13720.svg',
#                    'alt': ''}}]}]},
#              {'_attributes': {'class': ['FlatPlanImg', '_floor'],
#                'id': 'planTab-2'},
#               'div': [{'_attributes': {'class': ['FlatPlanImg_wrap', '_type']},
#                 'img': [{'_attributes': {'class': ['FlatPlanImg_img'],
#                    'src': '/choose/params/flat-11989/floor_svg/',
#                    'alt': ''}}]}]},
#              {'_attributes': {'class': ['FlatPlanImg', '_section'],
#                'id': 'planTab-3'},
#               'div': [{'_attributes': {'class': ['FlatPlanImg_wrap',
#                   '_section']},
#                 'img': [{'_attributes': {'class': ['FlatPlanImg_img',
#                     '_section'],
#                    'src': '/choose/params/flat-11989/floor_section/',
#                    'alt': ''}}]}]},
#              {'_attributes': {'class': ['FlatPlanImg', '_section'],
#                'id': 'planTab-4'},
#               'div': [{'_attributes': {'class': ['FlatPlanImg_wrap',
#                   '_section']},
#                 'img': [{'_attributes': {'class': ['FlatPlanImg_img',
#                     '_section'],
#                    'src': '/upload/shop_3/2/6/6/group_2665/shop_property_file_2665_13492.svg',
#                    'alt': ''}}]}]}],
#             'img': [{'_attributes': {'class': ['FlatPlan_compass'],
#                'data-flat-compass': 'planTab-1',
#                'src': '/upload/shop_3/2/6/6/group_2665/shop_property_file_2665_13493.svg',
#                'alt': ''}},
#              {'_attributes': {'class': ['FlatPlan_compass'],
#                'data-flat-compass': 'planTab-2',
#                'src': '/upload/shop_3/2/6/6/group_2665/shop_property_file_2665_13493.svg',
#                'alt': ''}},
#              {'_attributes': {'class': ['FlatPlan_compass'],
#                'data-flat-compass': 'planTab-3',
#                'src': '/upload/shop_3/2/6/6/group_2665/shop_property_file_2665_13878.svg',
#                'alt': ''}},
#              {'_attributes': {'class': ['FlatPlan_compass'],
#                'data-flat-compass': 'planTab-4',
#                'src': '/upload/shop_3/2/6/6/group_2664/shop_property_file_2664_13491.svg',
#                'alt': ''}}],
#             'button': [{'_attributes': {'class': ['Zoom', 'FlatPlan_zoom'],
#                'data-img-zoom': '',
#                'href': '/choose/params/flat-11989/floor_svg',
#                'data-fancybox': 'images'},
#               'span': [{'_attributes': {'class': ['Zoom_txt']},
#                 '_value': 'На весь экран'},
#                {'_attributes': {'class': ['Zoom_icon']},
#                 'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#                    'width': '18',
#                    'height': '18',
#                    'viewbox': '0 0 18 18',
#                    'fill': 'none'},
#                   '_value': 'Комнат'},
#                  {'_attributes': {'class': ['FlatInfo_dots']}},
#                  {'_attributes': {'class': ['FlatInfo_val']}, '_value': '3'}]},
#                {'_attributes': {'class': ['FlatInfo_item']},
#                 'div': [{'_attributes': {'class': ['FlatInfo_lbl']},
#                   '_value': 'Площадь'},
#                  {'_attributes': {'class': ['FlatInfo_dots']}},
#                  {'_attributes': {'class': ['FlatInfo_val']},
#                   '_value': '75.13 м',
#                   'sup': [{'_value': '2'}]}]},
#                {'_attributes': {'class': ['FlatInfo_item']},
#                 'div': [{'_attributes': {'class': ['FlatInfo_lbl']},
#                   '_value': 'Срок сдачи'},
#                  {'_attributes': {'class': ['FlatInfo_dots']}},
#                  {'_attributes': {'class': ['FlatInfo_val']},
#                   '_value': 'I кв. 2023'}]},
#                {'_attributes': {'class': ['FlatInfo_item']},
#                 'div': [{'_attributes': {'class': ['FlatInfo_lbl']},
#                   '_value': 'Вид из окна'},
#                  {'_attributes': {'class': ['FlatInfo_dots']}},
#                  {'_attributes': {'class': ['FlatInfo_val']},
#                   '_value': 'Двор, Улица'}]}]},
#              {'_attributes': {'class': ['FlatPrice']},
#               'div': [{'_attributes': {'class': ['FlatPrice_row']},
#                 'div': [{'_attributes': {'class': ['FlatPrice_lbl']},
#                   '_value': 'Цена:'},
#                  {'_attributes': {'class': ['FlatPrice_val'],
#                    'data-flat-price': ''}}]},
#                {'_attributes': {'class': ['FlatPrice_row']},
#                 'div': [{'_attributes': {'class': ['FlatPrice_lbl']},
#                   '_value': 'Цена по акции:'},
#                  {'_attributes': {'class': ['FlatPrice_val', '_action'],
#                    'data-flat-price-discount': ''}}]},
#                {'_attributes': {'class': ['FlatPrice_note']},
#                 'p': [{'_attributes': {'style': 'white-space: normal;'},
#                   '_value': '*Подробности акции на сайте или в отделе продаж.'}]},
#                {'_attributes': {'class': ['FlatPrice_note']},
#                 'p': [{'_attributes': {'style': 'white-space: normal;'},
#                   '_value': '**На данный момент реализация квартир в чистовой отделке не осуществляется.'}]}],
#               'button': [{'_attributes': {'class': ['Btn',
#                   '_oranj',
#                   'FlatPrice_btn'],
#                  'data-booking-form-link': ''},
#                 '_value': 'Забронировать'}]},
#              {'_attributes': {'class': ['FlatFinish']},
#               'div': [{'_attributes': {'class': ['FlatFinish_tlt']},
#                 '_value': 'Варианты отделки'},
#                {'_attributes': {'class': ['FlatFinish_item']},
#                 'div': [{'_attributes': {'class': ['FlatFinishItem']},
#                   'input': [{'_attributes': {'class': ['FlatFinishItem_input'],
#                      'type': 'radio',
#                      'name': 'flat_finish',
#                      'id': 'finish_1',
#                      'checked': 'checked',
#                      'value': '0',
#                      'data-flat-finish': 'Улучшенная предчистовая',
#                      'data-flat-finish-name': 'prefinishing'}}],
#                   'label': [{'_attributes': {'class': ['FlatFinishItem_lbl'],
#                      'for': 'finish_1'}}],
#                   'div': [{'_attributes': {'class': ['FlatFinishItem_name']},
#                     '_value': 'Улучшенная предчистовая'},
#                    {'_attributes': {'class': ['FlatFinishItem_price']}}]}]},
#                {'_attributes': {'class': ['FlatFinish_item', '_disabled']},
#                 'div': [{'_attributes': {'class': ['FlatFinishItem']},
#                   'input': [{'_attributes': {'class': ['FlatFinishItem_input'],
#                      'type': 'radio',
#                      'name': 'flat_finish',
#                      'id': 'finish_2',
#                      'value': '0',
#                      'data-flat-finish': 'Чистовая «Стандарт»',
#                      'data-flat-finish-name': 'standart'}}],
#                   'label': [{'_attributes': {'class': ['FlatFinishItem_lbl'],
#                      'for': 'finish_2'}}],
#                   'div': [{'_attributes': {'class': ['FlatFinishItem_name']},
#                     '_value': 'Чистовая «Стандарт»'},
#                    {'_attributes': {'class': ['FlatFinishItem_price']}}]}]},
#                {'_attributes': {'class': ['FlatFinish_item', '_disabled']},
#                 'div': [{'_attributes': {'class': ['FlatFinishItem']},
#                   'input': [{'_attributes': {'class': ['FlatFinishItem_input'],
#                      'type': 'radio',
#                      'name': 'flat_finish',
#                      'id': 'finish_3',
#                      'value': '0',
#                      'data-flat-finish': 'Чистовая «Комфорт»',
#                      'data-flat-finish-name': 'comfort'}}],
#                   'label': [{'_attributes': {'class': ['FlatFinishItem_lbl'],
#                      'for': 'finish_3'}}],
#                   'div': [{'_attributes': {'class': ['FlatFinishItem_name']},
#                     '_value': 'Чистовая «Комфорт»'},
#                    {'_attributes': {'class': ['FlatFinishItem_price']}}]}]},
#                {'_attributes': {'class': ['FlatFinish_item', '_disabled']},
#                 'div': [{'_attributes': {'class': ['FlatFinishItem']},
#                   'input': [{'_attributes': {'class': ['FlatFinishItem_input'],
#                      'type': 'radio',
#                      'name': 'flat_finish',
#                      'id': 'finish_4',
#                      'value': '0',
#                      'data-flat-finish': 'Чистовая «Комфорт +»',
#                      'data-flat-finish-name': 'comfortPlus'}}],
#                   'label': [{'_attributes': {'class': ['FlatFinishItem_lbl'],
#                      'for': 'finish_4'}}],
#                   'div': [{'_attributes': {'class': ['FlatFinishItem_name']},
#                     '_value': 'Чистовая «Комфорт +»'},
#                    {'_attributes': {'class': ['FlatFinishItem_price']}}]}]}],
#               'a': [{'_attributes': {'class': ['FlatFinish_more'],
#                  'href': '/advantages/#types-finish'},
#                 '_value': 'Подробнее',
#                 'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#                    'width': '9',
#                    'height': '16',
#                    'viewbox': '0 0 9 16',
#                    'fill': 'none'},
#                   'rect': [{'_attributes': {'width': '11.0451',
#                      'height': '2.0082',
#                      'rx': '1',
#                      'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                      'fill': '#34424F'}},
#                    {'_attributes': {'width': '2.0082',
#                      'height': '11.0451',
#                      'rx': '1',
#                      'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                      'fill': '#34424F'}}]}]}]}]}]}]}],
#       'h2': [{'_attributes': {'class': ['H2']}, '_value': 'Варианты оплаты'},
#        {'_attributes': {'class': ['H2']}, '_value': 'Похожие квартиры'}],
#       'section': [{'_attributes': {'class': ['Flat_section']},
#         'div': [{'_attributes': {'class': ['FlatPay', 'TabsPage']},
#           'div': [{'_attributes': {'class': ['FlatPaySelect'],
#              'data-tabs-xs': ''},
#             'div': [{'_attributes': {'class': ['FlatPaySelect_val']},
#               'span': [{'_attributes': {'data-tabs-xs-val': ''},
#                 '_value': 'Ипотека'}],
#               'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#                  'width': '9',
#                  'height': '16',
#                  'viewbox': '0 0 9 16',
#                  'fill': 'none'},
#                 'rect': [{'_attributes': {'width': '11.0451',
#                    'height': '2.0082',
#                    'rx': '1',
#                    'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                    'fill': '#34424F'}},
#                  {'_attributes': {'width': '2.0082',
#                    'height': '11.0451',
#                    'rx': '1',
#                    'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                    'fill': '#34424F'}}]}]}]},
#            {'_attributes': {'class': ['FlatPay_tabBody', '_mortgage'],
#              'id': 'tabs-1'},
#             'div': [{'_attributes': {'class': ['FlatPay_txt']},
#               'div': [{'_attributes': {'class': ['FlatPay_txtInner']},
#                 'br': [{}],
#                 '_values': ['Купите квартиру №113 в\xa0ипотеку',
#                  'по\xa0сниженной ставке',
#                  'Рассчитайте ипотеку по номеру: 8\xa0(846)\xa0264-00-64.'],
#                 'ul': [{'li': [{'_value': '•\xa0от 0,1%, пока дом строится'},
#                    {'_value': '•\xa0от 4% на весь срок'}]}]}]},
#              {'_attributes': {'class': ['FlatPay_content']},
#               'form': [{'_attributes': {'class': ['FlatPayForm'],
#                  'method': '',
#                  'action': '',
#                  'data-mortgage-form': ''},
#                 'input': [{'_attributes': {'type': 'hidden',
#                    'name': 'discount',
#                    'value': '{"percent": 2, "fix": 0}'}},
#                  {'_attributes': {'type': 'hidden',
#                    'name': 'mortgage_rate',
#                    'value': '4'}},
#                  {'_attributes': {'type': 'hidden',
#                    'name': 'payments_price_start',
#                    'value': ''}},
#                  {'_attributes': {'type': 'hidden',
#                    'name': 'price_with_discount',
#                    'value': ''}}],
#                 'div': [{'_attributes': {'class': ['FlatPayForm_item']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Первоначальный взнос'},
#                    {'_attributes': {'class': ['RangeSliderSingle']},
#                     'div': [{'_attributes': {'class': ['RangeSliderSingle_inner'],
#                        'data-slider-range': '{"min":600000, "max":5900000, "step": 50000}',
#                        'data-slider-type': 'firstPayment'},
#                       'div': [{'_attributes': {'class': ['RangeSliderSingle_inputs']},
#                         'div': [{'_attributes': {'class': ['RangeSliderSingle_value'],
#                            'data-value-render': ''}}],
#                         'input': [{'_attributes': {'type': 'number',
#                            'name': 'firstPayment',
#                            'value': '1400000',
#                            'data-persist-id': 'firstPayment',
#                            'autocomplete': 'off'}}]}]}]}]},
#                  {'_attributes': {'class': ['FlatPayForm_item']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Срок'},
#                    {'_attributes': {'class': ['RangeSliderSingle']},
#                     'div': [{'_attributes': {'class': ['RangeSliderSingle_inner'],
#                        'data-slider-range': '{"min":1, "max":30, "step": 1}',
#                        'data-slider-type': 'years'},
#                       'div': [{'_attributes': {'class': ['RangeSliderSingle_inputs']},
#                         'div': [{'_attributes': {'class': ['RangeSliderSingle_value'],
#                            'data-value-render': ''}}],
#                         'input': [{'_attributes': {'type': 'number',
#                            'name': 'years',
#                            'value': '15',
#                            'data-persist-id': 'years',
#                            'autocomplete': 'off'}}]}]}]}]},
#                  {'_attributes': {'class': ['FlatPayForm_item', '_small']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Ежемесячный платёж'},
#                    {'_attributes': {'class': ['FlatPayForm_digits'],
#                      'data-mortgage-payment': ''}}]},
#                  {'_attributes': {'class': ['FlatPayForm_item', '_small']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Процентная ставка'},
#                    {'_attributes': {'class': ['FlatPayForm_digits'],
#                      'data-mortgage-rate': ''},
#                     '_value': 'от 4%'}]}]}],
#               'div': [{'_attributes': {'class': ['FlatPayNote']},
#                 'div': [{'_attributes': {'class': ['FlatPayNote_item',
#                     '_txt']},
#                   'br': [{}],
#                   '_values': ['Подробнее об условиях покупки',
#                    'в ипотеку в разделе'],
#                   'a': [{'_attributes': {'href': '/buy/mortgage/'},
#                     '_value': '«Как купить»'}]},
#                  {'_attributes': {'class': ['FlatPayNote_item']},
#                   'button': [{'_attributes': {'class': ['Btn',
#                       'FlatPayNote_btn'],
#                      'data-booking-form-link': ''},
#                     '_value': 'Забронировать'}]}]}]}]},
#            {'_attributes': {'class': ['FlatPay_tabBody', '_installment'],
#              'id': 'tabs-2'},
#             'div': [{'_attributes': {'class': ['FlatPay_txt']},
#               'div': [{'_attributes': {'class': ['FlatPay_txtInner']},
#                 '_value': 'Узнайте о возможности купить квартиру №113 в\xa0беспроцентную рассрочку от\xa0застройщика\n\t\t\t\t\t\t\t\t\t\t со\xa0скидкой от\xa01.5%'}]},
#              {'_attributes': {'class': ['FlatPay_content']},
#               'form': [{'_attributes': {'class': ['FlatPayForm'],
#                  'method': '',
#                  'action': '',
#                  'data-installment-form': ''},
#                 'input': [{'_attributes': {'type': 'hidden',
#                    'name': 'discount',
#                    'value': '{"percent": 1.5, "fix": 0}'}},
#                  {'_attributes': {'type': 'hidden',
#                    'name': 'payments_price_start',
#                    'value': ''}},
#                  {'_attributes': {'type': 'hidden',
#                    'name': 'price_with_discount',
#                    'value': ''}}],
#                 'div': [{'_attributes': {'class': ['FlatPayForm_item',
#                     '_big']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Первоначальный взнос'},
#                    {'_attributes': {'class': ['RangeSliderSingle']},
#                     'div': [{'_attributes': {'class': ['RangeSliderSingle_inner'],
#                        'data-slider-range': '{"min":100000, "max":5900000, "step": 50000}',
#                        'data-slider-type': 'firstPayment'},
#                       'div': [{'_attributes': {'class': ['RangeSliderSingle_inputs']},
#                         'div': [{'_attributes': {'class': ['RangeSliderSingle_value'],
#                            'data-value-render': ''}}],
#                         'input': [{'_attributes': {'type': 'number',
#                            'name': 'firstPayment',
#                            'value': '1400000',
#                            'data-persist-id': 'firstPayment',
#                            'autocomplete': 'off'}}]}]}]}]},
#                  {'_attributes': {'class': ['FlatPayForm_item', '_small']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Рассчётный период'},
#                    {'_attributes': {'class': ['FlatPayForm_digits'],
#                      'data-deadline': '2023/1'},
#                     '_value': 'до I кв. 2023'}]},
#                  {'_attributes': {'class': ['FlatPayForm_item', '_small']},
#                   'div': [{'_attributes': {'class': ['IndexMortgage_lbl',
#                       '_flat']},
#                     '_value': 'Ежемесячный платёж'},
#                    {'_attributes': {'class': ['FlatPayForm_digits'],
#                      'data-installment-payment-month': ''}}]}]}],
#               'div': [{'_attributes': {'class': ['FlatPayNote']},
#                 'div': [{'_attributes': {'class': ['FlatPayNote_item',
#                     '_txt']},
#                   'br': [{}],
#                   '_values': ['Подробнее об условиях покупки',
#                    'в рассрочку в разделе'],
#                   'a': [{'_attributes': {'href': '/buy/installment/'},
#                     '_value': '«Как купить»'}]},
#                  {'_attributes': {'class': ['FlatPayNote_item']},
#                   'button': [{'_attributes': {'class': ['Btn',
#                       'FlatPayNote_btn'],
#                      'data-booking-form-link': ''},
#                     '_value': 'Забронировать'}]}]}]}]},
#            {'_attributes': {'class': ['FlatPay_tabBody', '_full'],
#              'id': 'tabs-3'},
#             'div': [{'_attributes': {'class': ['FlatPay_txt']},
#               'div': [{'_attributes': {'class': ['FlatPay_txtInner']},
#                 'br': [{}],
#                 '_values': ['Купите квартиру №113 с\xa0полной оплатой собственными средствами',
#                  'и получите скидку от\xa02%']}]},
#              {'_attributes': {'class': ['FlatPay_content']},
#               'form': [{'_attributes': {'method': '',
#                  'action': '',
#                  'data-fullbuy-form': ''},
#                 'input': [{'_attributes': {'type': 'hidden',
#                    'name': 'discount',
#                    'value': '{"percent": 2, "fix": 0}'}},
#                  {'_attributes': {'type': 'hidden',
#                    'name': 'payments_price_start',
#                    'value': ''}}]}],
#               'div': [{'_attributes': {'class': ['FlatPayFull']},
#                 'div': [{'_attributes': {'class': ['FlatPayFull_item']},
#                   'div': [{'_attributes': {'class': ['FlatPayFull_tlt']},
#                     '_value': '1. Бронирование'},
#                    {'_attributes': {'class': ['FlatPayFull_txt']},
#                     '_value': 'Забронируйте квартиру'}]},
#                  {'_attributes': {'class': ['FlatPayFull_item']},
#                   'div': [{'_attributes': {'class': ['FlatPayFull_tlt']},
#                     '_value': '2. Договор'},
#                    {'_attributes': {'class': ['FlatPayFull_txt']},
#                     '_value': 'Заключите договор долевого участия'}]},
#                  {'_attributes': {'class': ['FlatPayFull_item']},
#                   'div': [{'_attributes': {'class': ['FlatPayFull_tlt']},
#                     '_value': '3. Регистрация'},
#                    {'_attributes': {'class': ['FlatPayFull_txt']},
#                     '_value': 'Зарегистрируйте договор в\xa0Росреестре'}]},
#                  {'_attributes': {'class': ['FlatPayFull_item']},
#                   'div': [{'_attributes': {'class': ['FlatPayFull_tlt']},
#                     '_value': '4. Оплата'},
#                    {'_attributes': {'class': ['FlatPayFull_txt']},
#                     '_value': 'Получите договор и\xa0оплатите квартиру'}]}]},
#                {'_attributes': {'class': ['FlatPayNote']},
#                 'div': [{'_attributes': {'class': ['FlatPayNote_item',
#                     '_txt']},
#                   'br': [{}],
#                   '_values': ['Подробнее об условиях покупки',
#                    'по 100% оплате в разделе'],
#                   'a': [{'_attributes': {'href': '/buy/full_payment/'},
#                     '_value': '«Как купить»'}]},
#                  {'_attributes': {'class': ['FlatPayNote_item']},
#                   'button': [{'_attributes': {'class': ['Btn',
#                       'FlatPayNote_btn'],
#                      'data-booking-form-link': ''},
#                     '_value': 'Забронировать'}]}]}]}]}],
#           'ul': [{'_attributes': {'class': ['TabsPage_list', 'FlatPay_tabs'],
#              'data-tabs': ''},
#             'li': [{'_attributes': {'class': ['TabsPage_item', '_flatPay']},
#               'a': [{'_attributes': {'href': '#tabs-1',
#                  'data-tab': '',
#                  'data-tab-title': 'Ипотека'},
#                 '_value': 'Ипотека'}]},
#              {'_attributes': {'class': ['TabsPage_item', '_flatPay'],
#                'data-tab-installment': ''},
#               'a': [{'_attributes': {'href': '#tabs-2',
#                  'data-tab': '',
#                  'data-tab-title': 'Рассрочка'},
#                 '_value': 'Рассрочка'}]},
#              {'_attributes': {'class': ['TabsPage_item', '_flatPay']},
#               'a': [{'_attributes': {'href': '#tabs-3',
#                  'data-tab': '',
#                  'data-tab-title': '100% оплата'},
#                 '_value': '100% оплата'}]}]}]}]},
#        {'_attributes': {'class': ['Flat_section', '_similar']},
#         'button': [{'_attributes': {'class': ['ArrowSlider',
#             '_left',
#             'swiper-hot-button-prev'],
#            'data-slider-prev': ''},
#           'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#              'width': '9',
#              'height': '16',
#              'viewbox': '0 0 9 16',
#              'fill': 'none'},
#             'rect': [{'_attributes': {'width': '11.0451',
#                'height': '2.0082',
#                'rx': '1',
#                'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                'fill': '#34424F'}},
#              {'_attributes': {'width': '2.0082',
#                'height': '11.0451',
#                'rx': '1',
#                'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                'fill': '#34424F'}}]}]},
#          {'_attributes': {'class': ['ArrowSlider',
#             '_right',
#             'swiper-hot-button-next'],
#            'data-slider-next': ''},
#           'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#              'width': '9',
#              'height': '16',
#              'viewbox': '0 0 9 16',
#              'fill': 'none'},
#             'rect': [{'_attributes': {'width': '11.0451',
#                'height': '2.0082',
#                'rx': '1',
#                'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                'fill': '#34424F'}},
#              {'_attributes': {'width': '2.0082',
#                'height': '11.0451',
#                'rx': '1',
#                'transform': 'matrix(-0.689481 0.724304 -0.689481 -0.724303 9 8)',
#                'fill': '#34424F'}}]}]}],
#         'div': [{'_attributes': {'class': ['FlatSimilar', 'swiper-container'],
#            'data-index-slider': ''},
#           'div': [{'_attributes': {'class': ['FlatSimilar_list',
#               'swiper-wrapper']},
#             'div': [{'_attributes': {'class': ['FlatSimilar_item',
#                 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '3 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '13137'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/3/1/item_13137/shop_property_file_13137_15159.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 1.1 / д. 1 / с. 3 / эт. 5 / №118'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '77.69 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 621 026 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'IV кв. 2024'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-13137/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '2 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '13295'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/3/2/item_13295/shop_property_file_13295_15319.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 1.1 / д. 2 / с. 3 / эт. 7 / №171'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '61.78 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '4 539 965 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'IV кв. 2024'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-13295/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '2 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '11372'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/1/3/item_11372/shop_property_file_11372_12687.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 25.4 / д. 1 / с. 2 / эт. 6 / №196'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '72.35 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 896 474 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'III кв. 2023'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-11372/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '2 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '11209'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/1/2/item_11209/shop_property_file_11209_12513.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 25.4 / д. 1 / с. 1 / эт. 2 / №15'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '72.11 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 836 070 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'III кв. 2023'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-11209/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '2 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '13076'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/3/0/item_13076/shop_property_file_13076_15104.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 1.1 / д. 1 / с. 2 / эт. 8 / №86'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '61.78 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '4 539 965 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'IV кв. 2024'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-13076/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '3 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '10668'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/0/6/item_10668/shop_property_file_10668_11957.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 45.3 / д. 2 / с. 1 / эт. 8 / №36'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '78 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 851 912 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'I кв. 2023'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-10668/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '2 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '11200'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/1/2/item_11200/shop_property_file_11200_12612.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 25.4 / д. 1 / с. 1 / эт. 13 / №114'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '72.11 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 876 936 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'III кв. 2023'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-11200/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '3 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '13157'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/3/1/item_13157/shop_property_file_13157_15063.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 1.1 / д. 1 / с. 3 / эт. 1 / №102'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '77.69 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 156 322 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'IV кв. 2024'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-13157/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '3 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '11802'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/1/8/item_11802/shop_property_file_11802_13318.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 42 / д. 2 / с. 7 / эт. 3 / №365'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '73.32 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 905 245 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'I кв. 2023'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-11802/'}}]}]}]},
#              {'_attributes': {'class': ['FlatSimilar_item', 'swiper-slide']},
#               'div': [{'_attributes': {'class': ['PlanCard', '_similar']},
#                 'div': [{'_attributes': {'class': ['PlanCard_inner']},
#                   'div': [{'_attributes': {'class': ['PlanCard_row', '_top']},
#                     'div': [{'_attributes': {'class': ['PlanCard_rooms']},
#                       '_value': '2 комнаты'},
#                      {'_attributes': {'class': ['PlanCard_fav']},
#                       'div': [{'_attributes': {'class': ['FavBtn'],
#                          'data-favorite-flat': '',
#                          'data-flat-id': '11390'}}]}]},
#                    {'_attributes': {'class': ['PlanCard_img']},
#                     'img': [{'_attributes': {'src': '/upload/shop_3/1/1/3/item_11390/shop_property_file_11390_12705.svg',
#                        'alt': ''}}]},
#                    {'_attributes': {'class': ['PlanCard_place']},
#                     '_value': 'Кв-л 25.4 / д. 1 / с. 2 / эт. 8 / №214'},
#                    {'_attributes': {'class': ['PlanCard_row', '_info']},
#                     'span': [{'_value': '72.35 м', 'sup': [{'_value': '2'}]},
#                      {'_value': '5 896 474 ₽'}]},
#                    {'_attributes': {'class': ['PlanCard_row', '_bottom']},
#                     'span': [{'_value': 'Срок сдачи:'},
#                      {'_value': 'III кв. 2023'}]}],
#                   'a': [{'_attributes': {'class': ['PlanCard_link'],
#                      'href': '/choose/params/flat-11390/'}}]}]}]}]}]}]}]}]},
#    {'_attributes': {'class': ['FormPopup'],
#      'data-booking-form-popup': '',
#      'style': 'display:none;'},
#     'div': [{'_attributes': {'class': ['Form']},
#       'div': [{'_attributes': {'class': ['Form_inner']},
#         'div': [{'_attributes': {'class': ['Form_hd']},
#           'div': [{'_attributes': {'class': ['Form_tlt']},
#             '_value': 'Бронирование квартиры №113',
#             'small': [{'_value': 'Квартал 25.4.1 / Дом 1 / Секция 2 / Этаж 9'}]},
#            {'_attributes': {'class': ['FormColorBorder']},
#             'div': [{'_attributes': {'class': ['FormColorBorder_item',
#                 '_color1']}},
#              {'_attributes': {'class': ['FormColorBorder_item', '_color2']}},
#              {'_attributes': {'class': ['FormColorBorder_item', '_color3']}},
#              {'_attributes': {'class': ['FormColorBorder_item', '_color4']}},
#              {'_attributes': {'class': ['FormColorBorder_item',
#                 '_color5']}}]}]}],
#         'form': [{'_attributes': {'class': ['Form_body'],
#            'action': '/ajax/form-booked-flat/',
#            'data-action': '/ajax/form-booked-flat/',
#            'method': 'post',
#            'autocomplete': 'off',
#            'data-booking-form': '',
#            'data-utm-save': '',
#            'data-ym-args': '{"code": 23592493, "name": "knopka_bron_kvartiry"}'},
#           'input': [{'_attributes': {'type': 'hidden',
#              'name': 'comment',
#              'value': 'Квартиры №113 / Квартал 25.4.1 / Дом 1 / Секция 2 / Этаж 9'}}],
#           'div': [{'_attributes': {'class': ['Form_item']},
#             'div': [{'_attributes': {'class': ['InputText', '_popup']},
#               'input': [{'_attributes': {'class': ['InputText_inpt'],
#                  'type': 'text',
#                  'name': 'name'}}],
#               'label': [{'_attributes': {'class': ['InputText_lbl', '_popup']},
#                 '_value': 'Ваше имя'}]}]},
#            {'_attributes': {'class': ['Form_item']},
#             'div': [{'_attributes': {'class': ['InputText',
#                 '_popup',
#                 '_error']},
#               'input': [{'_attributes': {'class': ['InputText_inpt'],
#                  'type': 'tel',
#                  'name': 'phone',
#                  'required': ''}}],
#               'label': [{'_attributes': {'class': ['InputText_lbl', '_popup']},
#                 '_value': 'Телефон'}]}]},
#            {'_attributes': {'class': ['Form_item']},
#             'div': [{'_attributes': {'class': ['SelectTime', '_active']},
#               'label': [{'_attributes': {'class': ['SelectTime_lbl']},
#                 '_value': 'Время звонка'}],
#               'select': [{'_attributes': {'class': ['SelectForm'],
#                  'data-select': '',
#                  'name': 'time',
#                  'data-time-tour': ''}}]}]},
#            {'_attributes': {'class': ['Form_item']},
#             'button': [{'_attributes': {'class': ['Form_btn', 'Btn', '_oranj'],
#                'type': 'Submit'},
#               '_value': 'Перезвонить мне'}]},
#            {'_attributes': {'class': ['Form_note']},
#             '_value': 'Отправляя форму, Вы соглашаетесь с условиями',
#             'a': [{'_attributes': {'href': '/upload/policy.pdf',
#                'target': '_blank'},
#               '_value': 'пользовательского соглашения'}]}]}],
#         'button': [{'_attributes': {'class': ['Form_close'],
#            'data-close-popup': ''},
#           'svg': [{'_attributes': {'xmlns': 'http://www.w3.org/2000/svg',
#              'width': '17',
#              'height': '16',
#              'viewbox': '0 0 17 16',
#              'fill': 'none'},
#             'rect': [{'_attributes': {'width': '20.6587',
#                'height': '1.9675',
#                'rx': '0.983748',
#                'transform': 'matrix(0.707075 -0.707138 0.707075 0.707138 1 14.6094)',
#                'fill': '#34424F'}},
#              {'_attributes': {'width': '20.6587',
#                'height': '1.9675',
#                'rx': '0.983748',
#                'transform': 'matrix(-0.707076 -0.707138 0.707075 -0.707138 15.6055 16)',
#                'fill': '#34424F'}}]}]}]}]}]}]}]

# %%
print(str(response))
# Out:
# <Response [200]>

# %%
data_table.DataTable.max_columns = 110
data_table.DataTable(df, include_index=False, num_rows_per_page=900)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>num</th>
#       <th>plan</th>
#       <th>kvartal</th>
#       <th>zzflat</th>
#       <th>zzprice</th>
#       <th>zzm</th>
#       <th>zzsrok</th>
#       <th>zzotname1</th>
#       <th>zzotprice1</th>
#       <th>zzotname2</th>
#       <th>zzotprice2</th>
#       <th>zzotname3</th>
#       <th>zzotprice3</th>
#       <th>zzotname4</th>
#       <th>zzotprice4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12010</td>
#       <td>Квартира 85</td>
#       <td>Планировка Тип 330з</td>
#       <td>Перспективный</td>
#       <td>3</td>
#       <td>6359155.00</td>
#       <td>75.13 м</td>
#       <td>I кв. 2023</td>
#       <td>Улучшенная предчистовая</td>
#       <td>0</td>
#       <td>Чистовая «Стандарт»</td>
#       <td>0</td>
#       <td>Чистовая «Комфорт»</td>
#       <td>0</td>
#       <td>Чистовая «Комфорт +»</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td
td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>860</th>
#       <td>11925</td>
#       <td>Квартира 497</td>
#       <td>Планировка Тип 329</td>
#       <td>У парка</td>
#       <td>3</td>
#       <td>6936726.00</td>
#       <td>77.53 м</td>
#       <td>I кв. 2023</td>
#       <td>Улучшенная предчистовая</td>
#       <td>0</td>
#       <td>Чистовая «Стандарт»</td>
#       <td>0</td>
#       <td>Чистовая «Комфорт»</td>
#       <td>0</td>
#       <td>Чистовая «Комфорт +»</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>861</th>
#       <td>11989</td>
#       <td>Квартира 113</td>
#       <td>Планировка Тип 330з</td>
#       <td>Перспективный</td>
#       <td>3</td>
#       <td>6227352.00</td>
#       <td>75.13 м</td>
#       <td>I кв. 2023</td>
#       <td>Улучшенная предчистовая</td>
#       <td>0</td>
#       <td>Чистовая «Стандарт»</td>
#       <td>0</td>
#       <td>Чистовая «Комфорт»</td>
#       <td>0</td>
#       <td>Чистовая «Комфорт +»</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>862 rows × 16 columns</p>
# </div>

# %%
df.tail()
# Out:
#         id           num                 plan          kvartal zzflat  \
# 568  13346  Квартира 160   Планировка Тип 228  ReForma Optimum      2
# 569  13347  Квартира 161   Планировка Тип 221  ReForma Optimum      2
# 570  13349  Квартира 163  Планировка Тип 221з  ReForma Optimum      2
# 571  13350  Квартира 164  Планировка Тип 228з  ReForma Optimum      2
# 572  13351  Квартира 165  Планировка Тип 128з  ReForma Optimum      1
#
#         zzprice      zzm       zzsrok                zzotname1 zzotprice1  \
# 568  4753890.00  61.78 м  IV кв. 2024  Улучшенная предчистовая          0
# 569  4133367.00   53.7 м  IV кв. 2024  Улучшенная предчистовая          0
# 570  4133367.00   53.7 м  IV кв. 2024  Улучшенная предчистовая          0
# 571  4753890.00  61.78 м  IV кв. 2024  Улучшенная предчистовая          0
# 572  2957192.00  37.32 м  IV кв. 2024  Улучшенная предчистовая          0
#
#                zzotname2 zzotprice2           zzotname3 zzotprice3  \
# 568  Чистовая «Стандарт»     746000  Чистовая «Комфорт»     869000
# 569  Чистовая «Стандарт»     648000  Чистовая «Комфорт»     756000
# 570  Чистовая «Стандарт»     648000  Чистовая «Комфорт»     756000
# 571  Чистовая «Стандарт»     746000  Чистовая «Комфорт»     869000
# 572  Чистовая «Стандарт»     451000  Чистовая «Комфорт»     525000
#
#                 zzotname4 zzotprice4
# 568  Чистовая «Комфорт +»     928000
# 569  Чистовая «Комфорт +»     806000
# 570  Чистовая «Комфорт +»     806000
# 571  Чистовая «Комфорт +»     928000
# 572  Чистовая «Комфорт +»     560000

# %%
df
# Out:
#         id          num                 plan        kvartal  zzflat  \
# 0    12010  Квартира 85  Планировка Тип 330з  Перспективный       3
# 1    12038  Квартира 61  Планировка Тип 330з  Перспективный       3
# 2    12055  Квартира 30   Планировка Тип 013  Перспективный  Студия
# 3    12061  Квартира 36   Планировка Тип 013  Перспективный  Студия
# 4    12081   Квартира 2   Планировка Тип 331  Перспективный       3
# ..     ...          ...                  ...            ...     ...
# 152  12645  Квартира 84   Планировка Тип 157       Семейный       1
# 153  12647  Квартира 86  Планировка Тип 009з       Семейный  Студия
# 154  12655  Квартира 94  Планировка Тип 009з       Семейный  Студия
# 155  12656  Квартира 95   Планировка Тип 335       Семейный       3
# 156  12657  Квартира 96   Планировка Тип 273       Семейный       2
#
#         zzprice      zzm       zzsrok                zzotname1 zzotprice1  \
# 0    6359155.00  75.13 м   I кв. 2023  Улучшенная предчистовая          0
# 1    6007681.00  75.13 м   I кв. 2023  Улучшенная предчистовая          0
# 2    3061272.00  34.42 м   I кв. 2023  Улучшенная предчистовая          0
# 3    3020221.00  34.42 м   I кв. 2023  Улучшенная предчистовая          0
# 4    6784697.00  84.86 м   I кв. 2023  Улучшенная предчистовая          0
# ..          ...      ...          ...                      ...        ...
# 152  3705676.00  41.66 м  IV кв. 2023  Улучшенная предчистовая          0
# 153  2913897.00  32.74 м  IV кв. 2023  Улучшенная предчистовая          0
# 154  2913897.00  32.74 м  IV кв. 2023  Улучшенная предчистовая          0
# 155  6349502.00  75.83 м  IV кв. 2023  Улучшенная предчистовая          0
# 156  4493310.00  51.88 м  IV кв. 2023  Улучшенная предчистовая          0
#
#                zzotname2 zzotprice2           zzotname3 zzotprice3  \
# 0    Чистовая «Стандарт»          0  Чистовая «Комфорт»          0
# 1    Чистовая «Стандарт»          0  Чистовая «Комфорт»          0
# 2    Чистовая «Стандарт»          0  Чистовая «Комфорт»          0
# 3    Чистовая «Стандарт»          0  Чистовая «Комфорт»          0
# 4    Чистовая «Стандарт»          0  Чистовая «Комфорт»          0
# ..                   ...        ...                 ...        ...
# 152  Чистовая «Стандарт»     503000  Чистовая «Комфорт»     586000
# 153  Чистовая «Стандарт»     395000  Чистовая «Комфорт»     461000
# 154  Чистовая «Стандарт»     395000  Чистовая «Комфорт»     461000
# 155  Чистовая «Стандарт»     916000  Чистовая «Комфорт»    1067000
# 156  Чистовая «Стандарт»     626000  Чистовая «Комфорт»     730000
#
#                 zzotname4 zzotprice4
# 0    Чистовая «Комфорт +»          0
# 1    Чистовая «Комфорт +»          0
# 2    Чистовая «Комфорт +»          0
# 3    Чистовая «Комфорт +»          0
# 4    Чистовая «Комфорт +»          0
# ..                    ...        ...
# 152  Чистовая «Комфорт +»     626000
# 153  Чистовая «Комфорт +»     492000
# 154  Чистовая «Комфорт +»     492000
# 155  Чистовая «Комфорт +»    1139000
# 156  Чистовая «Комфорт +»     779000
#
# [157 rows x 16 columns]

# %%
response
# Out:
# <Response [200]>

# %%
zzprice
# Out:
# '2428229.00'

# %%
qq=html_to_json.convert(response.text)

# %%
ww=pd.json_normalize(qq)

# %%
ww
# Out:
#                                                 html  \
# 0  [{'_attributes': {'lang': 'ru'}, 'head': [{'me...
#
#                                              _values  \
# 0  [html, Rating Mail.ru counter, //Rating Mail.r...
#
#                                               script  \
# 0  [{'_attributes': {'type': 'text/javascript'}, ...
#
#                                             noscript  \
# 0  [{'div': [{'img': [{'_attributes': {'src': 'ht...
#
#                                                  div  \
# 0  [{'_attributes': {'class': ['Preloader', 'Prel...
#
#                                               header  \
# 0  [{'_attributes': {'class': ['Header']}, 'div':...
#
#                                               button
# 0  [{'_attributes': {'class': ['ToUp'], 'data-to-...

# %%
zz=pd.DataFrame(ww._values[0][4][3].items())

# %%
zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][1]['div'][1]['div'][0]['_attributes']['data-flat-id']
# Out:
# '12740'

# %%
zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][1]['div'][0]['_value']
# Out:
# 'Квартира 104'

# %%
zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][0]['a'][0]['_value']
# Out:
# 'Планировка Тип 004'

# %%
zz[1][1][0]['div'][0]['div'][0]['h1'][0]['div'][2]['a'][0]['_value']
# Out:
# 'Семейный'

# %%
zz=pd.DataFrame(zz[1][1][0].items())

# %%
zz=pd.DataFrame(zz[1][2][0].items())

# %%
zz=pd.DataFrame(zz[1][1][0].items())

# %%
zz=pd.DataFrame(zz[1][2][1].items())

# %%
zz=pd.DataFrame(zz[1][1][1].items())

# %%
zz=pd.DataFrame(zz[1][1][0].items())

# %%
zzprice=zz[1][1][1]['_attributes']['value']

# %%
zzprice
# Out:
# '2428229.00'

# %%
zzm=zz[1][2][0]['div'][1]['div'][2]['_value']

# %%
zzm
# Out:
# '26.24 м'

# %%
zzflat=zz[1][2][0]['div'][0]['div'][2]['_value']
# Out:
# 'Студия'

# %%
zzsrok=zz[1][2][0]['div'][2]['div'][2]['_value']

# %%
zz[1][2][2]['div'][2]['div'][0]['input'][0]['_attributes']['data-flat-finish']
zz[1][2][2]['div'][2]['div'][0]['input'][0]['_attributes']['value']
# Out:
# '317000'

# %%
zz[1][2][2]['div'][1]['div'][0]['input'][0]['_attributes']['data-flat-finish']
zz[1][2][2]['div'][1]['div'][0]['input'][0]['_attributes']['value']
# Out:
# {'class': ['FlatFinishItem_input'],
#  'type': 'radio',
#  'name': 'flat_finish',
#  'id': 'finish_1',
#  'checked': 'checked',
#  'value': '0',
#  'data-flat-finish': 'Улучшенная предчистовая',
#  'data-flat-finish-name': 'prefinishing'}

# %%
zz[1][2][2]['div'][3]['div'][0]['input'][0]['_attributes']['data-flat-finish']
zz[1][2][2]['div'][3]['div'][0]['input'][0]['_attributes']['value']
# Out:
# '369000'

# %%
zz[1][2][2]['div'][4]['div'][0]['input'][0]['_attributes']['data-flat-finish']
zz[1][2][2]['div'][4]['div'][0]['input'][0]['_attributes']['value']
# Out:
# '394000'

# %%
https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos=12

# %%
url_doc_list ='https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos=24'
response = requests.get(url_doc_list)
qq=html_to_json.convert(response.text)
ww=pd.json_normalize(qq)

# %%
url_doc_list ='https://www.amond.ru/kvartiry/search/'
response = requests.get(url_doc_list)
qq=html_to_json.convert(response.text)
ww=pd.json_normalize(qq)

# %%
from ast import Pass
dfamond=pd.DataFrame()
i=0
while i<=36:
 url_doc_list ='https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos='+str(i)
 print(url_doc_list)
 response = requests.get(url_doc_list)
 qq=html_to_json.convert(response.text)
 ww=pd.json_normalize(qq)
 j=0
# if len(ww)>1:
 try:
   len(ww['div'][0])
   while j<len(ww['div'][0]):
    id=ww['div'][0][j]['_attributes']['rel'] + ' '+ww['div'][0][0]['_attributes']['data-comp']
    name=ww['div'][0][j]['div'][0]['p'][0]['a'][0]['_value']
    kvartal=ww['div'][0][j]['div'][1]['table'][0]['tr'][0]['td'][0]['p'][0]['_value']+' '+ww['div'][0][0]['div'][1]['table'][0]['tr'][0]['td'][0]['p'][1]['_value']
    dom=ww['div'][0][j]['div'][1]['table'][0]['tr'][0]['td'][1]['p'][0]['_value'] +' '+ww['div'][0][0]['div'][1]['table'][0]['tr'][0]['td'][1]['p'][1]['_value']
    sek=ww['div'][0][j]['div'][1]['table'][0]['tr'][0]['td'][2]['p'][0]['_value'] +' '+ww['div'][0][0]['div'][1]['table'][0]['tr'][0]['td'][2]['p'][1]['_value']
    etaz=ww['div'][0][j]['div'][1]['table'][0]['tr'][0]['td'][3]['p'][0]['_value']+' '+ww['div'][0][0]['div'][1]['table'][0]['tr'][0]['td'][3]['p'][1]['_value']
    srok=ww['div'][0][j]['div'][3]['strong'][0]['_value']
    otdelka=ww['div'][0][j]['div'][4]['strong'][0]['_value']
    flat=ww['div'][0][j]['div'][5]['strong'][0]['_value']
    num=ww['div'][0][j]['div'][2]['p'][0]['_value']
    sq=ww['div'][0][j]['div'][2]['p'][1]['_value']
    pr_m=ww['div'][0][j]['div'][2]['p'][2]['_value'].replace('<span class="ruble">','').replace('</span>/м<sup>2</sup>','')
    price=ww['div'][0][j]['div'][2]['p'][2]['strong'][0]['_value']
    new_row = {'id':id, 'name':name,'kvartal':kvartal,'dom':dom,'sek':sek,'etaz':etaz,'srok':srok,'otdelka':otdelka,'flat':flat,'num':num,'sq':sq,'pr_m':pr_m,'price':price}  
    dfamond=dfamond.append(new_row, ignore_index=True)
    j=j+1
 except KeyError:
  Pass 
# time.sleep(4)
 i=i+12
# Out:
# https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos=0
# https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos=12
# https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos=24
# https://www.amond.ru/kvartiry/search/?template=15&cur_cc=363&curPos=36

# %%
dfamond
# Out:
#            id                   name     kvartal    dom       sek     etaz  \
# 0   3654 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 1   3570 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 2   3625 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 3   3626 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 4   3628 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 5   3629 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 6   3630 2066  Жилой район «Волгарь»  Квартал 12  Дом 6  Секция 1   Этаж 3
# 7     4 кв. 2023г  Черновая  Однокомнатная квартира   1   44,72м  83 000 р.
# 8     4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  76 500 р.
# 9     4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  76 500 р.
# 10    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  77 500 р.
# 11    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  77 500 р.
# 12    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  77 500 р.
# 13    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  77 500 р.
# 14    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   59,31м  77 500 р.
# 15    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  75 000 р.
# 16    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  75 000 р.
# 17    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  75 000 р.
# 18    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  76 000 р.
# 19    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  76 000 р.
# 20    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  76 000 р.
# 21    4 кв. 2023г  Черновая  Двухкомнатная квартира   2   60,75м  76 000 р.
# 22  2 кв. 2023 г.  Черновая  Двухкомнатная квартира   2   67,21м  74 000 р.
# 23  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  103,58м  63 000 р.
# 24  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,15м  62 000 р.
# 25  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,15м  63 000 р.
# 26  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,52м  61 000 р.
# 27  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,52м  61 000 р.
# 28  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,87м  60 000 р.
# 29  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,87м  60 000 р.
# 30  2 кв. 2023 г.  Черновая  Трехкомнатная квартира   3  108,87м  61 000 р.
#
#         price
# 0   3 272 720
# 1   3 711 760
# 2   3 711 760
# 3   3 711 760
# 4   3 711 760
# 5   3 711 760
# 6   3 711 760
# 7   3 711 760
# 8   4 537 215
# 9   4 537 215
# 10  4 596 525
# 11  4 596 525
# 12  4 596 525
# 13  4 596 525
# 14  4 596 525
# 15  4 556 250
# 16  4 556 250
# 17  4 556 250
# 18  4 617 000
# 19  4 617 000
# 20  4 617 000
# 21  4 617 000
# 22  4 973 540
# 23  6 525 540
# 24  6 705 300
# 25  6 813 450
# 26  6 619 720
# 27  6 619 720
# 28  6 532 200
# 29  6 532 200
# 30  6 641 070

# %%
data_table.DataTable.max_columns = 103
data_table.DataTable(dfamond, include_index=False, num_rows_per_page=1500)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>name</th>
#       <th>kvartal</th>
#       <th>dom</th>
#       <th>sek</th>
#       <th>etaz</th>
#       <th>srok</th>
#       <th>otdelka</th>
#       <th>flat</th>
#       <th>num</th>
#       <th>sq</th>
#       <th>pr_m</th>
#       <th>price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td
td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>3528 2066</td>
#       <td>Жилой район «Волгарь»</td>
#       <td>Квартал 12</td>
#       <td>Дом 6</td>
#       <td>Секция 1</td>
#       <td>Этаж 22</td>
#       <td>4 кв. 2023г</td>
#       <td>Черновая</td>
#       <td>Двухкомнатная квартира</td>
#       <td>2</td>
#       <td>60,75м</td>
#       <td>75 000 р.</td>
#       <td>4 556 250</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>3661 2066</td>
#       <td>Жилой район «Волгарь»</td>
#       <td>Квартал 12</td>
#       <td>Дом 6</td>
#       <td>Секция 1</td>
#       <td>Этаж 22</td>
#       <td>4 кв. 2023г</td>
#       <td>Черновая</td>
#       <td>Двухкомнатная квартира</td>
#       <td>2</td>
#       <td>60,75м</td>
#       <td>75 000 р.</td>
#       <td>4 556 250</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>3550 2066</td>
#       <td>Жилой район «Волгарь»</td>
#       <td>Квартал 12</td>
#       <td>Дом 6</td>
#       <td>Секция 1</td>
#       <td>Этаж 22</td>
#       <td>4 кв. 2023г</td>
#       <td>Черновая</td>
#       <td>Двухкомнатная квартира</td>
#       <td>2</td>
#       <td>60,75м</td>
#       <td>76 000 р.</td>
#       <td>4 617 000</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>3565 2066</td>
#       <td>Жилой район «Волгарь»</td>
#       <td>Квартал 12</td>
#       <td>Дом 6</td>
#       <td>Секция 1</td>
#       <td>Этаж 22</td>
#       <td>4 кв. 2023г</td>
#       <td>Черновая</td>
#       <td>Двухкомнатная квартира</td>
#       <td>2</td>
#       <td>60,75м</td>
#       <td>76 000 р.</td>
#       <td>4

# %%
dfkosh=pd.DataFrame()

# %%
dfkosh
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
i=100
while i<=2000:
  url_doc_list = 'https://koshelev-proekt.ru/zhilye-kompleksy/flat/'+str(i) 
 # print(url_doc_list)
  response = requests.get(url_doc_list)
 # print(response)
  if str(response)=='<Response [200]>':
 #  print(str(i))
   qq=html_to_json.convert(response.text)
   ww=pd.json_normalize(qq)
   if len(ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][0]['_value'])>4:
    dom=     ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][0]['_value']
    kvartira=ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][1]['_value']
    otdelka= ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][2]['_value']
    try:
     srok=    ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][4]['_value']
    except IndexError:
     srok=    ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][3]['_value']
    numroom= ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][0]['div'][1]['_value']
    area=    ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][0]['div'][3]['_value']
    try:
      price=   ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][2]['_value']
    except KeyError:
      price=ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][2]['div'][1]['_value']
    new_row = {'id':i,'dom':dom, 'kvartira':kvartira, 'otdelka':otdelka,'srok':srok,'numroom':numroom,'area':area,'price':price}  
    dfkosh=dfkosh.append(new_row, ignore_index=True)
  time.sleep(2)
  i=i+1

# %%
data_table.DataTable.max_columns = 103
data_table.DataTable(dfkosh, include_index=False, num_rows_per_page=1500)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th
#       <td>1-комн. 36.20 м</td>
#       <td>Предчистовая отделка</td>
#       <td>Срок сдачи IV Квартал 2023</td>
#       <td>1</td>
#       <td>36.20 м</td>
#       <td>2 629 000 ₽</td>
#     </tr>
#     <tr>
#       <th>620</th>
#       <td>1811.0</td>
#       <td>Жилой комплекс «Видный-2» / Дом № 8</td>
#       <td>3-комн. 95.30 м</td>
#       <td>Предчистовая отделка</td>
#       <td>Срок сдачи IV Квартал 2023</td>
#       <td>3</td>
#       <td>95.30 м</td>
#       <td>6 941 000 ₽</td>
#     </tr>
#   </tbody>
# </table>
# <p>621 rows × 8 columns</p>
# </div>

# %%
dfkosh
# Out:
#          id                                   dom         kvartira  \
# 0     102.0  Жилой комплекс «Видный-2» / Дом № 13  3-комн. 71.20 м
# 1     103.0  Жилой комплекс «Видный-2» / Дом № 13  3-комн. 71.20 м
# 2     104.0  Жилой комплекс «Видный-2» / Дом № 13  3-комн. 71.20 м
# 3     115.0  Жилой комплекс «Видный-2» / Дом № 13  3-комн. 71.20 м
# 4     216.0   Жилой комплекс «Видный-2» / Дом № 5  3-комн. 71.20 м
# ..      ...                                   ...              ...
# 616  1807.0   Жилой комплекс «Видный-2» / Дом № 8  1-комн. 40.60 м
# 617  1808.0   Жилой комплекс «Видный-2» / Дом № 8  2-комн. 75.60 м
# 618  1809.0   Жилой комплекс «Видный-2» / Дом № 8  2-комн. 50.50 м
# 619  1810.0   Жилой комплекс «Видный-2» / Дом № 8  1-комн. 36.20 м
# 620  1811.0   Жилой комплекс «Видный-2» / Дом № 8  3-комн. 95.30 м
#
#                       otdelka                        srok numroom     area  \
# 0       Чистовая Люкс отделка  Срок сдачи II Квартал 2023       3  71.20 м
# 1       Чистовая Люкс отделка  Срок сдачи II Квартал 2023       3  71.20 м
# 2       Чистовая Люкс отделка  Срок сдачи II Квартал 2023       3  71.20 м
# 3       Чистовая Люкс отделка  Срок сдачи II Квартал 2023       3  71.20 м
# 4    Чистовая отделка Комфорт  Срок сдачи II Квартал 2023       3  71.20 м
# ..                        ...                         ...     ...      ...
# 616      Предчистовая отделка  Срок сдачи IV Квартал 2023       1  40.60 м
# 617      Предчистовая отделка  Срок сдачи IV Квартал 2023       2  75.60 м
# 618      Предчистовая отделка  Срок сдачи IV Квартал 2023       2  50.50 м
# 619      Предчистовая отделка  Срок сдачи IV Квартал 2023       1  36.20 м
# 620      Предчистовая отделка  Срок сдачи IV Квартал 2023       3  95.30 м
#
#            price
# 0    5 880 000 ₽
# 1    5 880 000 ₽
# 2    5 880 000 ₽
# 3    5 880 000 ₽
# 4    5 690 000 ₽
# ..           ...
# 616  2 940 000 ₽
# 617  5 513 000 ₽
# 618  3 692 000 ₽
# 619  2 629 000 ₽
# 620  6 941 000 ₽
#
# [621 rows x 8 columns]

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][3]
# Out:
# {'_attributes': {'class': ['fl-year', 'f13']},
#  '_value': 'Срок сдачи III Квартал 2022'}

# %%
# 31      Предчистовая отделка  Срок сдачи III Квартал 2022       1  37.00 м
# 32      Предчистовая отделка  Срок сдачи III Квартал 2022       1  37.00 м
# 33      Предчистовая отделка  Срок сдачи III Квартал 2022       2  47.30 м
# 34          Полулюкс отделка  Срок сдачи III Квартал 2022       1  43.10 м
# 35          Полулюкс отделка  Срок сдачи III Квартал 2022       1  43.10 м
# 36          Полулюкс отделка  Срок сдачи III Квартал 2022       1  43.10 м
# 37          Полулюкс отделка  Срок сдачи III Квартал 2022       1  43.10 м
# 38          Полулюкс отделка  Срок сдачи III Квартал 2022       1  43.10 м
# 39          Полулюкс отделка  Срок сдачи III Квартал 2022       1  43.10 м
# 40     Чистовая Люкс отделка  Срок сдачи III Квартал 2022       2  49.50 м
# 41     Чистовая Люкс отделка  Срок сдачи III Квартал 2022       2  49.50 м
#
#           price
# 0   5 880 000 ₽
# 1   5 880 000 ₽
# 2   5 880 000 ₽
# 3   5 880 000 ₽
# 4   5 690 000 ₽
# 5   3 435 000 ₽
# 6   3 435 000 ₽
# 7   3 435 000 ₽
# 8   3 435 000 ₽
# 9   3 435 000 ₽
# 10  3 435 000 ₽
# 11  4 130 000 ₽
# 12  3 435 000 ₽
# 13  4 541 000 ₽
# 14  4 541 000 ₽
# 15  4 789 000 ₽
# 16  4 408 000 ₽
# 17  4 408 000 ₽
# 18  4 408 000 ₽
# 19  3 445 000 ₽
# 20  3 414 000 ₽
# 21  4 395 000 ₽
# 22  3 445 000 ₽
# 23  4 475 000 ₽
# 24  3 445 000 ₽
# 25  4 969 000 ₽
# 26  3 445 000 ₽
# 27  4 969 000 ₽
# 28  3 445 000 ₽
# 29  4 408 000 ₽
# 30  4 969 000 ₽
# 31  3 445 000 ₽
# 32  3 445 000 ₽
# 33  4 408 000 ₽
# 34  4 390 000 ₽
# 35  4 390 000 ₽
# 36  4 390 000 ₽
# 37  4 390 000 ₽
# 38  4 390 000 ₽
# 39  4 390 000 ₽
# 40  4 986 000 ₽
# 41  4 986 000 ₽

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div']
# Out:
# [{'_attributes': {'class': ['flat-left']},
#   'div': [{'_attributes': {'class': ['flat-main', 'fl-desc']},
#     'div': [{'_attributes': {'class': ['fl-nav', 'f13']}, '_value': '«» /'},
#      {'_attributes': {'class': ['fl-name', 'h32']},
#       '_value': '-комн.  м',
#       'sup': [{'_value': '2'}]},
#      {'_attributes': {'class': ['fl-type', 'tipsted', 'f13'], 'data-link': ''},
#       'i': [{'_attributes': {'class': ['fas', 'fa-camera']}}]},
#      {'_attributes': {'class': ['fl-year', 'f13']}, '_value': 'Срок сдачи'}]},
#    {'_attributes': {'class': ['flat-plan']},
#     'img': [{'_attributes': {'src': ''}}]}]},
#  {'_attributes': {'class': ['flat-right']},
#   'div': [{'_attributes': {'class': ['fl-table']},
#     'div': [{'_attributes': {'class': ['fl-drow-l', 'fl-drow-first']},
#       '_value': 'Комнат'},
#      {'_attributes': {'class': ['fl-drow-r', 'fl-drow-first']}},
#      {'_attributes': {'class': ['fl-drow-l']}, '_value': 'Общая площадь'},
#      {'_attributes': {'class': ['fl-drow-r']},
#       '_value': 'м',
#       'sup': [{'_value': '2'}]},
#      {'_attributes': {'class': ['fl-drow-l']}, '_value': 'Жилая площадь'},
#      {'_attributes': {'class': ['fl-drow-r']},
#       '_value': 'м',
#       'sup': [{'_value': '2'}]},
#      {'_attributes': {'class': ['fl-drow-l']}, '_value': 'Площадь кухни'},
#      {'_attributes': {'class': ['fl-drow-r']},
#       '_value': 'м',
#       'sup': [{'_value': '2'}]},
#      {'_attributes': {'class': ['fl-drow-l']}, '_value': 'Этаж'},
#      {'_attributes': {'class': ['fl-drow-r']}}]},
#    {'_attributes': {'class': ['fl-prpr', 'f13']}, '_value': 'Цена'},
#    {'_attributes': {'class': ['fl-price', 'h32']}, '_value': '₽'},
#    {'_attributes': {'class': ['fl-book', 'h16']},
#     'a': [{'_attributes': {'data-form': 'book'},
#       '_value': 'Забронировать'}]}]}]

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][0]['_value']
# Out:
# '«» /'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][1]['_value']
# Out:
# '2-комн. 50.50 м'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][2]['_value']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-e29371f2c7ad> in <module>
# ----> 1 ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][2]['_value']
#
# KeyError: '_value'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][0]['div'][0]['div'][4]['_value']
# Out:
# 'Срок сдачи IV Квартал 2023'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][0]['div'][1]['_value']
# Out:
# '2'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][0]['div'][3]['_value']
# Out:
# '50.50 м'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][0]['div'][5]['_value']
# Out:
# '30.60 м'

# %%
ww.html[0][0]['body'][0]['div'][2]['div'][0]['div'][1]['div'][2]['_value']
# Out:
# '3 443 000 ₽'

# %%
  df = pd.json_normalize(objects_list)
  dffull=df

# %%
df=df.drop(df.index)
dffull=df.drop(dffull.index)

# %%
df=pd.DataFrame()
dffull=pd.DataFrame()

# %%
#Новая Самара дома
documents = []
#url_doc_list = 'https://pb11955.profitbase.ru/api/v4/json/property?access_token=8c0b7e5c0d250eb774cbbde41749cfed5f304ab5ab71c18cbaebb0be51fe34ba&houseId=96354'
url_doc_list ='https://pb11955.profitbase.ru/api/v4/json/house?access_token=cdf1e4b56ac17776e1f61e6fe70f2b9b56f681b9bc7a2a335c01f4de0e67935a'
#url_doc_list ='https://pb11955.profitbase.ru/api/v4/json/house?access_token=8c0b7e5c0d250eb774cbbde41749cfed5f304ab5ab71c18cbaebb0be51fe34ba'
response = requests.get(url_doc_list)
documents = response.json()
documents = documents['data']
dfhouses = pd.json_normalize(documents)

# %%
dfhouses['developmentEndQuarter.year']
# Out:
# 0    2023
# 1    2023
# 2    2023
# 3    2023
# 4    2022
# 5    2022
# 6    2022
# 7    2023
# 8    2023
# Name: developmentEndQuarter.year, dtype: object

# %%
dfhouses['developmentEndQuarter.quarter']
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    3
# 5    4
# 6    4
# 7    3
# 8    3
# Name: developmentEndQuarter.quarter, dtype: int64

# %%
data_table.DataTable.max_columns = 103
data_table.DataTable(dfhouses, include_index=False, num_rows_per_page=1500)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>projectId</th>
#       <th>projectName</th>
#       <th>title</th>
#       <th>type</th>
#       <th>street</th>
#       <th>number</th>
#       <th>facing</th>
#       <th>material</th>
#       <th>buildingState</th>
#       <th>...</th>
#       <th>currency.shortName</th>
#       <th>currency.unicodeSymbol</th>
#       <th>address.full</th>
#       <th>address.locality</th>
#       <th>address.district</th>
#       <th>address.region</th>
#       <th>address.street</th>
#       <th>address.number</th>
#       <th>developmentStartQuarter.year</th>
#       <th>developmentStartQuarter.quarter</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>97978</td>
#       <td>33148</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>Дом 10</td>
#       <td>RESIDENTIAL</td>
#       <td>1 квартал</td>
#       <td>10</td>
#       <td>Черновая</td>
#       <td>Кирпичный</td>
#       <td>None</td>
#       <td>...</td>
#       <td>руб</td>
#       <td>8381</td>
#       <td>Самара, п.Мехзавод, Красноглинский, Самарская ...</td>
#       <td>Самара, п.Мехзавод</td>
#       <td>Красноглинский</td>
#       <td>Самарская область</td>
#       <td>1 квартал</td>
#       <td>10</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>97429</td>
#       <td>33148</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>Дом 7</td>
#       <td>RESIDENTIAL</td>
#       <td>1 квартал</td>
#       <td>7</td>
#       <td>Черновая</td>
#       <td>Кирпичный</td>
#       <td>None</td>
#       <td>...</td>
#       <td>руб</td>
#       <td>8381</td>
#       <td>Самара, п.Мехзавод, Красноглинский, Самарская ...</td>
#       <td>Самара, п.Мехзавод</td>
#       <td>Красноглинский</td>
#       <td>Самарская область</td>
#       <td>1 квартал</td>
#       <td>7</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>96354</td>
#       <td>33148</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>Дом 9</td>
#       <td>RESIDENTIAL</td>
#       <td>1 квартал</td>
#       <td>9</td>
#       <td>Черновая</td>
#       <td>Кирпичный</td>
#       <td>None</td>
#       <td>...</td>
#       <td>руб</td>
#       <td>8381</td>
#       <td>Самара, п.Мехзавод, Красноглинский, Самарская ...</td>
#       <td>Самара, п.Мехзавод</td>
#       <td>Красноглинский</td>
#       <td>Самарская область</td>
#       <td>1 квартал</td>
#       <td>9</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>95772</td>
#       <td>33148</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>Дом 8</td>
#       <td>RESIDENTIAL</td>
#       <td>1 квартал</td>
#       <td>8</td>
#       <td>Черновая</td>
#       <td>Кирпичный</td>
#       <td>None</td>
#       <td>...</td>
#       <td>руб</td>
#       <td>8381</td>
#       <td>Самара, п.Мехзавод, Красноглинский, Самарская ...</td>
#       <td>Самара, п.Мехзавод</td>
#       <td>Красноглинский</td>
#       <td>Самарская область</td>
#       <td>1 квартал</td>
#       <td>8</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td
# 5           None                         2021                             1.0
# 6           None                         2021                             2.0
# 7             53                          NaN                             NaN
# 8             54                          NaN                             NaN
#
# [9 rows x 47 columns]

# %%
#Новая Самара квартиры
i=0
df=pd.DataFrame()
dffull=pd.DataFrame()
while i<len(dfhouses):
 documents = []
 url_doc_list = 'https://pb11955.profitbase.ru/api/v4/json/property?access_token=cdf1e4b56ac17776e1f61e6fe70f2b9b56f681b9bc7a2a335c01f4de0e67935a&houseId='+str(dfhouses.id[i])
 response = requests.get(url_doc_list)
 documents = response.json()
 documents = documents['data']
 df = pd.json_normalize(documents)
 dffull=pd.concat([dffull,df],ignore_index=True)
 i=i+1

# %%
documents = response.json()

# %%
documents.keys()
# Out:
# dict_keys(['status', 'data'])

# %%
#https://pb11955.profitbase.ru/api/v4/json/property-types?access_token=cdf1e4b56ac17776e1f61e6fe70f2b9b56f681b9bc7a2a335c01f4de0e67935a
documents = []
url_doc_list = 'https://pb11955.profitbase.ru/api/v4/json/property-types?access_token=cdf1e4b56ac17776e1f61e6fe70f2b9b56f681b9bc7a2a335c01f4de0e67935a&houseId=104542'
response = requests.get(url_doc_list)
documents = response.json()
documents = documents['data']
df = pd.json_normalize(documents)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-16e87f46620c> in <module>
#       4 response = requests.get(url_doc_list)
#       5 documents = response.json()
# ----> 6 documents = documents['data']
#       7 df = pd.json_normalize(documents)
#
# TypeError: list indices must be integers or slices, not str

# %%
documents[0]#['id'=='11106275']
# Out:
# {'id': 94584,
#  'alias': 'property',
#  'name': 'Квартира',
#  'typePurpose': 'residential',
#  'customFields': [{'id': 452173,
#    'key': 'pbcf_60e687afcb233',
#    'name': 'icon Кухня-гостиная',
#    'rank': 34,
#    'type': 'text',
#    'specificationName': 'kitchen-living-room'},
#   {'id': 452174,
#    'key': 'pbcf_60e68d55c6cf3',
#    'name': 'icon Большая прихожая',
#    'rank': 35,
#    'type': 'text',
#    'specificationName': 'large-hallway'},
#   {'id': 452175,
#    'key': 'pbcf_60e68d7e09771',
#    'name': 'icon Панорамное остекление',
#    'rank': 36,
#    'type': 'text',
#    'specificationName': 'panoramic-glazing'},
#   {'id': 452176,
#    'key': 'pbcf_60e68d9119d4d',
#    'name': 'icon Разнесенные спальни',
#    'rank': 37,
#    'type': 'text',
#    'specificationName': 'separated-bedrooms'},
#   {'id': 452177,
#    'key': 'pbcf_60e68da7add82',
#    'name': 'icon Мастер-спальня',
#    'rank': 38,
#    'type': 'text',
#    'specificationName': 'master-bedroom'},
#   {'id': 452178,
#    'key': 'pbcf_60e68dc543eed',
#    'name': 'icon Торцевая (на 3 стороны)',
#    'rank': 39,
#    'type': 'text',
#    'specificationName': 'face'},
#   {'id': 452179,
#    'key': 'pbcf_60e68ddae901c',
#    'name': 'icon Угловая (Угловая ориентация комнат)',
#    'rank': 40,
#    'type': 'text',
#    'specificationName': 'corner'},
#   {'id': 452180,
#    'key': 'pbcf_60e68df5e22fd',
#    'name': 'icon Напротив лифта',
#    'rank': 41,
#    'type': 'text',
#    'specificationName': 'opposite-the-elevator'},
#   {'id': 452181,
#    'key': 'pbcf_60e68e0cd5c0e',
#    'name': 'icon Двухуровневая',
#    'rank': 42,
#    'type': 'text',
#    'specificationName': 'two-tier'},
#   {'id': 452182,
#    'key': 'pbcf_60e68e28188dc',
#    'name': 'icon Пентхаус',
#    'rank': 43,
#    'type': 'text',
#    'specificationName': 'penthouse'},
#   {'id': 452183,
#    'key': 'pbcf_60e68e43bc883',
#    'name': 'icon С готовым ремонтом',
#    'rank': 44,
#    'type': 'text',
#    'specificationName': 'finish-renovation'},
#   {'id': 452184,
#    'key': 'pbcf_60e68e5866173',
#    'name': 'icon Вид на парк',
#    'rank': 45,
#    'type': 'text',
#    'specificationName': 'park-view'},
#   {'id': 452185,
#    'key': 'pbcf_60e68e6a4651e',
#    'name': 'icon Окна на две стороны',
#    'rank': 46,
#    'type': 'text',
#    'specificationName': 'two-sides-windows'},
#   {'id': 452186,
#    'key': 'pbcf_60e68e79bf230',
#    'name': 'icon Вид на двор',
#    'rank': 47,
#    'type': 'text',
#    'specificationName': 'courtyard-view'},
#   {'id': 452187,
#    'key': 'pbcf_60e68e87da4a5',
#    'name': 'icon Солнечная сторона',
#    'rank': 48,
#    'type': 'text',
#    'specificationName': 'sunny-side'},
#   {'id': 452188,
#    'key': 'pbcf_60e68e9540106',
#    'name': 'icon Гардеробная',
#    'rank': 49,
#    'type': 'text',
#    'specificationName': 'wardrobe'},
#   {'id': 452189,
#    'key': 'pbcf_60e68ea4a0b00',
#    'name': 'icon Кладовка',
#    'rank': 50,
#    'type': 'text',
#    'specificationName': 'storeroom'},
#   {'id': 452190,
#    'key': 'pbcf_60e68f0456493',
#    'name': 'icon Лоджия',
#    'rank': 51,
#    'type': 'text',
#    'specificationName': 'loggia'},
#   {'id': 452191,
#    'key': 'pbcf_60e68f17675c8',
#    'name': 'icon Балкон',
#    'rank': 52,
#    'type': 'text',
#    'specificationName': 'balcony'},
#   {'id': 452192,
#    'key': 'pbcf_60e68f282d2d4',
#    'name': 'icon Теплая лоджия',
#    'rank': 53,
#    'type': 'text',
#    'specificationName': 'warm-loggia'},
#   {'id': 452193,
#    'key': 'pbcf_60e68f3af41e0',
#    'name': 'icon Терасса',
#    'rank': 54,
#    'type': 'text',
#    'specificationName': 'terrace'},
#   {'id': 452194,
#    'key': 'pbcf_60e68f4e04196',
#    'name': 'icon Постирочная',
#    'rank': 55,
#    'type': 'text',
#    'specificationName': 'Laundry'},
#   {'id': 452195,
#    'key': 'pbcf_60e68f630155e',
#    'name': 'icon Совмещенный санузел',
#    'rank': 56,
#    'type': 'text',
#    'specificationName': 'combined-bathroom'},
#   {'id': 452196,
#    'key': 'pbcf_60e68f71653e4',
#    'name': 'icon Второй санузел',
#    'rank': 57,
#    'type': 'text',
#    'specificationName': 'second-bathroom'},
#   {'id': 452197,
#    'key': 'pbcf_60e68f8fe24d9',
#    'name': 'icon Раздельный санузел',
#    'rank': 58,
#    'type': 'text',
#    'specificationName': 'separate-bathroom'},
#   {'id': 452413,
#    'key': 'pbcf_60e6e4505e155',
#    'name': 'Срок сдачи',
#    'rank': 59,
#    'type': 'text',
#    'specificationName': None}],
#  'systemFields': [{'id': 409441,
#    'key': 'property_price',
#    'name': 'Полная цена',
#    'rank': 3,
#    'type': 'price',
#    'specificationName': None},
#   {'id': 409442,
#    'key': 'description',
#    'name': 'Описание',
#    'rank': 4,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409445,
#    'key': 'owner',
#    'name': 'Владелец',
#    'rank': 7,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409449,
#    'key': 'house_name',
#    'name': 'Название дома',
#    'rank': 10,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409451,
#    'key': 'property_area',
#    'name': 'Площадь, м2',
#    'rank': 12,
#    'type': 'area',
#    'specificationName': None},
#   {'id': 409452,
#    'key': 'price_meter',
#    'name': 'Цена за метр',
#    'rank': 13,
#    'type': 'price',
#    'specificationName': None},
#   {'id': 409453,
#    'key': 'rooms',
#    'name': 'Кол-во комнат',
#    'rank': 14,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409454,
#    'key': 'position_on_floor',
#    'name': 'Номер на площадке',
#    'rank': 15,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409456,
#    'key': 'building_states',
#    'name': 'Стадия строительства',
#    'rank': 17,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409457,
#    'key': 'area_living',
#    'name': 'Жилая площадь, м2',
#    'rank': 18,
#    'type': 'area',
#    'specificationName': None},
#   {'id': 409458,
#    'key': 'area_kitchen',
#    'name': 'Площадь кухни, м2',
#    'rank': 19,
#    'type': 'area',
#    'specificationName': None},
#   {'id': 409459,
#    'key': 'area_estimated',
#    'name': 'Расчетная площадь, м2',
#    'rank': 20,
#    'type': 'area',
#    'specificationName': None},
#   {'id': 409460,
#    'key': 'window',
#    'name': 'Куда выходят окна',
#    'rank': 21,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409461,
#    'key': 'loggia_count',
#    'name': 'Кол-во лоджий',
#    'rank': 22,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409462,
#    'key': 'balcony_count',
#    'name': 'Кол-во балконов',
#    'rank': 23,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409463,
#    'key': 'combined_bathroom_count',
#    'name': 'Кол-во совмещенных санузлов',
#    'rank': 24,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409464,
#    'key': 'separated_bathroom_count',
#    'name': 'Кол-во раздельных санузлов',
#    'rank': 25,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409465,
#    'key': 'is_studio',
#    'name': 'Студия',
#    'rank': 26,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409466,
#    'key': 'is_free_layout',
#    'name': 'Свободная планировка',
#    'rank': 27,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409468,
#    'key': 'facing',
#    'name': 'Отделка',
#    'rank': 28,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409467,
#    'key': 'is_euro_layout',
#    'name': 'Европланировка',
#    'rank': 33,
#    'type': 'text',
#    'specificationName': None},
#   {'id': 409473,
#    'key': 'price_actual',
#    'name': 'Прайсовая цена',
#    'rank': 34,
#    'type': 'price',
#    'specificationName': None}],
#  'nameForms': {'plural': 'Квартиры',
#   'genitive': 'Квартиры',
#   'genitivePlural': 'Квартир',
#   'accusative': 'Квартиру',
#   'abbreviation': 'Кв'}}

# %%
 i=0
 while i<len(dffull):
   dffull['srok'][i]=str(dfhouses['id'==dffull['house_id'][i]]['developmentEndQuarter.year']) #+''+str(dfhouses['id'==i]['developmentEndQuarter.quarter'])
   i=i+1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-a3bf3099e42c> in <module>
#       1 i=0
#       2 while i<len(dffull):
# ----> 3   dffull['srok'][i]=str(dfhouses['id'==dffull['house_id'][i]]['developmentEndQuarter.year']) #+''+str(dfhouses['id'==i]['developmentEndQuarter.quarter'])
#       4   i=i+1
#       5
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
dffull.head()
# Out:
#         id  house_id houseName        projectName number  rooms_amount  floor  \
# 0  9990251   97978.0    Дом 10  ЖК "Новая Самара"      2           1.0    1.0
# 1  9990252   97978.0    Дом 10  ЖК "Новая Самара"      3           1.0    1.0
# 2  9990254   97978.0    Дом 10  ЖК "Новая Самара"      5           1.0    1.0
# 3  9990257   97978.0    Дом 10  ЖК "Новая Самара"      8           1.0    2.0
# 4  9990258   97978.0    Дом 10  ЖК "Новая Самара"      9           1.0    2.0
#
#   sectionName without_layout studio  ... specialOffersIds area.area_total  \
# 0           1           True  False  ...             None           41.19
# 1           1           True  False  ...             None           45.43
# 2           1           True  False  ...             None           39.23
# 3           1           True  False  ...             None           41.19
# 4           1           True  False  ...             None           45.43
#
#   area.area_estimated area.area_living area.area_kitchen area.area_balcony  \
# 0                None            31.19             10.00              None
# 1                None            36.43              9.00              None
# 2                None            30.12              9.11              None
# 3                None            31.19             10.00              None
# 4                None            36.43              9.00              None
#
#   area.area_without_balcony price.value  price.pricePerMeter  \
# 0                      None   3501150.0              85000.0
# 1                      None   3861550.0              85000.0
# 2                      None   3413010.0              87000.0
# 3                      None   3501150.0              85000.0
# 4                      None   3861550.0              85000.0
#
#                                                 srok
# 0  0    2023\n1    2023\n2    2023\n3    2023\n4 ...
# 1  0    2023\n1    2023\n2    2023\n3    2023\n4 ...
# 2  0    2023\n1    2023\n2    2023\n3    2023\n4 ...
# 3  0    2023\n1    2023\n2    2023\n3    2023\n4 ...
# 4  0    2023\n1    2023\n2    2023\n3    2023\n4 ...
#
# [5 rows x 29 columns]

# %%
dfhouses
# Out:
#        id  projectId        projectName      title         type     street  \
# 0   97978      33148  ЖК "Новая Самара"     Дом 10  RESIDENTIAL  1 квартал
# 1   97429      33148  ЖК "Новая Самара"      Дом 7  RESIDENTIAL  1 квартал
# 2   96354      33148  ЖК "Новая Самара"      Дом 9  RESIDENTIAL  1 квартал
# 3   95772      33148  ЖК "Новая Самара"      Дом 8  RESIDENTIAL  1 квартал
# 4   89332      33148  ЖК "Новая Самара"     Дом 67  RESIDENTIAL  1 квартал
# 5   91508      33148  ЖК "Новая Самара"     Дом 69  RESIDENTIAL  1 квартал
# 6   93808      33148  ЖК "Новая Самара"     Дом 73  RESIDENTIAL  1 квартал
# 7  104539      33148  ЖК "Новая Самара"  Секция 53  RESIDENTIAL  1 квартал
# 8  104542      33148  ЖК "Новая Самара"  Секция 54  RESIDENTIAL  1 квартал
#
#   number    facing   material buildingState  ...  currency.shortName  \
# 0     10  Черновая  Кирпичный          None  ...                 руб
# 1      7  Черновая  Кирпичный          None  ...                 руб
# 2      9  Черновая  Кирпичный          None  ...                 руб
# 3      8  Черновая  Кирпичный          None  ...                 руб
# 4     67  Черновая  Кирпичный    UNFINISHED  ...                 руб
# 5   None  Черновая  Кирпичный    UNFINISHED  ...                 руб
# 6   None  Черновая  Кирпичный    UNFINISHED  ...                 руб
# 7     53  Черновая  Кирпичный    UNFINISHED  ...                 руб
# 8     54  Черновая  Кирпичный    UNFINISHED  ...                 руб
#
#   currency.unicodeSymbol                                       address.full  \
# 0                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 1                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 2                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 3                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 4                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 5                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 6                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 7                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
# 8                   8381  Самара, п.Мехзавод, Красноглинский, Самарская ...
#
#      address.locality address.district     address.region  address.street  \
# 0  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 1  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 2  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 3  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 4  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 5  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 6  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 7  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
# 8  Самара, п.Мехзавод   Красноглинский  Самарская область       1 квартал
#
#   address.number developmentStartQuarter.year developmentStartQuarter.quarter
# 0             10                          NaN                             NaN
# 1              7                          NaN                             NaN
# 2              9                          NaN                             NaN
# 3              8                          NaN                             NaN
# 4             67                         2020                             4.0
# 5           None                         2021                             1.0
# 6           None                         2021                             2.0
# 7             53                          NaN                             NaN
# 8             54                          NaN                             NaN
#
# [9 rows x 47 columns]

# %%
from google.colab import data_table

# %%
data_table.DataTable.max_columns = 103
data_table.DataTable(dffull, include_index=False, num_rows_per_page=1500)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th
#       <td>None</td>
#       <td>62.80</td>
#       <td>None</td>
#       <td>51.80</td>
#       <td>11.00</td>
#       <td>None</td>
#       <td>None</td>
#       <td>4779080</td>
#       <td>76100</td>
#     </tr>
#     <tr>
#       <th>112</th>
#       <td>9990385</td>
#       <td>97978</td>
#       <td>Дом 10</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>136</td>
#       <td>1</td>
#       <td>10</td>
#       <td>3</td>
#       <td>True</td>
#       <td>False</td>
#       <td>...</td>
#       <td>111626</td>
#       <td>None</td>
#       <td>42.30</td>
#       <td>None</td>
#       <td>31.44</td>
#       <td>10.86</td>
#       <td>None</td>
#       <td>None</td>
#       <td>3595500</td>
#       <td>85000</td>
#     </tr>
#     <tr>
#       <th>113</th>
#       <td>9990386</td>
#       <td>97978</td>
#       <td>Дом 10</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>137</td>
#       <td>1</td>
#       <td>10</td>
#       <td>3</td>
#       <td>True</td>
#       <td>False</td>
#       <td>...</td>
#       <td>111625</td>
#       <td>None</td>
#       <td>41.97</td>
#       <td>None</td>
#       <td>31.11</td>
#       <td>10.86</td>
#       <td>None</td>
#       <td>None</td>
#       <td>3567450</td>
#       <td>85000</td>
#     </tr>
#     <tr>
#       <th>114</th>
#       <td>9990387</td>
#       <td>97978</td>
#       <td>Дом 10</td>
#       <td>ЖК "Новая Самара"</td>
#       <td>138</td>
#       <td>2</td>
#       <td>10</td>
#       <td>3</td>
#       <td>True</td>
#       <td>False</td>
#       <td>...</td>
#       <td>111626</td>
#       <td>None</td>
#       <td>66.12</td>
#       <td>None</td>
#       <td>52.62</td>
#       <td>13.50</td>
#       <td>None</td>
#       <td>None</td>
#       <td>5031732</td>
#       <td>76100</td>
#     </tr>
#   </tbody>
# </table>
# <p>115 rows × 28 columns</p>
# </div>

# %%
dffull.head(2)
# Out:
#       id   pdId  region                                            address  \
# 0  18136  43084      63  г Самара, улица Советской Армии, д. 0, корпус ...
# 1   4024   2200      63         г Самара, район Октябрьский, просека Пятая
#
#    floorMin  floorMax  objElemLivingCnt objReady100PercDt  \
# 0        27        27               360        2023-06-30
# 1         5         5                16        2023-12-31
#
#   wallMaterialShortDesc objLkFinishTypeDesc  ...  \
# 0        Монолит-кирпич         Без отделки  ...
# 1                Кирпич         Без отделки  ...
#
#   quartography.objLivElemEntrFloorAvg  metro.id  metro.name metro.line  \
# 0                                 8.0    54.311   Советская     Первая
# 1                                 4.0       NaN         NaN        NaN
#
#   metro.color metro.time metro.isWalk metro.colors  \
# 0     #CD0505       11.5         True    [#CD0505]
# 1         NaN        NaN          NaN          NaN
#
#                                            nameObj  complexShortNm
# 0                                              NaN             NaN
# 1  Жилой комплекс "Акварель" (ЖК "Акварель") дом 9        Акварель
#
# [2 rows x 103 columns]

# %%
dffull.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Columns: 103 entries, id to complexShortNm
# dtypes: bool(2), float64(14), int64(40), object(47)
# memory usage: 140.1+ KB

# %%
zastr.reset_index(inplace=True)

# %%
len(zastr)
# Out:
# 190

# %%
zastr.head(2)
# Out:
#    index  objId                                          developer  \
# 0      0  13391  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 1      1  13383  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
#
#    rpdRegionCd                   objAddr  objFloorMin  objFloorMax  \
# 0           72  г Тюмень, ул Профсоюзная            3           12
# 1           72                  г Тюмень            4           20
#
#    objElemLivingCnt objReady100PercDt  objSquareLiving  ...  problemFlag  \
# 0                44        2022-12-31          4297.44  ...         NONE
# 1                68        2022-12-31          6293.78  ...         NONE
#
#    siteStatus  objGuarantyEscrowFlg  residentialBuildings     rpdNum   pdId  \
# 0  Строящиеся                     0                     1  72-000096  28101
# 1  Строящиеся                     0                     1  72-000095  28105
#
#    buildType  objStatus objCommercNm  complexShortName
# 0      Жилое          0          NaN               NaN
# 1      Жилое          0          NaN               NaN
#
# [2 rows x 24 columns]

# %%
type(zastr.developer)
# Out:
# pandas.core.series.Series

# %%
len(zastr)
# Out:
# 190

# %%
zastr.developer[1]
# Out:
# {'devId': 306,
#  'shortName': '2МЕН ГРУПП',
#  'fullName': '2МЕН ГРУПП',
#  'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#  'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#  'companyGroup': 5776,
#  'devInn': '7701651356'}

# %%
zastr.developer[1].items() #['companyGroup']
# Out:
# dict_items([('devId', 306), ('shortName', '2МЕН ГРУПП'), ('fullName', '2МЕН ГРУПП'), ('groupName', '2МЕН ГРУПП ДЕВЕЛОПМЕНТ'), ('orgForm', {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'}), ('companyGroup', 5776), ('devInn', '7701651356')])

# %%
zastr=zastr.assign(e=pd.Series(zastr.developer.).values)

# %%
zastr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 2000 non-null   int64
#  1   objId                 2000 non-null   int64
#  2   developer             2000 non-null   object
#  3   rpdRegionCd           2000 non-null   int64
#  4   objAddr               1998 non-null   object
#  5   objFloorMin           2000 non-null   int64
#  6   objFloorMax           2000 non-null   int64
#  7   objElemLivingCnt      2000 non-null   int64
#  8   objReady100PercDt     2000 non-null   object
#  9   objSquareLiving       2000 non-null   float64
#  10  objCompensFundFlg     2000 non-null   int64
#  11  objProblemFlg         2000 non-null   int64
#  12  latitude              2000 non-null   float64
#  13  longitude             2000 non-null   float64
#  14  problemFlag           2000 non-null   object
#  15  siteStatus            2000 non-null   object
#  16  objGuarantyEscrowFlg  2000 non-null   int64
#  17  residentialBuildings  2000 non-null   int64
#  18  rpdNum                2000 non-null   object
#  19  pdId                  2000 non-null   int64
#  20  buildType             2000 non-null   object
#  21  objStatus             2000 non-null   int64
#  22  objCommercNm          1564 non-null   object
#  23  complexShortName      298 non-null    object
#  24  e                     2000 non-null   object
# dtypes: float64(3), int64(12), object(10)
# memory usage: 390.8+ KB

# %%
type(zastr.developer)
# Out:
# pandas.core.series.Series

# %%
len(dffull)
# Out:
# 181

# %%
dffull['num_d']=""

# %%
dffull['num_m']=""
dffull['num_r']=""

# %%
dffull.columns
# Out:
# Index(['id', 'pdId', 'region', 'address', 'floorMin', 'floorMax', 'objElemLivingCnt', 'objReady100PercDt', 'wallMaterialShortDesc', 'objLkFinishTypeDesc',
#        ...
#        'metro.line', 'metro.color', 'metro.time', 'metro.isWalk', 'metro.colors', 'nameObj', 'complexShortNm', 'num_d', 'num_m', 'num_r'],
#       dtype='object', length=106)

# %%
i=0
while i<len(dffull):
#  print(str(i))
#  zastr=zastr.assign(devId=zastr.developer[i]['devId'])
#  zastr.shortName[i]=zastr.developer[i]['shortName']
#  zastr.fullName[i]=zastr.developer[i]['fullName']
#  zastr.groupName=zastr.developer[i]['groupName']
#  zastr.companyGroup=zastr.developer[i]['companyGroup']
#  zastr.devInn[i]=zastr.developer[i]['devInn']
  i=i+1

# %%
zastr.head(2)
# Out:
#    index  objId                                          developer  \
# 0      0  13391  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
# 1      1  13383  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...
#
#    rpdRegionCd                   objAddr  objFloorMin  objFloorMax  \
# 0           72  г Тюмень, ул Профсоюзная            3           12
# 1           72                  г Тюмень            4           20
#
#    objElemLivingCnt objReady100PercDt  objSquareLiving  ...  \
# 0                44        2022-12-31          4297.44  ...
# 1                68        2022-12-31          6293.78  ...
#
#    objGuarantyEscrowFlg  residentialBuildings     rpdNum   pdId buildType  \
# 0                     0                     1  72-000096  28101     Жилое
# 1                     0                     1  72-000095  28105     Жилое
#
#   objStatus  objCommercNm  complexShortName  \
# 0         0           NaN               NaN
# 1         0           NaN               NaN
#
#                                                    e  devId
# 0  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...    682
# 1  {'devId': 306, 'shortName': '2МЕН ГРУПП', 'ful...    682
#
# [2 rows x 26 columns]

# %%
zastr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 190 non-null    int64
#  1   objId                 190 non-null    int64
#  2   developer             190 non-null    object
#  3   rpdRegionCd           190 non-null    int64
#  4   objAddr               190 non-null    object
#  5   objFloorMin           190 non-null    int64
#  6   objFloorMax           190 non-null    int64
#  7   objElemLivingCnt      190 non-null    int64
#  8   objReady100PercDt     190 non-null    object
#  9   objSquareLiving       190 non-null    float64
#  10  objCompensFundFlg     190 non-null    int64
#  11  objProblemFlg         190 non-null    int64
#  12  latitude              190 non-null    float64
#  13  longitude             190 non-null    float64
#  14  problemFlag           190 non-null    object
#  15  siteStatus            190 non-null    object
#  16  objGuarantyEscrowFlg  190 non-null    int64
#  17  residentialBuildings  190 non-null    int64
#  18  rpdNum                190 non-null    object
#  19  pdId                  190 non-null    int64
#  20  buildType             190 non-null    object
#  21  objStatus             190 non-null    int64
#  22  objCommercNm          159 non-null    object
#  23  complexShortName      17 non-null     object
# dtypes: float64(3), int64(12), object(9)
# memory usage: 35.8+ KB

# %%
type(zastr.developer[1])
# Out:
# dict

# %%
zz=pd.DataFrame(zastr.developer[1])

# %%
zz
# Out:
#            devId shortName fullName                  groupName  \
# fullForm    1087    АРНИКА   АРНИКА  Строительный холдинг Град
# id          1087    АРНИКА   АРНИКА  Строительный холдинг Град
# shortForm   1087    АРНИКА   АРНИКА  Строительный холдинг Град
#
#                                  orgForm  companyGroup      devInn
# fullForm   Закрытое акционерное общество          5847  6318136702
# id                                   119          5847  6318136702
# shortForm                            ЗАО          5847  6318136702

# %%
zastr.head(2)
# Out:
#    index  objId                                          developer  \
# 0     63  18136  {'devId': 6193, 'shortName': 'АЛЬЯНС', 'fullNa...
# 1    185   4024  {'devId': 1087, 'shortName': 'АРНИКА', 'fullNa...
#
#    rpdRegionCd                                            objAddr  \
# 0           63  г Самара, улица Советской Армии, д. 0, корпус ...
# 1           63         г Самара, район Октябрьский, просека Пятая
#
#    objFloorMin  objFloorMax  objElemLivingCnt objReady100PercDt  \
# 0           27           27               360        2023-06-30
# 1            5            5                16        2023-12-31
#
#    objSquareLiving  ...  problemFlag  siteStatus  objGuarantyEscrowFlg  \
# 0         20664.24  ...         NONE  Строящиеся                     1
# 1           918.77  ...         NONE  Строящиеся                     0
#
#    residentialBuildings     rpdNum   pdId  buildType  objStatus  \
# 0                     1  63-000283  43084      Жилое          0
# 1                     1  63-000027   2200      Жилое          0
#
#                                       objCommercNm  complexShortName
# 0                                              NaN               NaN
# 1  Жилой комплекс "Акварель" (ЖК "Акварель") дом 9          Акварель
#
# [2 rows x 24 columns]

# %%
ser
# Out:
# 0    [{'objId': 42206, 'developer': {'devId': 8154, 'shortName': 'СПЕЦЗАСТРОЙЩИК ЖЕЛЕЗНО ИЖЕВСК', 'fullName': 'СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК ЖЕЛЕЗНО ИЖЕВСК', 'groupName': 'Железно', 'orgForm': {'id': 4...
# Name: list, dtype: object

# %%
documents = []
url_doc_list = 'https://наш.дом.рф/сервисы/api/object/47925/document/rpd'
response = requests.get(url_doc_list)
documents = response.json()
documents = documents['data']
#documents = json_normalize(documents)

# %%
type(documents)
# Out:
# list

# %%
df_docs=pd.DataFrame(documents)

# %%
df_docs
# Out:
#    ordNum   rpdId    pdId  devId      rpdIssueDttm     rpdNum rpdPublStatusDesc                                                                               rpdPdfLink  \
# 0       1  652865  620216   1296  10-11-2022 04:16  38-000548         Размещена  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/ce607034-266a-4e49-95f1-217c322a940a
# 1       2  644383  620216   1296  10-10-2022 10:34  38-000548         Размещена  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/10b264ae-f152-4ac0-9db0-406d40a8a47f
# 2       3  640101  620216   1296  05-10-2022 07:48  38-000548         Размещена  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/756e320c-8c44-4e31-8653-71238d3a257d
# 3       4  636091  620216   1296  13-09-2022 15:22  38-000548         Размещена  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/e60fe102-2daa-4649-ae7e-f181f13e3f6c
# 4       5  634846  620216   1296  09-09-2022 17:37  38-000548         Размещена  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/cd720523-87b1-497f-b1a8-f575b0a28f7b
# 5       6  620216  620216   1296  08-09-2022 16:30  38-000548         Размещена  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70c73cad-5a83-4aa0-8c6d-28c79eedfbba
#
#                                                                             rpdPdfLinkTest rpdPdfSize          loadDttm                 fileName      fileNameDownload  objId
# 0  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/ce607034-266a-4e49-95f1-217c322a940a    1126143  21-11-2022 01:10  obj47925_pd38-000548_01  obj47925_pd38-000548  47925
# 1  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/10b264ae-f152-4ac0-9db0-406d40a8a47f    1126131  21-11-2022 01:10  obj47925_pd38-000548_02  obj47925_pd38-000548  47925
# 2  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/756e320c-8c44-4e31-8653-71238d3a257d    1126588  21-11-2022 01:10  obj47925_pd38-000548_03  obj47925_pd38-000548  47925
# 3  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/e60fe102-2daa-4649-ae7e-f181f13e3f6c    1123821  21-11-2022 01:10  obj47925_pd38-000548_04  obj47925_pd38-000548  47925
# 4  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/cd720523-87b1-497f-b1a8-f575b0a28f7b    1124056  21-11-2022 01:10  obj47925_pd38-000548_05  obj47925_pd38-000548  47925
# 5  https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70c73cad-5a83-4aa0-8c6d-28c79eedfbba    1123959  21-11-2022 01:10  obj47925_pd38-000548_06  obj47925_pd38-000548  47925

# %%
documents
# Out:
# {'data': [{'ordNum': 1,
#    'rpdId': 652865,
#    'pdId': 620216,
#    'devId': 1296,
#    'rpdIssueDttm': '10-11-2022 04:16',
#    'rpdNum': '38-000548',
#    'rpdPublStatusDesc': 'Размещена',
#    'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/ce607034-266a-4e49-95f1-217c322a940a',
#    'rpdPdfLinkTest': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/ce607034-266a-4e49-95f1-217c322a940a',
#    'rpdPdfSize': '1126143',
#    'loadDttm': '21-11-2022 01:10',
#    'fileName': 'obj47925_pd38-000548_01',
#    'fileNameDownload': 'obj47925_pd38-000548',
#    'objId': 47925},
#   {'ordNum': 2,
#    'rpdId': 644383,
#    'pdId': 620216,
#    'devId': 1296,
#    'rpdIssueDttm': '10-10-2022 10:34',
#    'rpdNum': '38-000548',
#    'rpdPublStatusDesc': 'Размещена',
#    'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/10b264ae-f152-4ac0-9db0-406d40a8a47f',
#    'rpdPdfLinkTest': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/10b264ae-f152-4ac0-9db0-406d40a8a47f',
#    'rpdPdfSize': '1126131',
#    'loadDttm': '21-11-2022 01:10',
#    'fileName': 'obj47925_pd38-000548_02',
#    'fileNameDownload': 'obj47925_pd38-000548',
#    'objId': 47925},
#   {'ordNum': 3,
#    'rpdId': 640101,
#    'pdId': 620216,
#    'devId': 1296,
#    'rpdIssueDttm': '05-10-2022 07:48',
#    'rpdNum': '38-000548',
#    'rpdPublStatusDesc': 'Размещена',
#    'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/756e320c-8c44-4e31-8653-71238d3a257d',
#    'rpdPdfLinkTest': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/756e320c-8c44-4e31-8653-71238d3a257d',
#    'rpdPdfSize': '1126588',
#    'loadDttm': '21-11-2022 01:10',
#    'fileName': 'obj47925_pd38-000548_03',
#    'fileNameDownload': 'obj47925_pd38-000548',
#    'objId': 47925},
#   {'ordNum': 4,
#    'rpdId': 636091,
#    'pdId': 620216,
#    'devId': 1296,
#    'rpdIssueDttm': '13-09-2022 15:22',
#    'rpdNum': '38-000548',
#    'rpdPublStatusDesc': 'Размещена',
#    'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/e60fe102-2daa-4649-ae7e-f181f13e3f6c',
#    'rpdPdfLinkTest': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/e60fe102-2daa-4649-ae7e-f181f13e3f6c',
#    'rpdPdfSize': '1123821',
#    'loadDttm': '21-11-2022 01:10',
#    'fileName': 'obj47925_pd38-000548_04',
#    'fileNameDownload': 'obj47925_pd38-000548',
#    'objId': 47925},
#   {'ordNum': 5,
#    'rpdId': 634846,
#    'pdId': 620216,
#    'devId': 1296,
#    'rpdIssueDttm': '09-09-2022 17:37',
#    'rpdNum': '38-000548',
#    'rpdPublStatusDesc': 'Размещена',
#    'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/cd720523-87b1-497f-b1a8-f575b0a28f7b',
#    'rpdPdfLinkTest': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/cd720523-87b1-497f-b1a8-f575b0a28f7b',
#    'rpdPdfSize': '1124056',
#    'loadDttm': '21-11-2022 01:10',
#    'fileName': 'obj47925_pd38-000548_05',
#    'fileNameDownload': 'obj47925_pd38-000548',
#    'objId': 47925},
#   {'ordNum': 6,
#    'rpdId': 620216,
#    'pdId': 620216,
#    'devId': 1296,
#    'rpdIssueDttm': '08-09-2022 16:30',
#    'rpdNum': '38-000548',
#    'rpdPublStatusDesc': 'Размещена',
#    'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70c73cad-5a83-4aa0-8c6d-28c79eedfbba',
#    'rpdPdfLinkTest': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/70c73cad-5a83-4aa0-8c6d-28c79eedfbba',
#    'rpdPdfSize': '1123959',
#    'loadDttm': '21-11-2022 01:10',
#    'fileName': 'obj47925_pd38-000548_06',
#    'fileNameDownload': 'obj47925_pd38-000548',
#    'objId': 47925}],
#  'errcode': '0'}

# %%
type(documents)
# Out:
# dict

# %%
type(documents)
# Out:
# list

# %%
# !pip install tabula-py
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tabula-py
#   Downloading tabula_py-2.6.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 4.8 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.21.6)
# Collecting distro
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.3.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.8.0 tabula-py-2.6.0

# %%
# !pip install PyMuPDF
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.21.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 5.4 MB/s
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.21.0

# %%
# !pip install PyPDF2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyPDF2
#   Downloading pypdf2-2.11.2-py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 4.8 MB/s
# Requirement already satisfied: typing_extensions>=3.10.0.0 in /usr/local/lib/python3.7/dist-packages (from PyPDF2) (4.1.1)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.11.2

# %%
import tabula

# %%
import re

# %%
r = requests.get(rpdPdfLink, stream=True)

# %%
dffull.tail()
# Out:
#         id    pdId  region                                            address  \
# 175  25813   78496      63  г Самара, район Ленинский, Улица Вилоновская, ...
# 176  33908  221806      63  г Самара, район Самарский, улица Степана Разин...
# 177  44145  513488      63                   г Тольятти, ул Советская, д. 60А
# 178  34040  232480      63               г Самара, ул Советской Армии, д. 127
# 179  43207  295812      63                           г Самара, ул Маяковского
#
#      floorMin  floorMax  objElemLivingCnt objReady100PercDt  \
# 175        22        22               260        2022-12-31
# 176         9        10               113        2023-12-31
# 177         8         8                56        2023-09-30
# 178        26        26               496        2023-06-30
# 179        19        19               142        2024-09-30
#
#     wallMaterialShortDesc objLkFinishTypeDesc  ...  \
# 175        Монолит-кирпич         Без отделки  ...
# 176                Кирпич         Без отделки  ...
# 177        Монолит-кирпич        Под чистовую  ...
# 178        Монолит-кирпич         Без отделки  ...
# 179        Монолит-кирпич         Без отделки  ...
#
#     quartography.objLivElemEntrFloorAvg  metro.id  metro.name metro.line  \
# 175                                 4.0    54.308  Московская     Первая
# 176                                 4.0    54.509  Алабинская     Первая
# 177                                 7.0       NaN         NaN        NaN
# 178                                10.0    54.312      Победа     Первая
# 179                                 9.0    54.509  Алабинская     Первая
#
#     metro.color metro.time metro.isWalk metro.colors  \
# 175     #CD0505  19.366667        False    [#CD0505]
# 176     #CD0505  26.800000        False    [#CD0505]
# 177         NaN        NaN          NaN          NaN
# 178     #CD0505  10.150000        False    [#CD0505]
# 179     #CD0505  19.483333         True    [#CD0505]
#
#                                                nameObj  complexShortNm
# 175                                       ЖК "Садовая"         САДОВАЯ
# 176  Жилой комплекс"Вознесенский"(2 этап) (ЖК"Возне...   Вознесенский
# 177                                                NaN             NaN
# 178                                       ЖК "Журавли"             NaN
# 179                                ЖК "Маяковский NEW"             NaN
#
# [5 rows x 103 columns]

# %%
x=0
i=0
documents=[]
dfrasp=pd.DataFrame()
dfraspfull=pd.DataFrame()
while i<len(dffull):
 url_doc_list = 'https://наш.дом.рф/сервисы/api/object/'+str(dffull['id'].unique()[i])+'/sales_agg'
 response = requests.get(url_doc_list)
 documents = response.json()
 documents = documents['data']
 dfrasp = pd.json_normalize(documents)
 try:
   dffull.loc[i,'raspr']=dfrasp['apartmentsAggData.realised'][0]
 except KeyError:
   qq=True
# dfraspfull=pd.concat([dfraspfull,dfrasp],ignore_index=True)
 time.sleep(5)
 i=i+1

# %%
dffull.head(20)
# Out:
#        id    pdId  region                                            address  \
# 0   18136   43084      63  г Самара, улица Советской Армии, д. 0, корпус ...
# 1    4024    2200      63         г Самара, район Октябрьский, просека Пятая
# 2    4025    2200      63         г Самара, район Октябрьский, просека Пятая
# 3    4023    2200      63         г Самара, район Октябрьский, просека Пятая
# 4    4026    2200      63         г Самара, район Октябрьский, просека Пятая
# 5   47153  615536      63                 г Чапаевск, ул Пролетарская, д. 10
# 6   47152  615536      63                 г Чапаевск, ул Пролетарская, д. 10
# 7   46297  595937      63                 г Чапаевск, ул Пролетарская, д. 10
# 8   24539   69105      63                              г Самара, Белорусская
# 9   24540   69105      63                              г Самара, Белорусская
# 10  35909  279525      63     г Самара, Ленинский район, ул Мичурина, д. Б/н
# 11   3402    2537      63  г Самара, район Кировский, улица Демократическ...
# 12   3409    2537      63  г Самара, район Кировский, улица Демократическ...
# 13  27567   97312      63  г Самара, район Ленинский, улица Галактионовск...
# 14  27568   97312      63  г Самара, район Ленинский, улица Галактионовск...
# 15  27561   97303      63  г Самара, район Ленинский, улица Галактионовск...
# 16  27566   97312      63  г Самара, район Ленинский, улица Галактионовск...
# 17  27565   97303      63  г Самара, район Ленинский, улица Галактионовск...
# 18  27570   97312      63  г Самара, район Ленинский, улица Галактионовск...
# 19  27564   97303      63  г Самара, район Ленинский, улица Галактионовск...
#
#     floorMin  floorMax  objElemLivingCnt objReady100PercDt  \
# 0         27        27               360        2023-06-30
# 1          5         5                16        2023-12-31
# 2          5         5                64        2022-12-31
# 3          5         5                48        2022-12-31
# 4          5         5                64        2022-12-31
# 5          5         5                32        2023-09-30
# 6          5         5                32        2023-09-30
# 7          5         5                32        2022-12-31
# 8         25        25               396        2022-12-31
# 9          1         1                 0        2022-12-31
# 10        23        23               101        2022-12-31
# 11         5         5                24        2022-06-30
# 12         5         5                24        2022-06-30
# 13        16        16                36        2025-12-31
# 14        16        16                54        2025-12-31
# 15        23        23                80        2023-03-31
# 16        16        16                55        2025-12-31
# 17        17        17                24        2023-03-31
# 18        11        11                18        2025-12-31
# 19         9         9                 0        2023-03-31
#
#    wallMaterialShortDesc   objLkFinishTypeDesc  ...  \
# 0         Монолит-кирпич           Без отделки  ...
# 1                 Кирпич           Без отделки  ...
# 2                 Кирпич           Без отделки  ...
# 3                 Кирпич           Без отделки  ...
# 4                 Кирпич           Без отделки  ...
# 5                 Кирпич  По желанию заказчика  ...
# 6                 Кирпич  По желанию заказчика  ...
# 7                 Кирпич  По желанию заказчика  ...
# 8                 Кирпич           Без отделки  ...
# 9                 Другое           Без отделки  ...
# 10        Монолит-кирпич           Без отделки  ...
# 11                Кирпич           Без отделки  ...
# 12                Кирпич           Без отделки  ...
# 13        Монолит-кирпич           Без отделки  ...
# 14        Монолит-кирпич           Без отделки  ...
# 15        Монолит-кирпич           Без отделки  ...
# 16        Монолит-кирпич           Без отделки  ...
# 17        Монолит-кирпич           Без отделки  ...
# 18        Монолит-кирпич           Без отделки  ...
# 19        Монолит-кирпич           Без отделки  ...
#
#    quartography.objLivElemEntrFloorAvg  metro.id  metro.name metro.line  \
# 0                                  8.0    54.311   Советская     Первая
# 1                                  4.0       NaN         NaN        NaN
# 2                                  4.0       NaN         NaN        NaN
# 3                                  4.0       NaN         NaN        NaN
# 4                                  4.0       NaN         NaN        NaN
# 5                                  4.0       NaN         NaN        NaN
# 6                                  4.0       NaN         NaN        NaN
# 7                                  4.0       NaN         NaN        NaN
# 8                                  5.0       NaN         NaN        NaN
# 9                                  NaN       NaN         NaN        NaN
# 10                                 5.0    54.509  Алабинская     Первая
# 11                                 6.0       NaN         NaN        NaN
# 12                                 6.0       NaN         NaN        NaN
# 13                                 4.0    54.509  Алабинская     Первая
# 14                                 6.0    54.509  Алабинская     Первая
# 15                                 5.0    54.509  Алабинская     Первая
# 16                                 6.0    54.509  Алабинская     Первая
# 17                                 2.0    54.509  Алабинская     Первая
# 18                                 3.0    54.509  Алабинская     Первая
# 19                                 NaN    54.509  Алабинская     Первая
#
#    metro.color metro.time metro.isWalk metro.colors  \
# 0      #CD0505  11.500000         True    [#CD0505]
# 1          NaN        NaN          NaN          NaN
# 2          NaN        NaN          NaN          NaN
# 3          NaN        NaN          NaN          NaN
# 4          NaN        NaN          NaN          NaN
# 5          NaN        NaN          NaN          NaN
# 6          NaN        NaN          NaN          NaN
# 7          NaN        NaN          NaN          NaN
# 8          NaN        NaN          NaN          NaN
# 9          NaN        NaN          NaN          NaN
# 10     #CD0505  16.250000         True    [#CD0505]
# 11         NaN        NaN          NaN          NaN
# 12         NaN        NaN          NaN          NaN
# 13     #CD0505  15.333333         True    [#CD0505]
# 14     #CD0505  15.150000         True    [#CD0505]
# 15     #CD0505  14.950000         True    [#CD0505]
# 16     #CD0505  15.483333         True    [#CD0505]
# 17     #CD0505  15.366667         True    [#CD0505]
# 18     #CD0505  15.166667         True    [#CD0505]
# 19     #CD0505  15.516667         True    [#CD0505]
#
#                                              nameObj  complexShortNm
# 0                                                NaN             NaN
# 1    Жилой комплекс "Акварель" (ЖК "Акварель") дом 9        Акварель
# 2    Жилой комплекс "Акварель" (ЖК "Акварель") дом 7        Акварель
# 3    Жилой комплекс "Акварель" (ЖК "Акварель") дом 8        Акварель
# 4   Жилой комплекс "Акварель" (ЖК "Акварель") дом 10        Акварель
# 5                                                NaN             NaN
# 6                                                NaN             NaN
# 7                                                NaN             NaN
# 8                                      ЖК "Две реки"             NaN
# 9                                      ЖК "Две реки"             NaN
# 10                                     ЖК "АКВАРИУМ"             NaN
# 11                               ЖК "КУЙБЫШЕВ" ДОМ 3        Куйбышев
# 12                               ЖК "КУЙБЫШЕВ" ДОМ 9        Куйбышев
# 13                              ЖК "Гранд Империалъ"             NaN
# 14                              ЖК "Гранд Империалъ"             NaN
# 15                              ЖК "Гранд Империалъ"             NaN
# 16                              ЖК "Гранд Империалъ"             NaN
# 17                              ЖК "Гранд Империалъ"             NaN
# 18                              ЖК "Гранд Империалъ"             NaN
# 19                              ЖК "Гранд Империалъ"             NaN
#
# [20 rows x 103 columns]

# %%
len(dffull)
# Out:
# 177

# %%
dffull[dffull.index==47]
# Out:
#        id    pdId  region                                address  floorMin  \
# 47  45120  553294      63  г Самара, район Куйбышевский, ш Южное        17
#
#     floorMax  objElemLivingCnt objReady100PercDt wallMaterialShortDesc  \
# 47        25               536        2024-09-30        Монолит-кирпич
#
#      objLkFinishTypeDesc  ... metro.line  metro.color  metro.time  \
# 47  По желанию заказчика  ...        NaN          NaN         NaN
#
#    metro.isWalk metro.colors            nameObj complexShortNm num_d  num_r  \
# 47          NaN          NaN  Макрорайон Амград            NaN   0.0    0.0
#
#     num_m
# 47    0.0
#
# [1 rows x 106 columns]

# %%
dffull[dffull.id==42767]
# Out:
#        id    pdId  region                      address  floorMin  floorMax  \
# 39  42767  496271      63  г Самара, район Октябрьский        28        28
#
#     objElemLivingCnt objReady100PercDt wallMaterialShortDesc  \
# 39               240        2024-09-30        Монолит-кирпич
#
#    objLkFinishTypeDesc  ... metro.line  metro.color  metro.time metro.isWalk  \
# 39         Без отделки  ...     Первая      #CD0505   10.366667         True
#
#    metro.colors nameObj complexShortNm num_d  num_r  num_m
# 39    [#CD0505]     NaN            NaN  35.0    0.0    0.0
#
# [1 rows x 106 columns]

# %%
dffull[dffull.pdId==615536]
# Out:
#       id    pdId  region                             address  floorMin  \
# 5  47153  615536      63  г Чапаевск, ул Пролетарская, д. 10         5
# 6  47152  615536      63  г Чапаевск, ул Пролетарская, д. 10         5
#
#    floorMax  objElemLivingCnt objReady100PercDt wallMaterialShortDesc  \
# 5         5                32        2023-09-30                Кирпич
# 6         5                32        2023-09-30                Кирпич
#
#     objLkFinishTypeDesc  ... metro.line  metro.color  metro.time metro.isWalk  \
# 5  По желанию заказчика  ...        NaN          NaN         NaN          NaN
# 6  По желанию заказчика  ...        NaN          NaN         NaN          NaN
#
#   metro.colors nameObj complexShortNm num_d       num_r    num_m
# 5          NaN     NaN            NaN   3.0  89136803.7  1765.26
# 6          NaN     NaN            NaN   NaN         NaN      NaN
#
# [2 rows x 106 columns]

# %%
rpdPdfLink=dffull.rpdPdfLink[46]

# %%
import math

# %%
dffull[dffull.index==46]
# Out:
#        id    pdId  region                                            address  \
# 46  40239  460620      63  г Самара, район Куйбышевский, шоссе Южное шосс...
#
#     floorMin  floorMax  objElemLivingCnt objReady100PercDt  \
# 46        11        25               911        2023-06-30
#
#    wallMaterialShortDesc   objLkFinishTypeDesc  ... metro.color  metro.time  \
# 46        Монолит-кирпич  По желанию заказчика  ...         NaN         NaN
#
#     metro.isWalk metro.colors            nameObj complexShortNm  raspr num_d  \
# 46           NaN          NaN  Макрорайон Амград            NaN  845.0   0.0
#
#            num_r     num_m
# 46  2.831752e+09  39330.69
#
# [1 rows x 107 columns]

# %%
str(dffull['rpdPdfLink'].head())
# Out:
# '0    https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...\n1    https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...\n2    https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...\n3    https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...\n4    https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/...\nName: rpdPdfLink, dtype: object'

# %%
dffull[dffull.pdId==2200]
# Out:
#      id  pdId  region                                     address  floorMin  \
# 1  4024  2200      63  г Самара, район Октябрьский, просека Пятая         5
# 2  4025  2200      63  г Самара, район Октябрьский, просека Пятая         5
# 3  4023  2200      63  г Самара, район Октябрьский, просека Пятая         5
# 4  4026  2200      63  г Самара, район Октябрьский, просека Пятая         5
#
#    floorMax  objElemLivingCnt objReady100PercDt wallMaterialShortDesc  \
# 1         5                16        2023-12-31                Кирпич
# 2         5                64        2022-12-31                Кирпич
# 3         5                48        2022-12-31                Кирпич
# 4         5                64        2022-12-31                Кирпич
#
#   objLkFinishTypeDesc  ... metro.line  metro.color  metro.time metro.isWalk  \
# 1         Без отделки  ...        NaN          NaN         NaN          NaN
# 2         Без отделки  ...        NaN          NaN         NaN          NaN
# 3         Без отделки  ...        NaN          NaN         NaN          NaN
# 4         Без отделки  ...        NaN          NaN         NaN          NaN
#
#   metro.colors                                           nameObj  \
# 1          NaN   Жилой комплекс "Акварель" (ЖК "Акварель") дом 9
# 2          NaN   Жилой комплекс "Акварель" (ЖК "Акварель") дом 7
# 3          NaN   Жилой комплекс "Акварель" (ЖК "Акварель") дом 8
# 4          NaN  Жилой комплекс "Акварель" (ЖК "Акварель") дом 10
#
#   complexShortNm  num_d         num_r     num_m
# 1       Акварель  440.0  1.813398e+09  35096.83
# 2       Акварель  440.0  1.813398e+09  35096.83
# 3       Акварель  440.0  1.813398e+09  35096.83
# 4       Акварель  440.0  1.813398e+09  35096.83
#
# [4 rows x 106 columns]

# %%
dffull[(dffull.rpdPdfLink=='https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/8f6505ff-9e92-4872-a760-24d546ca19f5')&(dffull.index<3)]['num_d'].to_list()[0]
# Out:
# 440.0

# %%
x=102
dffull.fillna(0)
while x<len(dffull):
  rpdPdfLink=dffull.rpdPdfLink[x]
  new=False
  print(rpdPdfLink)
  print(str(x)+':'+str(dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)].id.count()))
  if dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)].id.count()==0:
   new=True
   tables = tabula.read_pdf(rpdPdfLink, pages='all', pandas_options={'header': None})
  if new==False:
   print(dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)]['num_d'].to_list()[0])
   dffull.loc[x,'num_d']=0 #dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)]['num_d'].to_list()[0] 
   dffull.loc[x,'num_r']=0 #dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)]['num_r'].to_list()[0]
   dffull.loc[x,'num_m']=0 #dffull[(dffull.rpdPdfLink==rpdPdfLink)&(dffull.index<x)]['num_m'].to_list()[0]
  print(str(x)+' :: '+str(dffull.iloc[x]['id']))
  i=0
  j=0
  k=0
  str_d=''
  str_m=''
  str_r=''
  num_d=0
  num_m=0
  num_r=0
  while (k<len(tables))&(new==True):
 # print('True!')
   i=0
   while i<len(tables[k].axes[1]):
    j=0
    while j<len(tables[k]):
     ffindr=0
     ffindm=0
     ffindd=0
     if str(tables[k][i][j])!='nan' and  str(type(tables[k][i][j]))!="<class 'numpy.float64'>" and  str(type(tables[k][i][j]))!="<class 'numpy.int64'>" :
      if ((str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных с использованием счетов эскроу:')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных при условии уплаты обязательных')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных с использованием иных')>-1))&(str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
  #      print(str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
         str_d=str(str(tables[k][i][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         print(str(k)+'+'+str(i)+'+'+str(j)+'||'+str(len(str_d))+'^^^'+str_d)
         if len(str_d)>0:
          if math.isnan(float(str_d))==False: 
           num_d=num_d+float(str_d)
           ffindd=1
         if ffindd==0:
          str_d=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False: 
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
          str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False: 
            num_d=num_d+float(str_d)
            ffindd=1
      if (str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных ')==-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
        try: 
         str_d=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
         str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         if len(str_d)>0:
           if math.isnan(float(str_d))==False: 
    #        print('111')
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
    #      print('222') 
          str_d=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False: 
            num_d=num_d+float(str_d)
            ffindd=1
         if ffindd==0:
    #      print('333')
          str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False: 
            num_d=num_d+float(str_d)
            ffindd=1
        except (KeyError, ValueError):
   #      print('444') 
         try:
          str_d=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
          str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
     #     print('try')
          if len(str_d)>0:
           if math.isnan(float(str_d))==False: 
            num_d=num_d+float(str_d)
            ffindd=1
         except (KeyError, ValueError):
          try:
           str_d=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.1.1.1.1','').replace('19.7.1.1.1.2','').replace('19.7.1.1.1.3',''))
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием счетов эскроу:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечения гражданской ответственности застройщика:', '')
           str_d=str_d.replace('Количество договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
           str_d=str_d.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
           if len(str_d)>0:
            if math.isnan(float(str_d))==False: 
             num_d=num_d+float(str_d)
             ffindd=1 
          except (KeyError, ValueError):   
           pass
# ПЛОЩАДЬ
      if ((str(tables[k][i][j].replace('\r', '')).find('Площадь объектов, в отношении которых договор участия в долевом строительстве')>-1))&(str(tables[k][i][j].replace('\r', '')).find('19.7.2.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
 #       print(str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
         str_m=str(str(tables[k][i][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2',''))
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
         str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         if len(str_m)>0:
           if math.isnan(float(str_m))==False: 
            num_m=num_m+float(str_m)
            ffindm=1
         if ffindm==0:
          str_m=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False: 
            num_m=num_m+float(str_m)
            ffindm=1
         if ffindm==0:
          str_m=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False: 
            num_m=num_m+float(str_m)
            ffindm=1
      if (str(tables[k][i][j].replace('\r', '')).find('Площадь объектов, в отношении которых договор участия в долевом строительстве')==-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.2.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
        try: 
         str_m=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2',''))
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
         str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
         str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         if len(str_m)>0:
           if math.isnan(float(str_m))==False: 
            num_m=num_m+float(str_m)
            ffindm=1
         if ffindm==0:
          str_m=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False: 
            num_m=num_m+float(str_m)
            ffindm=1
        except (KeyError, ValueError):
         try:
          str_m=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.2.1.1.1','').replace('19.7.2.1.1.2','').replace('19.7.2.1.1.3','').replace('м2',''))
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием счетов эскроу:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен с использованием иных способов обеспечения гражданскойответственности застройщика:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительстве заключен при условии уплаты обязательных отчислений (взносов) вкомпенсационный фонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:', '')
          str_m=str_m.replace('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:', '')
          str_m=str_m.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_m)>0:
           if math.isnan(float(str_m))==False: 
            num_m=num_m+float(str_m)
            ffindm=1
         except (KeyError, ValueError):
           pass
# РУБЛИ
      ffindr=0
      if ((str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд')>-1)or(str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных с использованием счетов эскроу')>-1))&(str(tables[k][i][j].replace('\r', '')).find('19.7.3.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
         print(str(k)+'m|m'+str(i)+'|'+str(j)+'|'+str(tables[k][i][j]))
         str_r=str(str(tables[k][i][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         if len(str_r)>0:
           if math.isnan(float(str_r))==False: 
            num_r=num_r+float(str_r)
            ffindr=1
         if ffindr==0:
          str_r=str(str(tables[k][i][j+1]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False: 
            num_r=num_r+float(str_r)
            ffindr=1
         if ffindr==0:
          str_r=str(str(tables[k][i+1][j+1]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False: 
            num_r=num_r+float(str_r)
            ffindr=1
      if (str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных')==-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.3.1.1.')>-1)&(str(tables[k][i][j].replace('\r', '')).find('Добавлены сведения в пункты:')==-1)&(str(tables[k][i][j].replace('\r', '')).find('Жилые помещения')==-1):
        try: 
         str_r=str(str(tables[k][i+1][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
         str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
         str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
         if len(str_r)>0:
           if math.isnan(float(str_r))==False: 
            num_r=num_r+float(str_r)
            ffindr=1
         if ffindr==0:
          str_r=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False: 
            num_r=num_r+float(str_r)
            ffindr=1
        except (KeyError, ValueError):
         try:
          str_r=str(str(tables[k][i+2][j]).replace('\r', '').replace('19.7.3.1.1.1','').replace('19.7.3.1.1.2','').replace('19.7.3.1.1.3','').replace('руб.','').replace('руб',''))
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:', '')
          str_r=str_r.replace('Суммарная цена договоров, заключенных с использованием иных способов обеспечениягражданской ответственности застройщика:', '')
          str_r=str_r.replace('(','').replace(')','').replace(' ','').replace(',','.').replace('Жилыепомещения:','')
          if len(str_r)>0:
           if math.isnan(float(str_r))==False: 
            num_r=num_r+float(str_r)
            ffindr=1
         except (KeyError, ValueError):
           pass
     #print(str(k)+'|'+str(i)+'|'+str(j)) 
     j=j+1
    i=i+1
#   print(str(k))
   k=k+1
  print(str(num_d)+'|'+str(num_m)+'|'+str(num_r))
  if new==True:
   dffull.loc[x,'num_d']=num_d
   dffull.loc[x,'num_r']=num_r
   dffull.loc[x,'num_m']=num_m
  x=x+1
#  print(dffull.objId[x])
#  print(num_r)
#  print(num_m)
# 42767, 43489, 40237, 40238,40236,40733,41623-ЮГ, 48688, 48686, 48687, 46470, 46469
# 40733
# Out:
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/d48530a5-a665-4912-8d4f-05d0a5daa3c3
# 102:0
# 102 :: 40733
# 44+0+44||0^^^
# 44+0+46||0^^^
# 44+0+48||0^^^
# 211.0|10438.33|662777899.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/c0f2712a-c626-4997-a3e7-902547d3c9aa
# 103:0
# 103 :: 45825
# 0.0|0.0|0.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 104:0
# 104 :: 47238
# 3.0|746.8|37984348.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 105:1
# 3.0
# 105 :: 47229
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 106:2
# 3.0
# 106 :: 47231
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 107:3
# 3.0
# 107 :: 47243
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 108:4
# 3.0
# 108 :: 47225
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 109:5
# 3.0
# 109 :: 47228
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 110:6
# 3.0
# 110 :: 47226
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 111:7
# 3.0
# 111 :: 47242
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 112:8
# 3.0
# 112 :: 47237
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 113:9
# 3.0
# 113 :: 47230
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 114:10
# 3.0
# 114 :: 47235
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 115:11
# 3.0
# 115 :: 47245
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 116:12
# 3.0
# 116 :: 47246
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 117:13
# 3.0
# 117 :: 47236
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/3cc7c6c2-ec1a-496a-a7a2-b8202a1fd2a7
# 118:14
# 3.0
# 118 :: 47232
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file

# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/f9d38784-7c7e-42ee-adb4-1765f5fb26d0
# 169:3
# 0.0
# 169 :: 40090
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/f9d38784-7c7e-42ee-adb4-1765f5fb26d0
# 170:4
# 0.0
# 170 :: 40092
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/4780a5d7-e7bb-4043-a420-05713259605b
# 171:0
# 171 :: 16734
# 211.0|20501.030000000002|1225379402.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/4780a5d7-e7bb-4043-a420-05713259605b
# 172:1
# 211.0
# 172 :: 16733
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/4780a5d7-e7bb-4043-a420-05713259605b
# 173:2
# 211.0
# 173 :: 16735
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/4780a5d7-e7bb-4043-a420-05713259605b
# 174:3
# 211.0
# 174 :: 16732
# 0|0|0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/40ad6429-a7a5-4e61-a5b4-abbfde887a2f
# 175:0
# 175 :: 21336
# 1.0|20595.01|746383750.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/0b6d087a-7ba1-4c2d-9575-39d5d04eec76
# 176:0
# 176 :: 25813
# 47.0|2919.21|64672774.2
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/d0a7c9f8-ab94-4645-b336-d64e1ceddb51
# 177:0
# 177 :: 33908
# 62.0|4639.3|304965600.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/6735ba3b-f653-4ed8-a49a-5544b6abeaa3
# 178:0
# 178 :: 44145
# 12.0|701.8|53974225.0
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/b220f667-e93e-4f9c-a6c5-c9dac6f22d34
# 179:0
# 179 :: 34040
# 496.0|22387.34|1201524683.4
# https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/d536c8c2-aed2-42f4-8e42-3bfcd4af518e
# 180:0
# 180 :: 43207
# 15.0|1020.71|106850247.0

# %%
float(tables[62][5][4].replace('\r','').replace('Количество договоров, заключенных при условии уплаты обязательных отчислений(взносов) в компенсационный фонд:',''))
# Out:
# 51.0

# %%
float(tables[63][5][6].replace('\r','').replace(',','.').replace('м2','').replace('Площадь объектов. в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:','').replace(' ',''))
# Out:
# 799.45

# %%
tables[46][0][0]
#Количество договоров, заключенных с использованием счетов эскроу:19.7.1.1.1.1
# Out:
# 'Суммарная цена договоров, заключенных при условии уплаты обязательных отчислений (взносов) в компенсационный фонд:19.7.3.1.1.2'

# %%
x=47
while x<48:#len(dffull):
  rpdPdfLink=dffull.rpdPdfLink[x]
#  print(rpdPdfLink)
  tables = tabula.read_pdf(rpdPdfLink, pages='all', pandas_options={'header': None})
  print(str(x)+' : '+str(dffull.iloc[x]['id'])) 
  i=0
  j=0
  k=0
  str_d=''
  str_m=''
  str_r=''
  num_d=0
  num_m=0
  num_r=0
  while k<len(tables):
   i=0
   while i<len(tables[k].axes[1]):
    j=0
    while j<len(tables[k]):
     print(str(k)+' - '+ str(i)+' - '+str(j)+':'+str(tables[k][i][j])+'   ' + str(type(tables[k][i][j])))
     if str(tables[k][i][j])!='nan' and  str(type(tables[k][i][j]))!="<class 'numpy.float64'>" and  str(type(tables[k][i][j]))!="<class 'numpy.int64'>" :
      d_bool=False
      r_bool=False
      m_bool=False
      try: 
        print(str(tables[k][i][j].str.replace('\r', ''))+'*'+str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1'))
        d_bool=((str(tables[k][i-1][j].replace('\r', '')).find('19.7.1.1.1')>-1)or(str(tables[k][i-2][j].replace('\r', '')).find('19.7.1.1.1')>-1)or(str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1')>-1))
      except KeyError:
        d_bool=False
      except AttributeError:
        d_bool=False
      try: 
        r_bool=(str(tables[k][i-1][j].replace('\r', '')).find('19.7.3.1.1')>-1)or(str(tables[k][i-2][j].replace('\r', '')).find('19.7.3.1.1')>-1)or(str(tables[k][i][j].replace('\r', '')).find('19.7.3.1.1')>-1)
      except KeyError:
        r_bool=False
      except AttributeError:
        r_bool=False  
      try: 
        m_bool=(str(tables[k][i-1][j].replace('\r', '')).find('19.7.2.1.1')>-1)or(str(tables[k][i-2][j].replace('\r', '')).find('19.7.2.1.1')>-1)or(str(tables[k][i][j].replace('\r', '')).find('19.7.2.1.1')>-1)
      except KeyError:
        m_bool=False
      except AttributeError:
        m_bool=False
      if (str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных с использованием счетов эскроу:')>-1)&(r_bool==True):
       str_r=tables[k][i][j].replace('\r', '');
       str_r=re.sub('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '', str_r);
       str_r=re.sub(' руб.', '', str_r);
       str_r=re.sub('руб.', '', str_r);
       str_r=re.sub(' ', '', str_r);
       num_r=num_r+float(str_r.replace(",","."));
      if ((str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных с использованием счетов эскроу:')>-1)&(d_bool==True))or((str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных с использованием счетов эскроу:')>-1)&(str(tables[k][i][j].replace('\r', '')).find('19.7.1.1.1.1')>-1)):
        print(str(k)+':'+str(i)+':'+str(j)) 
        print('Количество'+str(tables[k][i][j])+'  '+str(tables[k][i-1][j])+'  '+str(tables[k][i-2][j]))
 #      if (str(tables[k][i-2][j].replace('\r', '')).find('19.7.1.1.1')>-1)or(str(tables[k][i-1][j].replace('\r', '')).find('19.7.1.1.1')>-1):
        str_d=tables[k][i][j].replace('\r', '');
        str_d=re.sub('Количество договоров, заключенных с использованием счетов эскроу:', '', str_d);
        str_d=re.sub('19.7.1.1.1.1', '', str_d);
        str_d=re.sub(' руб.', '', str_d);
        str_d=re.sub('руб.', '', str_d);
        str_d=re.sub(' ', '', str_d);
        try:
          num_d=num_d+float(str_d.replace(",","."))
        except ValueError:
          str_d=tables[k][i+1][j+1]
          num_d=num_d+float(str_d.replace(",","."))
      if (str(tables[k][i][j].replace('\r', '')).find('Площадь объектов, в отношении которых договор участия в долевом строительстве')>-1)&(m_bool==True):
       str_m=tables[k][i][j].replace('\r', '');
#     print(str_m)
       str_m=re.sub('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '', str_m);
       str_m=re.sub("Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:", '', str_m);
       str_m=re.sub("Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:", '', str_m);
       str_m=re.sub(' м2', '', str_m);
       str_m=re.sub('м2', '', str_m);
       str_m=re.sub(' ', '', str_m);
       str_m=str_m.replace('(','');
       str_m=str_m.replace(')','');
       str_m=re.sub("Площадьобъектов,вотношениикоторыхдоговоручастиявдолевомстроительствезаключенприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:", '', str_m);
#     print(str_m);
       num_m=num_m+float(str_m.replace(",","."));
     j=j+1
    i=i+1
   k=k+1
  dffull.loc[x,'num_d']=num_d
  dffull.loc[x,'num_r']=num_r
  dffull.loc[x,'num_m']=num_m
  x=x+1
#  print(dffull.objId[x])
#  print(num_r)
#  print(num_m)
# 42767, 43489, 40237, 40238,40236,40733,41623-ЮГ, 48688, 48686, 48687, 46470, 46469
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 50 - 13 - 27:14.44   <class 'str'>
# 50 - 13 - 28:49.58   <class 'str'>
# 50 - 14 - 0:nan   <class 'numpy.float64'>
# 50 - 14 - 1:nan   <class 'numpy.float64'>
# 50 - 14 - 2:nan   <class 'numpy.float64'>
# 50 - 14 - 3:nan   <class 'numpy.float64'>
# 50 - 14 - 4:nan   <class 'numpy.float64'>
# 50 - 14 - 5:nan   <class 'numpy.float64'>
# 50 - 14 - 6:nan   <class 'numpy.float64'>
# 50 - 14 - 7:nan   <class 'numpy.float64'>
# 50 - 14 - 8:nan   <class 'numpy.float64'>
# 50 - 14 - 9:nan   <class 'numpy.float64'>
# 50 - 14 - 10:nan   <class 'numpy.float64'>
# 50 - 14 - 11:nan   <class 'numpy.float64'>
# 50 - 14 - 12:nan   <class 'numpy.float64'>
# 50 - 14 - 13:nan   <class 'numpy.float64'>
# 50 - 14 - 14:nan   <class 'numpy.float64'>
# 50 - 14 - 15:nan   <class 'numpy.float64'>
# 50 - 14 - 16:nan   <class 'numpy.float64'>
# 50 - 14 - 17:nan   <class 'numpy.float64'>
# 50 - 14 - 18:nan   <class 'numpy.float64'>
# 50 - 14 - 19:nan   <class 'numpy.float64'>
# 50 - 14 - 20:nan   <class 'numpy.float64'>
# 50 - 14 - 21:nan   <class 'numpy.float64'>
# 50 - 14 - 22:nan   <class 'numpy.float64'>
# 50 - 14 - 23:nan   <class 'numpy.float64'>
# 50 - 14 - 24:nan   <class 'numpy.float64'>
# 50 - 14 - 25:nan   <class 'numpy.float64'>
# 50 - 14 - 26:nan   <class 'numpy.float64'>
# 50 - 14 - 27:nan   <class 'numpy.float64'>
# 50 - 14 - 28:nan   <class 'numpy.float64'>
# 50 - 15 - 0:2.56   <class 'numpy.float64'>
# 50 - 15 - 1:2.56   <class 'numpy.float64'>
# 50 - 15 - 2:2.56   <class 'numpy.float64'>
# 50 - 15 - 3:2.56   <class 'numpy.float64'>
# 50 - 15 - 4:2.56   <class 'numpy.float64'>
# 50 - 15 - 5:2.56   <class 'numpy.float64'>
# 50 - 15 - 6:2.56   <class 'numpy.float64'>
# 50 - 15 - 7:2.56   <class 'numpy.float64'>
# 50 - 15 - 8:2.56   <class 'numpy.float64'>
# 50 - 15 - 9:2.56   <class 'numpy.float64'>
# 50 - 15 - 10:2.56   <class 'numpy.float64'>
# 50 - 15 - 11:2.56   <class 'numpy.float64'>
# 50 - 15 - 12:2.56   <class 'numpy.float64'>
# 50 - 15 - 13:2.56   <class 'numpy.float64'>
# 50 - 15 - 14:nan   <class 'numpy.float64'>
# 50 - 15 - 15:nan   <class 'numpy.float64'>
# 50 - 15 - 16:nan   <class 'numpy.float64'>
# 50 - 15 - 17:3.36   <class 'numpy.float64'>
# 50 - 15 - 18:nan   <class 'numpy.float64'>
# 50 - 15 - 19:nan   <class 'numpy.float64'>
# 50 - 15 - 20:nan   <class 'numpy.float64'>
# 50 - 15 - 21:nan   <class 'numpy.float64'>
# 50 - 15 - 22:nan   <class 'numpy.float64'>
# 50 - 15 - 23:nan   <class 'numpy.float64'>
# 50 - 15 - 24:nan   <class 'numpy.float64'>
# 50 - 15 - 25:nan   <class 'numpy.float64'>
# 50 - 15 - 26:nan   <class 'numpy.float64'>
# 50 - 15 - 27:3.36   <class 'numpy.float64'>
# 50 - 15 - 28:nan   <class 'numpy.float64'>
# 50 - 16 - 0:nan   <class 'numpy.float64'>
# 50 - 16 - 1:nan   <class 'numpy.float64'>
# 50 - 16 - 2:nan   <class 'numpy.float64'>
# 50 - 16 - 3:nan   <class 'numpy.float64'>
# 50 - 16 - 4:nan   <class 'numpy.float64'>
# 50 - 16 - 5:nan   <class 'numpy.float64'>
# 50 - 16 - 6:nan   <class 'numpy.float64'>
# 50 - 16 - 7:nan   <class 'numpy.float64'>
# 50 - 16 - 8:nan   <class 'numpy.float64'>
# 50 - 16 - 9:nan   <class 'numpy.float64'>
# 50 - 16 - 10:nan   <class 'numpy.float64'>
# 50 - 16 - 11:nan   <class 'numpy.float64'>
# 50 - 16 - 12:nan   <class 'numpy.float64'>
# 50 - 16 - 13:nan   <class 'numpy.float64'>
# 50 - 16 - 14:nan   <class 'numpy.float64'>
# 50 - 16 - 15:nan   <class 'numpy.float64'>
# 50 - 16 - 16:nan   <class 'numpy.float64'>
# 50 - 16 - 17:nan   <class 'numpy.float64'>
# 50 - 16 - 18:nan   <class 'numpy.float64'>
# 50 - 16 - 19:nan   <class 'numpy.float64'>
# 50 - 16 - 20:nan   <class 'numpy.float64'>
# 50 - 16 - 21:nan   <class 'numpy.float64'>
# 50 - 16 - 22:nan   <class 'numpy.float64'>
# 50 - 16 - 23:nan   <class 'numpy.float64'>
# 50 - 16 - 24:nan   <class 'numpy.float64'>
# 50 - 16 - 25:nan   <class 'numpy.float64'>
# 50 - 16 - 26:nan   <class 'numpy.float64'>
# 50 - 16 - 27:nan   <class 'numpy.float64'>
# 50 - 16 - 28:nan   <class 'numpy.float64'>
# 51 - 0 - 0:nan   <class 'numpy.float64'>
# 51 - 0 - 1:nan   <class 'numpy.float64'>
# 51 - 0 - 2:nan   <class 'numpy.float64'>
# 51 - 0 - 3:nan   <class 'numpy.float64'>
# 51 - 0 - 4:nan   <class 'numpy.float64'>
# 51 - 0 - 5:3.0   <class 'numpy.float64'>
# 51 - 0 - 6:nan   <class 'numpy.float64'>
# 51 - 0 - 7:nan   <class 'numpy.float64'>
# 51 - 0 - 8:nan   <class 'numpy.float64'>
# 51 - 0 - 9:nan   <class 'numpy.float64'>
# 51 - 0 - 10:nan   <class 'numpy.float64'>
# 51 - 0 - 11:4.0   <class 'numpy.float64'>
# 51 - 0 - 12:nan   <class 'numpy.float64'>
# 51 - 0 - 13:nan   <class 'numpy.float64'>
# 51 - 0 - 14:nan   <class 'numpy.float64'>
# 51 - 0 - 15:nan   <class 'numpy.float64'>
# 51 - 0 - 16:nan   <class 'numpy.float64'>
# 51 - 0 - 17:5.0   <class 'numpy.float64'>
# 51 - 0 - 18:nan   <class 'numpy.float64'>
# 51 - 0 - 19:nan   <class 'numpy.float64'>
# 51 - 0 - 20:nan   <class 'numpy.float64'>
# 51 - 0 - 21:nan   <class 'numpy.float64'>
# 51 - 0 - 22:nan   <class 'numpy.float64'>
# 51 - 0 - 23:6.0   <class 'numpy.float64'>
# 51 - 0 - 24:nan   <class 'numpy.float64'>
# 51 - 0 - 25:nan   <class 'numpy.float64'>
# 51 - 0 - 26:nan   <class 'numpy.float64'>
# 51 - 0 - 27:nan   <class 'numpy.float64'>
# 51 - 0 - 28:nan   <class 'numpy.float64'>
# 51 - 0 - 29:nan   <class 'numpy.float64'>
# 51 - 1 - 0:nan   <class 'float'>
# 51 - 1 - 1:nan   <class 'float'>
# 51 - 1 - 2:nan   <class 'float'>
# 51 - 1 - 3:nan   <class 'float'>
# 51 - 1 - 4:nan   <class 'float'>
# использования   <class 'str'>
# 51 - 1 - 6:nan   <class 'float'>
# 51 - 1 - 7:nan   <class 'float'>
# 51 - 1 - 8:nan   <class 'float'>
# 51 - 1 - 9:nan   <class 'float'>
# 51 - 1 - 10:nan   <class 'float'>
# использования   <class 'str'>
# 51 - 1 - 12:nan   <class 'float'>
# 51 - 1 - 13:nan   <class 'float'>
# 51 - 1 - 14:nan   <class 'float'>
# 51 - 1 - 15:nan   <class 'float'>
# 51 - 1 - 16:nan   <class 'float'>
# использования   <class 'str'>
# 51 - 1 - 18:nan   <class 'float'>
# 51 - 1 - 19:nan   <class 'float'>
# 51 - 1 - 20:nan   <class 'float'>
# 51 - 1 - 21:nan   <class 'float'>
# 51 - 1 - 22:nan   <class 'float'>
# использования   <class 'str'>
# 51 - 1 - 24:nan   <class 'float'>
# 51 - 1 - 25:nan   <class 'float'>
# 51 - 1 - 26:nan   <class 'float'>
# 51 - 1 - 27:nan   <class 'float'>
# 51 - 1 - 28:nan   <class 'float'>
# 51 - 1 - 29:nan   <class 'float'>
# 51 - 2 - 0:nan   <class 'numpy.float64'>
# 51 - 2 - 1:nan   <class 'numpy.float64'>
# 51 - 2 - 2:nan   <class 'numpy.float64'>
# 51 - 2 - 3:nan   <class 'numpy.float64'>
# 51 - 2 - 4:nan   <class 'numpy.float64'>
# 51 - 2 - 5:1.0   <class 'numpy.float64'>
# 51 - 2 - 6:nan   <class 'numpy.float64'>
# 51 - 2 - 7:nan   <class 'numpy.float64'>
# 51 - 2 - 8:nan   <class 'numpy.float64'>
# 51 - 2 - 9:nan   <class 'numpy.float64'>
# 51 - 2 - 10:nan   <class 'numpy.float64'>
# 51 - 2 - 11:1.0   <class 'numpy.float64'>
# 51 - 2 - 12:nan   <class 'numpy.float64'>
# 51 - 2 - 13:nan   <class 'numpy.float64'>
# 51 - 2 - 14:nan   <class 'numpy.float64'>
# 51 - 2 - 15:nan   <class 'numpy.float64'>
# 51 - 2 - 16:nan   <class 'numpy.float64'>
# 51 - 2 - 17:1.0   <class 'numpy.float64'>
# 51 - 2 - 18:nan   <class 'numpy.float64'>
# 51 - 2 - 19:nan   <class 'numpy.float64'>
# 51 - 2 - 20:nan   <class 'numpy.float64'>
# 51 - 2 - 21:nan   <class 'numpy.float64'>
# 51 - 2 - 22:nan   <class 'numpy.float64'>
# 51 - 2 - 23:1.0   <class 'numpy.float64'>
# 51 - 2 - 24:nan   <class 'numpy.float64'>
# 51 - 2 - 25:nan   <class 'numpy.float64'>
# 51 - 2 - 26:nan   <class 'numpy.float64'>
# 51 - 2 - 27:nan   <class 'numpy.float64'>
# 51 - 2 - 28:nan   <class 'numpy.float64'>
# 51 - 2 - 29:nan   <class 'numpy.float64'>
# 51 - 3 - 0:nan   <class 'float'>
# 51 - 3 - 1:nan   <class 'float'>
# 51 - 3 - 2:nan   <class 'float'>
# 51 - 3 - 3:nan   <class 'float'>
# 51 - 3 - 4:nan   <class 'float'>
# 51 - 3 - 5:Секция А   <class 'str'>
# 51 - 3 - 6:nan   <class 'float'>
# 51 - 3 - 7:nan   <class 'float'>
# 51 - 3 - 8:nan   <class 'float'>
# 51 - 3 - 9:nan   <class 'float'>
# 51 - 3 - 10:nan   <class 'float'>
# 51 - 3 - 11:Секция Б   <class 'str'>
# 51 - 3 - 12:nan   <class 'float'>
# 51 - 3 - 13:nan   <class 'float'>
# 51 - 3 - 14:nan   <class 'float'>
# 51 - 3 - 15:nan   <class 'float'>
# 51 - 3 - 16:nan   <class 'float'>
# 51 - 3 - 17:Секция Б   <class 'str'>
# 51 - 3 - 18:nan   <class 'float'>
# 51 - 3 - 19:nan   <class 'float'>
# 51 - 3 - 20:nan   <class 'float'>
# 51 - 3 - 21:nan   <class 'float'>
# 51 - 3 - 22:nan   <class 'float'>
# 51 - 3 - 23:Секция Б   <class 'str'>
# 51 - 3 - 24:nan   <class 'float'>
# 51 - 3 - 25:nan   <class 'float'>
# 51 - 3 - 26:nan   <class 'float'>
# 51 - 3 - 27:nan   <class 'float'>
# 51 - 3 - 28:nan   <class 'float'>
# 51 - 3 - 29:nan   <class 'float'>
# 51 - 4 - 0:nan   <class 'numpy.float64'>
# 51 - 4 - 1:nan   <class 'numpy.float64'>
# 51 - 4 - 2:nan   <class 'numpy.float64'>
# 51 - 4 - 3:nan   <class 'numpy.float64'>
# 51 - 4 - 4:nan   <class 'numpy.float64'>
# 51 - 4 - 5:77.67   <class 'numpy.float64'>
# 51 - 4 - 6:nan   <class 'numpy.float64'>
# 51 - 7 - 28:nan   <class 'numpy.float64'>
# 51 - 7 - 29:nan   <class 'numpy.float64'>
# 52 - 0 - 0:nan   <class 'numpy.float64'>
# 52 - 0 - 1:7.0   <class 'numpy.float64'>
# 52 - 0 - 2:nan   <class 'numpy.float64'>
# 52 - 0 - 3:nan   <class 'numpy.float64'>
# 52 - 0 - 4:nan   <class 'numpy.float64'>
# 52 - 0 - 5:nan   <class 'numpy.float64'>
# 52 - 0 - 6:nan   <class 'numpy.float64'>
# 52 - 0 - 7:nan   <class 'numpy.float64'>
# 52 - 0 - 8:8.0   <class 'numpy.float64'>
# 52 - 0 - 9:nan   <class 'numpy.float64'>
# 52 - 0 - 10:nan   <class 'numpy.float64'>
# 52 - 0 - 11:nan   <class 'numpy.float64'>
# 52 - 0 - 12:nan   <class 'numpy.float64'>
# 52 - 0 - 13:9.0   <class 'numpy.float64'>
# 52 - 0 - 14:nan   <class 'numpy.float64'>
# 52 - 0 - 15:nan   <class 'numpy.float64'>
# 52 - 0 - 16:nan   <class 'numpy.float64'>
# 52 - 0 - 17:nan   <class 'numpy.float64'>
# 52 - 0 - 18:10.0   <class 'numpy.float64'>
# 52 - 0 - 19:nan   <class 'numpy.float64'>
# 52 - 0 - 20:nan   <class 'numpy.float64'>
# 52 - 0 - 21:nan   <class 'numpy.float64'>
# 52 - 0 - 22:nan   <class 'numpy.float64'>
# 52 - 0 - 23:nan   <class 'numpy.float64'>
# 52 - 0 - 24:nan   <class 'numpy.float64'>
# 52 - 0 - 25:11.0   <class 'numpy.float64'>
# 52 - 0 - 26:nan   <class 'numpy.float64'>
# 52 - 0 - 27:nan   <class 'numpy.float64'>
# 52 - 0 - 28:nan   <class 'numpy.float64'>
# 52 - 1 - 0:nan   <class 'float'>
# использования   <class 'str'>
# 52 - 1 - 2:nan   <class 'float'>
# 52 - 1 - 3:nan   <class 'float'>
# 52 - 1 - 4:nan   <class 'float'>
# 52 - 1 - 5:nan   <class 'float'>
# 52 - 1 - 6:nan   <class 'float'>
# 52 - 1 - 7:nan   <class 'float'>
# использования   <class 'str'>
# 52 - 1 - 9:nan   <class 'float'>
# 52 - 1 - 10:nan   <class 'float'>
# 52 - 1 - 11:nan   <class 'float'>
# 52 - 1 - 12:nan   <class 'float'>
# использования   <class 'str'>
# 52 - 1 - 14:nan   <class 'float'>
# 52 - 1 - 15:nan   <class 'float'>
# 52 - 1 - 16:nan   <class 'float'>
# 52 - 1 - 17:nan   <class 'float'>
# использования   <class 'str'>
# 52 - 1 - 19:nan   <class 'float'>
# 52 - 1 - 20:nan   <class 'float'>
# 52 - 1 - 21:nan   <class 'float'>
# 52 - 1 - 22:nan   <class 'float'>
# 52 - 1 - 23:nan   <class 'float'>
# 52 - 1 - 24:nan   <class 'float'>
# использования   <class 'str'>
# 52 - 1 - 26:nan   <class 'float'>
# 52 - 1 - 27:nan   <class 'float'>
# 52 - 1 - 28:nan   <class 'float'>
# 52 - 2 - 0:nan   <class 'numpy.float64'>
# 52 - 2 - 1:1.0   <class 'numpy.float64'>
# 52 - 2 - 2:nan   <class 'numpy.float64'>
# 52 - 2 - 3:nan   <class 'numpy.float64'>
# 52 - 2 - 4:nan   <class 'numpy.float64'>
# 52 - 2 - 5:nan   <class 'numpy.float64'>
# 52 - 2 - 6:nan   <class 'numpy.float64'>
# 52 - 2 - 7:nan   <class 'numpy.float64'>
# 52 - 2 - 8:1.0   <class 'numpy.float64'>
# 52 - 2 - 9:nan   <class 'numpy.float64'>
# 52 - 2 - 10:nan   <class 'numpy.float64'>
# 52 - 2 - 11:nan   <class 'numpy.float64'>
# 52 - 2 - 12:nan   <class 'numpy.float64'>
# 52 - 2 - 13:1.0   <class 'numpy.float64'>
# 52 - 2 - 14:nan   <class 'numpy.float64'>
# 52 - 2 - 15:nan   <class 'numpy.float64'>
# 52 - 2 - 16:nan   <class 'numpy.float64'>
# 52 - 2 - 17:nan   <class 'numpy.float64'>
# 52 - 2 - 18:1.0   <class 'numpy.float64'>
# 52 - 2 - 19:nan   <class 'numpy.float64'>
# 52 - 2 - 20:nan   <class 'numpy.float64'>
# 52 - 2 - 21:nan   <class 'numpy.float64'>
# 52 - 2 - 22:nan   <class 'numpy.float64'>
# 52 - 2 - 23:nan   <class 'numpy.float64'>
# 52 - 2 - 24:nan   <class 'numpy.float64'>
# 52 - 2 - 25:1.0   <class 'numpy.float64'>
# 52 - 2 - 26:nan   <class 'numpy.float64'>
# 52 - 2 - 27:nan   <class 'numpy.float64'>
# 52 - 2 - 28:nan   <class 'numpy.float64'>
# 52 - 3 - 0:nan   <class 'float'>
# 52 - 3 - 1:Секция Б   <class 'str'>
# 52 - 3 - 2:nan   <class 'float'>
# 52 - 3 - 3:nan   <class 'float'>
# 52 - 3 - 4:nan   <class 'float'>
# 52 - 3 - 5:nan   <class 'float'>
# 52 - 3 - 6:nan   <class 'float'>
# 52 - 3 - 7:nan   <class 'float'>
# 52 - 3 - 8:Секция В   <class 'str'>
# 52 - 3 - 9:nan   <class 'float'>
# 52 - 3 - 10:nan   <class 'float'>
# 52 - 3 - 11:nan   <class 'float'>
# 52 - 3 - 12:nan   <class 'float'>
# 52 - 3 - 13:Секция В   <class 'str'>
# 52 - 3 - 14:nan   <class 'float'>
# 52 - 3 - 15:nan   <class 'float'>
# 52 - 3 - 16:nan   <class 'float'>
# 52 - 3 - 17:nan   <class 'float'>
# 52 - 3 - 18:Секция В   <class 'str'>
# 52 - 3 - 19:nan   <class 'float'>
# 52 - 3 - 20:nan   <class 'float'>
# 52 - 3 - 21:nan   <class 'float'>
# 52 - 3 - 22:nan   <class 'float'>
# 52 - 3 - 23:nan   <class 'float'>
# 52 - 3 - 24:nan   <class 'float'>
# 52 - 3 - 25:Секция В   <class 'str'>
# 52 - 3 - 26:nan   <class 'float'>
# 52 - 3 - 27:nan   <class 'float'>
# 52 - 3 - 28:nan   <class 'float'>
# 52 - 4 - 0:nan   <class 'numpy.float64'>
# 52 - 4 - 1:103.89   <class 'numpy.float64'>
# 52 - 4 - 2:nan   <class 'numpy.float64'>
# 52 - 7 - 26:nan   <class 'numpy.float64'>
# 52 - 7 - 27:nan   <class 'numpy.float64'>
# 52 - 7 - 28:nan   <class 'numpy.float64'>
# 53 - 0 - 0:nan   <class 'numpy.float64'>
# 53 - 0 - 1:nan   <class 'numpy.float64'>
# 53 - 0 - 2:nan   <class 'numpy.float64'>
# 53 - 0 - 3:nan   <class 'numpy.float64'>
# 53 - 0 - 4:nan   <class 'numpy.float64'>
# 53 - 0 - 5:nan   <class 'numpy.float64'>
# 53 - 0 - 6:nan   <class 'numpy.float64'>
# 53 - 0 - 7:nan   <class 'numpy.float64'>
# 53 - 0 - 8:12.0   <class 'numpy.float64'>
# 53 - 0 - 9:nan   <class 'numpy.float64'>
# 53 - 0 - 10:nan   <class 'numpy.float64'>
# 53 - 0 - 11:nan   <class 'numpy.float64'>
# 53 - 0 - 12:nan   <class 'numpy.float64'>
# 53 - 0 - 13:nan   <class 'numpy.float64'>
# 53 - 0 - 14:nan   <class 'numpy.float64'>
# 53 - 0 - 15:nan   <class 'numpy.float64'>
# 53 - 0 - 16:13.0   <class 'numpy.float64'>
# 53 - 0 - 17:nan   <class 'numpy.float64'>
# 53 - 0 - 18:nan   <class 'numpy.float64'>
# 53 - 0 - 19:nan   <class 'numpy.float64'>
# 53 - 0 - 20:nan   <class 'numpy.float64'>
# 53 - 0 - 21:nan   <class 'numpy.float64'>
# 53 - 0 - 22:nan   <class 'numpy.float64'>
# 53 - 0 - 23:14.0   <class 'numpy.float64'>
# 53 - 0 - 24:nan   <class 'numpy.float64'>
# 53 - 0 - 25:nan   <class 'numpy.float64'>
# 53 - 0 - 26:nan   <class 'numpy.float64'>
# 53 - 0 - 27:nan   <class 'numpy.float64'>
# 53 - 0 - 28:nan   <class 'numpy.float64'>
# 53 - 0 - 29:nan   <class 'numpy.float64'>
# 53 - 1 - 0:nan   <class 'float'>
# 53 - 1 - 1:nan   <class 'float'>
# 53 - 1 - 2:nan   <class 'float'>
# 53 - 1 - 3:nan   <class 'float'>
# 53 - 1 - 4:nan   <class 'float'>
# 53 - 1 - 5:nan   <class 'float'>
# 53 - 1 - 6:nan   <class 'float'>
# 53 - 1 - 7:nan   <class 'float'>
# использования   <class 'str'>
# 53 - 1 - 9:nan   <class 'float'>
# 53 - 1 - 10:nan   <class 'float'>
# 53 - 1 - 11:nan   <class 'float'>
# 53 - 1 - 12:nan   <class 'float'>
# 53 - 1 - 13:nan   <class 'float'>
# 53 - 1 - 14:nan   <class 'float'>
# 53 - 1 - 15:nan   <class 'float'>
# использования   <class 'str'>
# 53 - 1 - 17:nan   <class 'float'>
# 53 - 1 - 18:nan   <class 'float'>
# 53 - 1 - 19:nan   <class 'float'>
# 53 - 1 - 20:nan   <class 'float'>
# 53 - 1 - 21:nan   <class 'float'>
# 53 - 1 - 22:nan   <class 'float'>
# использования   <class 'str'>
# 53 - 1 - 24:nan   <class 'float'>
# 53 - 1 - 25:nan   <class 'float'>
# 53 - 1 - 26:nan   <class 'float'>
# 53 - 1 - 27:nan   <class 'float'>
# 53 - 1 - 28:nan   <class 'float'>
# 53 - 1 - 29:nan   <class 'float'>
# 53 - 2 - 0:nan   <class 'numpy.float64'>
# 53 - 2 - 1:nan   <class 'numpy.float64'>
# 53 - 2 - 2:nan   <class 'numpy.float64'>
# 53 - 2 - 3:nan   <class 'numpy.float64'>
# 53 - 2 - 4:nan   <class 'numpy.float64'>
# 53 - 2 - 5:nan   <class 'numpy.float64'>
# 53 - 2 - 6:nan   <class 'numpy.float64'>
# 53 - 2 - 7:nan   <class 'numpy.float64'>
# 53 - 2 - 8:1.0   <class 'numpy.float64'>
# 53 - 2 - 9:nan   <class 'numpy.float64'>
# 53 - 2 - 10:nan   <class 'numpy.float64'>
# 53 - 2 - 11:nan   <class 'numpy.float64'>
# 53 - 2 - 12:nan   <class 'numpy.float64'>
# 53 - 2 - 13:nan   <class 'numpy.float64'>
# 53 - 2 - 14:nan   <class 'numpy.float64'>
# 53 - 2 - 15:nan   <class 'numpy.float64'>
# 53 - 2 - 16:1.0   <class 'numpy.float64'>
# 53 - 2 - 17:nan   <class 'numpy.float64'>
# 53 - 2 - 18:nan   <class 'numpy.float64'>
# 53 - 2 - 19:nan   <class 'numpy.float64'>
# 53 - 2 - 20:nan   <class 'numpy.float64'>
# 53 - 2 - 21:nan   <class 'numpy.float64'>
# 53 - 2 - 22:nan   <class 'numpy.float64'>
# 53 - 2 - 23:1.0   <class 'numpy.float64'>
# 53 - 2 - 24:nan   <class 'numpy.float64'>
# 53 - 2 - 25:nan   <class 'numpy.float64'>
# 53 - 2 - 26:nan   <class 'numpy.float64'>
# 53 - 2 - 27:nan   <class 'numpy.float64'>
# 53 - 2 - 28:nan   <class 'numpy.float64'>
# 53 - 2 - 29:nan   <class 'numpy.float64'>
# 53 - 3 - 0:nan   <class 'float'>
# 53 - 3 - 1:nan   <class 'float'>
# 53 - 3 - 2:nan   <class 'float'>
# 53 - 3 - 3:nan   <class 'float'>
# 53 - 3 - 4:nan   <class 'float'>
# 53 - 3 - 5:nan   <class 'float'>
# 53 - 3 - 6:nan   <class 'float'>
# 53 - 3 - 7:nan   <class 'float'>
# 53 - 3 - 8:Секция Г   <class 'str'>
# 53 - 3 - 9:nan   <class 'float'>
# 53 - 3 - 10:nan   <class 'float'>
# 53 - 3 - 11:nan   <class 'float'>
# 53 - 3 - 12:nan   <class 'float'>
# 53 - 3 - 13:nan   <class 'float'>
# 53 - 3 - 14:nan   <class 'float'>
# 53 - 3 - 15:nan   <class 'float'>
# 53 - 3 - 16:Секция Г   <class 'str'>
# 53 - 3 - 17:nan   <class 'float'>
# 53 - 3 - 18:nan   <class 'float'>
# 53 - 3 - 19:nan   <class 'float'>
# 53 - 3 - 20:nan   <class 'float'>
# 53 - 3 - 21:nan   <class 'float'>
# 53 - 3 - 22:nan   <class 'float'>
# 53 - 3 - 23:Секция Г   <class 'str'>
# 53 - 3 - 24:nan   <class 'float'>
# 53 - 3 - 25:nan   <class 'float'>
# 53 - 3 - 26:nan   <class 'float'>
# 53 - 3 - 27:nan   <class 'float'>
# 54 - 0 - 27:19 Незадымляемая лестничная клетка Секция А. 2 этаж. Общественное   <class 'str'>
# 54 - 0 - 28:20 Тамбур Секция А. 2 этаж. Общественное   <class 'str'>
# 54 - 0 - 29:21 Помещение для размещения коммуникаций Секция А. 3 этаж. Техническое   <class 'str'>
# 54 - 0 - 30:22 Межквартирный коридор Секция А. 3 этаж. Общественное   <class 'str'>
# 54 - 0 - 31:23 Лифтовой холл Секция А. 3 этаж. Общественное   <class 'str'>
# 54 - 0 - 32:24 Воздушная зона Секция А. 3 этаж. Общественное   <class 'str'>
# 54 - 0 - 33:25 Безопасная зона для МГН Секция А. 3 этаж. Общественное   <class 'str'>
# 54 - 1 - 0:nan   <class 'numpy.float64'>
# 54 - 1 - 1:nan   <class 'numpy.float64'>
# 54 - 1 - 2:nan   <class 'numpy.float64'>
# 54 - 1 - 3:nan   <class 'numpy.float64'>
# 54 - 1 - 4:nan   <class 'numpy.float64'>
# 54 - 1 - 5:nan   <class 'numpy.float64'>
# 54 - 1 - 6:nan   <class 'numpy.float64'>
# 54 - 1 - 7:nan   <class 'numpy.float64'>
# 54 - 1 - 8:nan   <class 'numpy.float64'>
# 54 - 1 - 9:456.36   <class 'numpy.float64'>
# 54 - 1 - 10:12.46   <class 'numpy.float64'>
# 54 - 1 - 11:14.12   <class 'numpy.float64'>
# 54 - 1 - 12:7.18   <class 'numpy.float64'>
# 54 - 1 - 13:8.3   <class 'numpy.float64'>
# 54 - 1 - 14:14.12   <class 'numpy.float64'>
# 54 - 1 - 15:4.43   <class 'numpy.float64'>
# 54 - 1 - 16:24.49   <class 'numpy.float64'>
# 54 - 1 - 17:3.09   <class 'numpy.float64'>
# 54 - 1 - 18:8.1   <class 'numpy.float64'>
# 54 - 1 - 19:9.42   <class 'numpy.float64'>
# 54 - 1 - 20:14.35   <class 'numpy.float64'>
# 54 - 1 - 21:5.88   <class 'numpy.float64'>
# 54 - 1 - 22:3.09   <class 'numpy.float64'>
# 54 - 1 - 23:40.78   <class 'numpy.float64'>
# 54 - 1 - 24:7.62   <class 'numpy.float64'>
# 54 - 1 - 25:8.55   <class 'numpy.float64'>
# 54 - 1 - 26:2.78   <class 'numpy.float64'>
# 54 - 1 - 27:14.35   <class 'numpy.float64'>
# 54 - 1 - 28:5.54   <class 'numpy.float64'>
# 54 - 1 - 29:3.09   <class 'numpy.float64'>
# 54 - 1 - 30:40.78   <class 'numpy.float64'>
# 54 - 1 - 31:7.62   <class 'numpy.float64'>
# 54 - 1 - 32:8.55   <class 'numpy.float64'>
# 54 - 1 - 33:2.78   <class 'numpy.float64'>
# 55 - 0 - 0:26   <class 'numpy.int64'>
# 55 - 0 - 1:27   <class 'numpy.int64'>
# 55 - 0 - 2:28   <class 'numpy.int64'>
# 55 - 0 - 3:29   <class 'numpy.int64'>
# 55 - 0 - 4:30   <class 'numpy.int64'>
# 55 - 0 - 5:31   <class 'numpy.int64'>
# 55 - 0 - 6:32   <class 'numpy.int64'>
# 55 - 0 - 7:33   <class 'numpy.int64'>
# 55 - 0 - 8:34   <class 'numpy.int64'>
# 55 - 0 - 9:35   <class 'numpy.int64'>
# 55 - 0 - 10:36   <class 'numpy.int64'>
# 55 - 0 - 11:37   <class 'numpy.int64'>
# 55 - 0 - 12:38   <class 'numpy.int64'>
# 55 - 0 - 13:39   <class 'numpy.int64'>
# 55 - 0 - 14:40   <class 'numpy.int64'>
# 55 - 0 - 15:41   <class 'numpy.int64'>
# 55 - 0 - 16:42   <class 'numpy.int64'>
# 55 - 0 - 17:43   <class 'numpy.int64'>
# 55 - 0 - 18:44   <class 'numpy.int64'>
# 55 - 0 - 19:45   <class 'numpy.int64'>
# 55 - 0 - 20:46   <class 'numpy.int64'>
# 55 - 0 - 21:47   <class 'numpy.int64'>
# 55 - 0 - 22:48   <class 'numpy.int64'>
# 55 - 0 - 23:49   <class 'numpy.int64'>
# 55 - 0 - 24:50   <class 'numpy.int64'>
# 55 - 0 - 25:51   <class 'numpy.int64'>
# 55 - 0 - 26:52   <class 'numpy.int64'>
# 55 - 0 - 27:53   <class 'numpy.int64'>
# 55 - 0 - 28:54   <class 'numpy.int64'>
# 55 - 0 - 29:55   <class 'numpy.int64'>
# 55 - 0 - 30:56   <class 'numpy.int64'>
# 55 - 0 - 31:57   <class 'numpy.int64'>
# 55 - 0 - 32:58   <class 'numpy.int64'>
# 55 - 1 - 0:Незадымляемая лестничная клетка   <class 'str'>
# 55 - 1 - 1:Тамбур   <class 'str'>
# 55 - 1 - 2:Помещение для размещения коммуникаций   <class 'str'>
# 55 - 1 - 3:Межквартирный коридор   <class 'str'>
# 55 - 1 - 4:Лифтовой холл   <class 'str'>
# 55 - 1 - 5:Воздушная зона   <class 'str'>
# 55 - 1 - 6:Безопасная зона для МГН   <class 'str'>
# 55 - 1 - 7:Незадымляемая лестничная клетка   <class 'str'>
# 55 - 1 - 8:Тамбур   <class 'str'>
# 55 - 1 - 9:Помещение для размещения коммуникаций   <class 'str'>
# 55 - 1 - 10:Межквартирный коридор   <class 'str'>
# 55 - 1 - 11:Лифтовой холл   <class 'str'>
# 55 - 1 - 12:Воздушная зона   <class 'str'>
# 55 - 1 - 13:Безопасная зона для МГН   <class 'str'>
# 55 - 1 - 14:Незадымляемая лестничная клетка   <class 'str'>
# 55 - 1 - 15:Тамбур   <class 'str'>
# 55 - 1 - 16:Помещение для размещения коммуникаций   <class 'str'>
# 55 - 1 - 17:Межквартирный коридор   <class 'str'>
# 55 - 1 - 18:Лифтовой холл   <class 'str'>
# 55 - 1 - 19:Воздушная зона   <class 'str'>
# 55 - 1 - 20:Безопасная зона для МГН   <class 'str'>
# 55 - 1 - 21:Незадымляемая лестничная клетка   <class 'str'>
# 55 - 1 - 22:Тамбур   <class 'str'>
# 55 - 1 - 23:Помещение для размещения коммуникаций   <class 'str'>
# 55 - 1 - 24:Межквартирный коридор   <class 'str'>
# 55 - 1 - 25:Лифтовой холл   <class 'str'>
# 55 - 1 - 26:Воздушная зона   <class 'str'>
# 55 - 1 - 27:Безопасная зона для МГН   <class 'str'>
# 56 - 0 - 1:60   <class 'numpy.int64'>
# 56 - 0 - 2:61   <class 'numpy.int64'>
# 56 - 0 - 3:62   <class 'numpy.int64'>
# 56 - 0 - 4:63   <class 'numpy.int64'>
# 56 - 0 - 5:64   <class 'numpy.int64'>
# 56 - 0 - 6:65   <class 'numpy.int64'>
# 56 - 0 - 7:66   <class 'numpy.int64'>
# 56 - 0 - 8:67   <class 'numpy.int64'>
# 56 - 0 - 9:68   <class 'numpy.int64'>
# 56 - 0 - 10:69   <class 'numpy.int64'>
# 56 - 0 - 11:70   <class 'numpy.int64'>
# 56 - 0 - 12:71   <class 'numpy.int64'>
# 56 - 0 - 13:72   <class 'numpy.int64'>
# 56 - 0 - 14:73   <class 'numpy.int64'>
# 56 - 0 - 15:74   <class 'numpy.int64'>
# 56 - 0 - 16:75   <class 'numpy.int64'>
# 56 - 0 - 17:76   <class 'numpy.int64'>
# 56 - 0 - 18:77   <class 'numpy.int64'>
# 56 - 0 - 19:78   <class 'numpy.int64'>
# 56 - 0 - 20:79   <class 'numpy.int64'>
# 56 - 0 - 21:80   <class 'numpy.int64'>
# 56 - 0 - 22:81   <class 'numpy.int64'>
# 56 - 0 - 23:82   <class 'numpy.int64'>
# 56 - 0 - 24:83   <class 'numpy.int64'>
# 56 - 0 - 25:84   <class 'numpy.int64'>
# 56 - 0 - 26:85   <class 'numpy.int64'>
# 56 - 0 - 27:86   <class 'numpy.int64'>
# 56 - 0 - 28:87   <class 'numpy.int64'>
# 56 - 0 - 29:88   <class 'numpy.int64'>
# 56 - 0 - 30:89   <class 'numpy.int64'>
# 56 - 0 - 31:90   <class 'numpy.int64'>
# 56 - 0 - 32:91   <class 'numpy.int64'>
# 56 - 1 - 0:Воздушная зона   <class 'str'>
# 56 - 1 - 1:Безопасная зона для МГН   <class 'str'>
# 56 - 1 - 2:Незадымляемая лестничная клетка   <class 'str'>
# 56 - 1 - 3:Тамбур   <class 'str'>
# 56 - 1 - 4:Помещение для размещения коммуникаций   <class 'str'>
# 56 - 1 - 5:Межквартирный коридор   <class 'str'>
# 56 - 1 - 6:Лифтовой холл   <class 'str'>
# 56 - 1 - 7:Воздушная зона   <class 'str'>
# 56 - 1 - 8:Безопасная зона для МГН   <class 'str'>
# 56 - 1 - 9:Незадымляемая лестничная клетка   <class 'str'>
# 56 - 1 - 10:Тамбур   <class 'str'>
# 56 - 1 - 11:Помещение для размещения коммуникаций   <class 'str'>
# 56 - 1 - 12:Межквартирный коридор   <class 'str'>
# 56 - 1 - 13:Лифтовой холл   <class 'str'>
# 56 - 1 - 14:Воздушная зона   <class 'str'>
# 56 - 1 - 15:Безопасная зона для МГН   <class 'str'>
# 56 - 1 - 16:Незадымляемая лестничная клетка   <class 'str'>
# 56 - 1 - 17:Тамбур   <class 'str'>
# 56 - 1 - 18:Помещение для размещения коммуникаций   <class 'str'>
# 56 - 1 - 19:Межквартирный коридор   <class 'str'>
# 56 - 1 - 20:Лифтовой холл   <class 'str'>
# 56 - 1 - 21:Воздушная зона   <class 'str'>
# 56 - 3 - 4:Техническое   <class 'str'>
# 56 - 3 - 5:Общественное   <class 'str'>
# 56 - 3 - 6:Общественное   <class 'str'>
# 56 - 3 - 7:Общественное   <class 'str'>
# 56 - 3 - 8:Общественное   <class 'str'>
# 56 - 3 - 9:Общественное   <class 'str'>
# 56 - 3 - 10:Общественное   <class 'str'>
# ...
# 81 - 0 - 13:(создания) многоквартирного   <class 'str'>
# 81 - 0 - 14:дома и (или) иного объекта   <class 'str'>
# 81 - 0 - 15:недвижимости   <class 'str'>
# 81 - 0 - 16:20.1.2   <class 'str'>
# 81 - 0 - 17:Организационно-правовая форма организации, у которой привлекаются денежные   <class 'str'>
# 81 - 0 - 18:средства:   <class 'str'>
# 81 - 0 - 19:20.1.3   <class 'str'>
# 81 - 0 - 20:Полное наименование организации, у которой привлекаются денежные средства, без   <class 'str'>
# 81 - 0 - 21:указания организационно-правовой формы:   <class 'str'>
# 81 - 0 - 22:20.1.4   <class 'str'>
# 81 - 0 - 23:Идентификационный номер налогоплательщика организации, у которой привлекаются   <class 'str'>
# 81 - 0 - 24:денежные средства:   <class 'str'>
# 81 - 0 - 25:20.1.5 Сумма привлеченных средств:   <class 'str'>
# 81 - 0 - 26:20.1.6 Определенный соглашением или сделкой срок возврата привлеченных средств:   <class 'str'>
# 81 - 0 - 27:20.1.7   <class 'str'>
# 81 - 0 - 28:Кадастровый номер земельного участка, являющегося предметом залога в обеспечение   <class 'str'>
# 81 - 0 - 29:исполнения обязательства по возврату привлеченных средств:   <class 'str'>
# 81 - 0 - 30:21 О размере полностью оплаченного уставного капитала застройщика   <class 'str'>
# 81 - 0 - 31:21.1 О размере полностью   <class 'str'>
# 81 - 0 - 32:Размер полностью оплаченного уставного капитала застройщика:   <class 'str'>
# 81 - 0 - 33:оплаченного уставного капитала 21.1.1   <class 'str'>
# 81 - 0 - 34:10 000,00 руб.   <class 'str'>
# 81 - 0 - 35:застройщика   <class 'str'>
# 81 - 0 - 36:22 Информация об объекте социальной инфраструктуры, затраты на строительство, реконструкцию, на уплату процентов и суммы   <class 'str'>
# 81 - 0 - 37:основного долга, по целевым кредитам (целевым займам) на строительство, реконструкцию которого планируется возмещать частично   <class 'str'>
# 81 - 0 - 38:или полностью за счет денежных средств, уплачиваемых участниками долевого строительства по договору   <class 'str'>
# 81 - 0 - 39:22.1 О виде, назначении объекта   <class 'str'>
# 81 - 0 - 40:социальной инфраструктуры. Об   <class 'str'>
# 81 - 0 - 41:указанных в частях 3 и 4 статьи   <class 'str'>
# 82 - 0 - 0:nan   <class 'numpy.float64'>
# 82 - 0 - 1:nan   <class 'numpy.float64'>
# 82 - 0 - 2:nan   <class 'numpy.float64'>
# 82 - 0 - 3:nan   <class 'numpy.float64'>
# 82 - 0 - 4:nan   <class 'numpy.float64'>
# 82 - 0 - 5:nan   <class 'numpy.float64'>
# 82 - 0 - 6:nan   <class 'numpy.float64'>
# 82 - 0 - 7:nan   <class 'numpy.float64'>
# 82 - 0 - 8:nan   <class 'numpy.float64'>
# 82 - 0 - 9:nan   <class 'numpy.float64'>
# 82 - 0 - 10:nan   <class 'numpy.float64'>
# 82 - 0 - 11:nan   <class 'numpy.float64'>
# 82 - 0 - 12:nan   <class 'numpy.float64'>
# 82 - 0 - 13:nan   <class 'numpy.float64'>
# 82 - 1 - 0:средств, уплачиваемых всеми   <class 'str'>
# 82 - 1 - 1:nan   <class 'float'>
# 82 - 1 - 2:nan   <class 'float'>
# 82 - 1 - 3:nan   <class 'float'>
# 82 - 1 - 4:nan   <class 'float'>
# 82 - 1 - 5:nan   <class 'float'>
# 82 - 1 - 6:nan   <class 'float'>
# 82 - 1 - 7:nan   <class 'float'>
# 82 - 1 - 8:23 Иная, не противоречащая законодательству, информация о проекте   <class 'str'>
# 82 - 1 - 9:23.1 Иная информация о проекте   <class 'str'>
# 82 - 1 - 10:24 Сведения о фактах внесения изменений в проектную документацию   <class 'str'>
# документацию   <class 'str'>
# 82 - 1 - 12:No   <class 'str'>
# 82 - 1 - 13:1   <class 'str'>
# 82 - 2 - 0:nan   <class 'numpy.float64'>
# 82 - 2 - 1:nan   <class 'numpy.float64'>
# 82 - 2 - 2:nan   <class 'numpy.float64'>
# 82 - 2 - 3:nan   <class 'numpy.float64'>
# 82 - 2 - 4:nan   <class 'numpy.float64'>
# 82 - 2 - 5:nan   <class 'numpy.float64'>
# 82 - 2 - 6:nan   <class 'numpy.float64'>
# 82 - 2 - 7:nan   <class 'numpy.float64'>
# 82 - 2 - 8:nan   <class 'numpy.float64'>
# 82 - 2 - 9:nan   <class 'numpy.float64'>
# 82 - 2 - 10:nan   <class 'numpy.float64'>
# 82 - 2 - 11:nan   <class 'numpy.float64'>
# 82 - 2 - 12:nan   <class 'numpy.float64'>
# 82 - 2 - 13:nan   <class 'numpy.float64'>
# 82 - 3 - 0:nan   <class 'float'>
# 82 - 3 - 1:22.1.2   <class 'str'>
# 82 - 3 - 2:22.1.3   <class 'str'>
# 82 - 3 - 3:22.1.4   <class 'str'>
# 82 - 3 - 4:22.1.5   <class 'str'>
# 82 - 3 - 5:22.1.6   <class 'str'>
# 82 - 3 - 6:22.1.7   <class 'str'>
# 82 - 3 - 7:22.1.8   <class 'str'>
# 82 - 3 - 8:nan   <class 'float'>
# 82 - 3 - 9:23.1.1   <class 'str'>
# 82 - 3 - 10:nan   <class 'float'>
# 82 - 3 - 11:24.1.1   <class 'str'>
# 82 - 3 - 12:Дата   <class 'str'>
# 82 - 3 - 13:20.07.2022   <class 'str'>
# 82 - 4 - 0:nan   <class 'numpy.float64'>
# 82 - 4 - 1:nan   <class 'numpy.float64'>
# 82 - 4 - 2:nan   <class 'numpy.float64'>
# 82 - 4 - 3:nan   <class 'numpy.float64'>
# 82 - 4 - 4:nan   <class 'numpy.float64'>
# 82 - 4 - 5:nan   <class 'numpy.float64'>
# 82 - 4 - 6:nan   <class 'numpy.float64'>
# 82 - 4 - 7:nan   <class 'numpy.float64'>
# 82 - 4 - 8:nan   <class 'numpy.float64'>
# 82 - 4 - 9:nan   <class 'numpy.float64'>
# 82 - 4 - 10:nan   <class 'numpy.float64'>
# 82 - 4 - 11:nan   <class 'numpy.float64'>
# 82 - 4 - 12:nan   <class 'numpy.float64'>
# 82 - 4 - 13:nan   <class 'numpy.float64'>
# 82 - 5 - 0:nan   <class 'float'>
# 82 - 5 - 1:Вид объекта социальной инфраструктуры:   <class 'str'>
# 82 - 5 - 2:Назначение объекта социальной инфраструктуры:   <class 'str'>
# социальной инфраструктуры в государственную или муниципальную собственность:   <class 'str'>
# социальной инфраструктуры в государственную или муниципальную собственность:   <class 'str'>
# инфраструктуры в государственную или муниципальную собственность:   <class 'str'>
# собственность:   <class 'str'>
# 82 - 5 - 7:Цели затрат застройщика:   <class 'str'>
# 82 - 5 - 8:nan   <class 'float'>
# 82 - 5 - 9:Иная информация о проекте:   <class 'str'>
# 82 - 5 - 10:nan   <class 'float'>
# 82 - 5 - 11:nan   <class 'float'>
# документации   <class 'str'>
# 82 - 5 - 13:11.1 (2) О разрешении на строительство   <class 'str'>
# 82 - 6 - 0:nan   <class 'numpy.float64'>
# 82 - 6 - 1:nan   <class 'numpy.float64'>
# 82 - 6 - 2:nan   <class 'numpy.float64'>
# 82 - 6 - 3:nan   <class 'numpy.float64'>
# 82 - 6 - 4:nan   <class 'numpy.float64'>
# 82 - 6 - 5:nan   <class 'numpy.float64'>
# 82 - 6 - 6:nan   <class 'numpy.float64'>
# 82 - 6 - 7:nan   <class 'numpy.float64'>
# 82 - 6 - 8:nan   <class 'numpy.float64'>
# 82 - 6 - 9:nan   <class 'numpy.float64'>
# 82 - 6 - 10:nan   <class 'numpy.float64'>
# 82 - 6 - 11:nan   <class 'numpy.float64'>
# 82 - 6 - 12:nan   <class 'numpy.float64'>
# 82 - 6 - 13:nan   <class 'numpy.float64'>
# 82 - 7 - 0:nan   <class 'float'>
# 82 - 7 - 1:nan   <class 'float'>
# 82 - 7 - 2:nan   <class 'float'>
# 82 - 7 - 3:nan   <class 'float'>
# 82 - 7 - 4:nan   <class 'float'>
# 82 - 7 - 5:nan   <class 'float'>
# 82 - 7 - 6:nan   <class 'float'>
# 82 - 7 - 7:nan   <class 'float'>
# 82 - 7 - 8:nan   <class 'float'>
# 82 - 7 - 9:nan   <class 'float'>
# 82 - 7 - 10:nan   <class 'float'>
# 82 - 7 - 11:nan   <class 'float'>
# 82 - 7 - 12:Описание изменений   <class 'str'>
# Выписка_ЕГРН_зу_63-01-0407002-1605-63-466-2022-1   <class 'str'>
# 82 - 8 - 0:nan   <class 'numpy.float64'>
# 82 - 8 - 1:nan   <class 'numpy.float64'>
# 82 - 8 - 2:nan   <class 'numpy.float64'>
# 82 - 8 - 3:nan   <class 'numpy.float64'>
# 82 - 8 - 4:nan   <class 'numpy.float64'>
# 82 - 8 - 5:nan   <class 'numpy.float64'>
# 82 - 8 - 6:nan   <class 'numpy.float64'>
# 82 - 8 - 7:nan   <class 'numpy.float64'>
# 82 - 8 - 8:nan   <class 'numpy.float64'>
# 82 - 8 - 9:nan   <class 'numpy.float64'>
# 82 - 8 - 10:nan   <class 'numpy.float64'>
# 82 - 8 - 11:nan   <class 'numpy.float64'>
# 82 - 8 - 12:nan   <class 'numpy.float64'>
# 82 - 8 - 13:nan   <class 'numpy.float64'>
# 83 - 0 - 0:nan   <class 'numpy.float64'>
# 83 - 0 - 1:nan   <class 'numpy.float64'>
# 83 - 0 - 2:nan   <class 'numpy.float64'>
# 83 - 0 - 3:nan   <class 'numpy.float64'>
# 83 - 0 - 4:nan   <class 'numpy.float64'>
# 83 - 0 - 5:2.0   <class 'numpy.float64'>
# 83 - 0 - 6:nan   <class 'numpy.float64'>
# 83 - 0 - 7:nan   <class 'numpy.float64'>
# 83 - 0 - 8:nan   <class 'numpy.float64'>
# 83 - 0 - 9:nan   <class 'numpy.float64'>
# 83 - 0 - 10:nan   <class 'numpy.float64'>
# 83 - 0 - 11:3.0   <class 'numpy.float64'>
# 83 - 0 - 12:nan   <class 'numpy.float64'>
# 83 - 0 - 13:nan   <class 'numpy.float64'>
# 83 - 0 - 14:4.0   <class 'numpy.float64'>
# 83 - 0 - 15:nan   <class 'numpy.float64'>
# 83 - 0 - 16:nan   <class 'numpy.float64'>
# 83 - 0 - 17:nan   <class 'numpy.float64'>
# 83 - 0 - 18:5.0   <class 'numpy.float64'>
# 83 - 0 - 19:nan   <class 'numpy.float64'>
# 83 - 0 - 20:nan   <class 'numpy.float64'>
# 83 - 0 - 21:nan   <class 'numpy.float64'>
# 83 - 0 - 22:nan   <class 'numpy.float64'>
# 83 - 0 - 23:nan   <class 'numpy.float64'>
# 83 - 0 - 24:nan   <class 'numpy.float64'>
# 83 - 0 - 25:nan   <class 'numpy.float64'>
# 83 - 0 - 26:6.0   <class 'numpy.float64'>
# 83 - 0 - 27:nan   <class 'numpy.float64'>
# 83 - 0 - 28:nan   <class 'numpy.float64'>
# 83 - 0 - 29:nan   <class 'numpy.float64'>
# 83 - 0 - 30:nan   <class 'numpy.float64'>
# 83 - 0 - 31:nan   <class 'numpy.float64'>
# 83 - 0 - 32:nan   <class 'numpy.float64'>
# 83 - 0 - 33:7.0   <class 'numpy.float64'>
# 83 - 0 - 34:nan   <class 'numpy.float64'>
# 83 - 1 - 0:Добавлены сведения в пунктах: 12.1.1 (2)Вид права застройщика на   <class 'str'>
# 83 - 1 - 1:земельный участок; 12.1.2 (2)Вид договора или иного документа,   <class 'str'>
# 83 - 1 - 2:12.1 (2) О правах застройщика на земельный являющегося основанием возникновения права застройщика на земельный   <class 'str'>
# 83 - 1 - 3:участок, на котором осуществляется участок; 12.1.3 (2)Номер договора или иного документа, являющегося   <class 'str'>
# 83 - 1 - 4:строительство (создание) многоквартирного основанием возникновения права застройщика на земельный участок,   <class 'str'>
# 83 - 1 - 5:20.07.2022 дома либо многоквартирных домов и (или) определяющего права застройщика на земельный участок; 12.1.4 (2)Дата   <class 'str'>
# 83 - 1 - 6:иных объектов недвижимости, в том числе о подписания договора или иного документа, являющегося основанием   <class 'str'>
# 83 - 1 - 7:реквизитах правоустанавливающего возникновения права застройщика на земельный участок, определяющего   <class 'str'>
# 83 - 1 - 8:документа на земельный участок права застройщика на земельный участок; 12.1.11 (2)Дата государственной   <class 'str'>
# 83 - 1 - 9:регистрации права собственности Добавлен файл: Выписка_ЕГРН_зу_63-01-   <class 'str'>
# 83 - 1 - 10:0407002-1605-63-466-2022-1   <class 'str'>
# 83 - 1 - 11:20.07.2022 12.3 (2) О кадастровом номере и площади Добавлены сведения в пунктах: 12.3.1 (2)Кадастровый номер земельного   <class 'str'>
# 83 - 1 - 12:земельного участка участка; 12.3.2 (2)Площадь земельного участка   <class 'str'>
# 83 - 1 - 13:Добавлен Раздел_ПД_No2_162-2021-ПЗУ_корр.12.07.2022 с изменением   <class 'str'>
# 83 - 1 - 14:20.07.2022 12.3 (2) О кадастровом номере и площади информации о кадастровом номере земельного участка объекта   <class 'str'>
# 83 - 1 - 15:земельного участка капитального строительства, сведения о градостроительном плане   <class 'str'>
# 83 - 1 - 16:земельного участка, площадь участка.   <class 'str'>
# 83 - 1 - 17:Добавлен Раздел_ПД_No1_162-2021-ПЗ_корр.12.07.2022 с изменением   <class 'str'>
# 83 - 1 - 18:20.07.2022 12.3 (2) О кадастровом номере и площади информации о кадастровом номере земельного участка объекта   <class 'str'>
# 83 - 1 - 19:земельного участка капитального строительства, сведения о градостроительном плане   <class 'str'>
# 83 - 1 - 20:земельного участка, площадь участка.   <class 'str'>
# 83 - 1 - 21:4.1 О проектах строительства   <class 'str'>
# 83 - 1 - 22:многоквартирных домов и (или) иных   <class 'str'>
# 83 - 1 - 23:объектов недвижимости, в которых   <class 'str'>
# 83 - 1 - 24:принимали участие застройщик и (или) его   <class 'str'>
# 83 - 1 - 25:основное общество или дочерние общества   <class 'str'>
# 83 - 1 - 26:29.07.2022 такого основного общества в течение трех Добавлент п.4.1(2)   <class 'str'>
# 83 - 1 - 27:лет, предшествующих опубликованию   <class 'str'>
# 83 - 1 - 28:проектной декларации, с указанием места   <class 'str'>
# 83 - 1 - 29:нахождения указанных объектов   <class 'str'>
# 83 - 1 - 30:недвижимости, сроков ввода их в   <class 'str'>
# 83 - 1 - 31:эксплуатацию   <class 'str'>
# 83 - 1 - 32:6.1 О финансовом результате текущего года,   <class 'str'>
# 83 - 1 - 33:29.07.2022 о размерах кредиторской и дебиторской Актуализирована информация на 30.06.2022   <class 'str'>
# 83 - 1 - 34:задолженности на последнюю отчетную дату   <class 'str'>
# 84 - 0 - 0:nan   <class 'numpy.float64'>
# 84 - 0 - 1:nan   <class 'numpy.float64'>
# 84 - 0 - 2:nan   <class 'numpy.float64'>
# 84 - 0 - 3:nan   <class 'numpy.float64'>
# 84 - 0 - 4:nan   <class 'numpy.float64'>
# 84 - 0 - 5:nan   <class 'numpy.float64'>
# 84 - 1 - 0:8   <class 'numpy.int64'>
# 84 - 1 - 1:9   <class 'numpy.int64'>
# 84 - 1 - 2:10   <class 'numpy.int64'>
# 84 - 1 - 3:11   <class 'numpy.int64'>
# 84 - 1 - 4:12   <class 'numpy.int64'>
# 84 - 1 - 5:13   <class 'numpy.int64'>
# 84 - 2 - 0:nan   <class 'numpy.float64'>
# 84 - 2 - 1:nan   <class 'numpy.float64'>
# 84 - 2 - 2:nan   <class 'numpy.float64'>
# 84 - 2 - 3:nan   <class 'numpy.float64'>
# 84 - 2 - 4:nan   <class 'numpy.float64'>
# 84 - 2 - 5:nan   <class 'numpy.float64'>
# 84 - 3 - 0:29.07.2022   <class 'str'>
# 84 - 3 - 1:29.07.2022   <class 'str'>
# 84 - 3 - 2:05.09.2022   <class 'str'>
# 84 - 3 - 3:05.09.2022   <class 'str'>
# 84 - 3 - 4:05.09.2022   <class 'str'>
# 84 - 3 - 5:07.10.2022   <class 'str'>
# 84 - 4 - 0:nan   <class 'numpy.float64'>
# 84 - 4 - 1:nan   <class 'numpy.float64'>
# 84 - 4 - 2:nan   <class 'numpy.float64'>
# 84 - 4 - 3:nan   <class 'numpy.float64'>
# 84 - 4 - 4:nan   <class 'numpy.float64'>
# 84 - 4 - 5:nan   <class 'numpy.float64'>
# заключенного с застройщиком   <class 'str'>
# соответствии с договором кредита (займа)   <class 'str'>
# застройщика   <class 'str'>
# 84 - 5 - 3:19.6 О целевом кредите (целевом займе)   <class 'str'>
# использованием счетов эскроу   <class 'str'>
# 84 - 5 - 5:19.6 О целевом кредите (целевом займе)   <class 'str'>
# 84 - 6 - 0:nan   <class 'numpy.float64'>
# 84 - 6 - 1:nan   <class 'numpy.float64'>
# 84 - 6 - 2:nan   <class 'numpy.float64'>
# 84 - 6 - 3:nan   <class 'numpy.float64'>
# 84 - 6 - 4:nan   <class 'numpy.float64'>
# 84 - 6 - 5:nan   <class 'numpy.float64'>
# 84 - 7 - 0:Изменена информация о генеральном подрядчике   <class 'str'>
# 84 - 7 - 1:Добавлена информация о целевом кредите (целевом займе)   <class 'str'>
# 84 - 7 - 2:Изменены сведения в п.1.5.1, 1.5.2, 1.5.3   <class 'str'>
# Неиспользованный остаток по кредиту (займу) на указанную дату   <class 'str'>
# договоров, заключенных с использованием счетов эскроу   <class 'str'>
# Неиспользованный остаток по кредиту (займу) на указанную дату   <class 'str'>
# 84 - 8 - 0:nan   <class 'numpy.float64'>
# 84 - 8 - 1:nan   <class 'numpy.float64'>
# 84 - 8 - 2:nan   <class 'numpy.float64'>
# 84 - 8 - 3:nan   <class 'numpy.float64'>
# 84 - 8 - 4:nan   <class 'numpy.float64'>
# 84 - 8 - 5:nan   <class 'numpy.float64'>
# 85 - 0 - 0:nan   <class 'numpy.float64'>
# 85 - 0 - 1:nan   <class 'numpy.float64'>
# 85 - 0 - 2:nan   <class 'numpy.float64'>
# 85 - 1 - 0:14   <class 'numpy.int64'>
# 85 - 1 - 1:15   <class 'numpy.int64'>
# 85 - 1 - 2:16   <class 'numpy.int64'>
# 85 - 2 - 0:nan   <class 'numpy.float64'>
# 85 - 2 - 1:nan   <class 'numpy.float64'>
# 85 - 2 - 2:nan   <class 'numpy.float64'>
# 85 - 3 - 0:07.10.2022   <class 'str'>
# 85 - 3 - 1:07.11.2022   <class 'str'>
# 85 - 3 - 2:07.11.2022   <class 'str'>
# 85 - 4 - 0:nan   <class 'numpy.float64'>
# 85 - 4 - 1:nan   <class 'numpy.float64'>
# 85 - 4 - 2:nan   <class 'numpy.float64'>
# использованием счетов эскроу   <class 'str'>
# 85 - 5 - 1:19.6 О целевом кредите (целевом займе)   <class 'str'>
# использованием счетов эскроу   <class 'str'>
# 85 - 6 - 0:nan   <class 'numpy.float64'>
# 85 - 6 - 1:nan   <class 'numpy.float64'>
# 85 - 6 - 2:nan   <class 'numpy.float64'>
# договоров, заключенных с использованием счетов эскроу   <class 'str'>
# Неиспользованный остаток по кредиту (займу) на указанную дату   <class 'str'>
# договоров, заключенных с использованием счетов эскроу   <class 'str'>
# 85 - 8 - 0:nan   <class 'numpy.float64'>
# 85 - 8 - 1:nan   <class 'numpy.float64'>
# 85 - 8 - 2:nan   <class 'numpy.float64'>
# 86 - 0 - 0:nan   <class 'numpy.float64'>
# 86 - 1 - 0:Сведения об электронной подписи   <class 'str'>
# 86 - 2 - 0:nan   <class 'numpy.float64'>

# %%
data_table.DataTable.max_columns = 110
data_table.DataTable(dffull, include_index=False, num_rows_per_page=200)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>pdId</th>
#       <th>region</th>
#       <th>address</th>
#       <th>floorMin</th>
#       <th>floorMax</th>
#       <th>objElemLivingCnt</th>
#       <th>objReady100PercDt</th>
#       <th>wallMaterialShortDesc</th>
#       <th>objLkFinishTypeDesc</th>
#       <th>...</th>
#       <th>metro.line</th>
#       <th>metro.color</th>
#       <th>metro.time</th>
#       <th>metro.isWalk</th>
#       <th>metro.colors</th>
#       <th>nameObj</th>
#       <th>complexShortNm</th>
#       <th>num_d</th>
#       <th>num_r</th>
#       <th>num_m</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18136</td>
#       <td>43084</td>
#       <td>63</td>
#       <td>г Самара, улица Советской Армии, д. 0, корпус ...</td>
#       <td>27</td>
#       <td>27</td>
#       <td>360</td>
#       <td>2023-06-30</td>
#       <td>Монолит-кирпич</td>
#       <td>Без отделки</td>
#       <td>...</td>
#       <td>Первая</td>
#       <td>#CD0505</td>
#       <td>11.500000</td>
#       <td>True</td>
#       <td>[#CD0505]</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>65.0</td>
#       <td>4.578315e+08</td>
#       <td>9761.87</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4024</td>
#       <td>2200</td>
#       <td>63</td>
#       <td>г Самара, район Октябрьский, просека Пятая</td>
#       <td>5</td>
#       <td>5</td>
#       <td>16</td>
#       <td>2023-12-31</td>
#       <td>Кирпич</td>
#       <td>Без отделки</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Жилой комплекс "Акварель" (ЖК "Акварель") дом 9</td>
#       <td>Акварель</td>
#       <td>440.0</td>
#       <td>1.813398e+09</td>
#       <td>35096.83</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4025</td>
#       <td>2200</td>
#       <td>63</td>
#       <td>г Самара, район Октябрьский, просека Пятая</td>
#       <td>5</td>
#       <td>5</td>
#       <td>64</td>
#       <td>2022-12-31</td>
#       <td>Кирпич</td>
#       <td>Без отделки</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>Жилой комплекс "Акварель" (ЖК "Акварель") дом 7</td>
#       <td>Акварель</td>
#       <td>440.0</td>
#       <td>1.813398e+09</td>
#       <td>35096.83</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>
#     </tr>
#     <tr>
#       <th>180</th>
#       <td>43207</td>
#       <td>295812</td>
#       <td>63</td>
#       <td>г Самара, ул Маяковского</td>
#       <td>19</td>
#       <td>19</td>
#       <td>142</td>
#       <td>2024-09-30</td>
#       <td>Монолит-кирпич</td>
#       <td>Без отделки</td>
#       <td>...</td>
#       <td>Первая</td>
#       <td>#CD0505</td>
#       <td>19.483333</td>
#       <td>True</td>
#       <td>[#CD0505]</td>
#       <td>ЖК "Маяковский NEW"</td>
#       <td>NaN</td>
#       <td>15.0</td>
#       <td>1.068502e+08</td>
#       <td>1020.71</td>
#     </tr>
#   </tbody>
# </table>
# <p>181 rows × 106 columns</p>
# </div>

# %%
tables[78]
# Out:
#      0                                                  1   2             3  \
# 0  NaN  19.7 О количестве заключенных\rдоговоров (обща... NaN        19.7.1
# 1  NaN                                                NaN NaN      19.7.1.1
# 2  NaN                                                NaN NaN    19.7.1.1.1
# 3  NaN                                                NaN NaN  19.7.1.1.1.1
# 4  NaN                                                NaN NaN  19.7.1.1.1.2
# 5  NaN                                                NaN NaN  19.7.1.1.1.3
# 6  NaN                                                NaN NaN    19.7.1.1.2
# 7  NaN                                                NaN NaN  19.7.1.1.2.1
# 8  NaN                                                NaN NaN  19.7.1.1.2.2
# 9  NaN                                                NaN NaN  19.7.1.1.2.3
# 10 NaN                                                NaN NaN    19.7.1.1.3
#
#      4                                                  5   6
# 0  NaN  О количестве договоров участия в долевом строи... NaN
# 1  NaN                Вид объекта долевого строительства: NaN
# 2  NaN                                   Жилые помещения: NaN
# 3  NaN  Количество договоров, заключенных с использова... NaN
# 4  NaN  Количество договоров, заключенных при условии ... NaN
# 5  NaN  Количество договоров, заключенных с использова... NaN
# 6  NaN                                 Нежилые помещения: NaN
# 7  NaN  Количество договоров, заключенных с использова... NaN
# 8  NaN  Количество договоров, заключенных при условии ... NaN
# 9  NaN  Количество договоров, заключенных с использова... NaN
# 10 NaN                                      Машино-места: NaN

# %%
str(tables[78][3][2])=='19.7.1.1.1'
# Out:
# True

# %%
len(tables[113].axes[1])
# Out:
# 9

# %%
type(tables)
# Out:
# list

# %%
#from numpy import float64
i=0
j=0
k=0
str_d=''
str_m=''
str_r=''
num_d=0
num_m=0
num_r=0
while k<len(tables):
 i=0
 while i<len(tables[k].axes[1]):
  j=0
  while j<len(tables[k]):
#   print(str(k)+' - '+ str(i)+' - '+str(j)+':'+str(tables[k][i][j])+'   ' + str(type(tables[k][i][j])))
   if str(tables[k][i][j])!='nan' and  str(type(tables[k][i][j]))!="<class 'numpy.float64'>" and  str(type(tables[k][i][j]))!="<class 'numpy.int64'>" :
    if (str(tables[k][i][j].replace('\r', '')).find('Суммарная цена договоров, заключенных с использованием счетов эскроу:')>-1):
     str_r=tables[k][i][j].replace('\r', '');
     str_r=re.sub('Суммарная цена договоров, заключенных с использованием счетов эскроу:', '', str_r);
     str_r=re.sub(' руб.', '', str_r);
     str_r=re.sub(' ', '', str_r);
     num_r=num_r+float(str_r.replace(",","."));
    if (str(tables[k][i][j].replace('\r', '')).find('Количество договоров, заключенных с использованием счетов эскроу:')>-1):
     str_d=tables[k][i][j].replace('\r', '');
     str_d=re.sub('Количество договоров, заключенных с использованием счетов эскроу:', '', str_d);
     str_d=re.sub(' руб.', '', str_d);
     str_d=re.sub(' ', '', str_d);
     num_d=num_d+float(str_d.replace(",","."));
    if (str(tables[k][i][j].replace('\r', '')).find('Площадь объектов, в отношении которых договор участия в долевом строительстве')>-1):
     str_m=tables[k][i][j].replace('\r', '');
#     print(str_m)
     str_m=re.sub('Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием счетов эскроу:', '', str_m);
     str_m=re.sub("Площадь объектов, в отношении которых договор участия в долевом строительствезаключен при условии уплаты обязательных отчислений (взносов) в компенсационныйфонд:", '', str_m);
     str_m=re.sub("Площадь объектов, в отношении которых договор участия в долевом строительствезаключен с использованием иных способов обеспечения гражданской ответственностизастройщика:", '', str_m);
     str_m=re.sub(' м2', '', str_m);
     str_m=re.sub(' ', '', str_m);
     str_m=str_m.replace('(','');
     str_m=str_m.replace(')','');
     str_m=re.sub("Площадьобъектов,вотношениикоторыхдоговоручастиявдолевомстроительствезаключенприусловииуплатыобязательныхотчисленийвзносоввкомпенсационныйфонд:", '', str_m);
#     print(str_m);
     num_m=num_m+float(str_m.replace(",","."));
   j=j+1
  i=i+1
# print(k)
 k=k+1
print(num_d)
print(num_r)
print(num_m)
# Out:
# 845.0
# 2831752392.54
# 39330.69

# %%
print(tables[110][5].to_string().find('Суммарная цена договоров, заключенных с использованием счетов эскроу:')>-1)
# Out:
# True

# %%
pd.options.display.width=200
pd.options.display.max_colwidth=200

# %%
len(tables[108][5]) #[tables[108][5].str.find('845')>-1]
# Out:
# 11

# %%
tables[112]
# Out:
#      0   1   2             3   4  \
# 0  NaN NaN NaN  19.7.2.1.3.1 NaN
# 1  NaN NaN NaN  19.7.2.1.3.2 NaN
# 2  NaN NaN NaN  19.7.2.1.3.3 NaN
# 3  NaN NaN NaN        19.7.3 NaN
# 4  NaN NaN NaN      19.7.3.1 NaN
# 5  NaN NaN NaN    19.7.3.1.1 NaN
# 6  NaN NaN NaN  19.7.3.1.1.1 NaN
# 7  NaN NaN NaN  19.7.3.1.1.2 NaN
# 8  NaN NaN NaN  19.7.3.1.1.3 NaN
# 9  NaN NaN NaN    19.7.3.1.2 NaN
# 10 NaN NaN NaN  19.7.3.1.2.1 NaN
# 11 NaN NaN NaN  19.7.3.1.2.2 NaN
# 12 NaN NaN NaN  19.7.3.1.2.3 NaN
# 13 NaN NaN NaN    19.7.3.1.3 NaN
# 14 NaN NaN NaN  19.7.3.1.3.1 NaN
#
#                                                     5   6
# 0   Площадь объектов, в отношении которых договор ... NaN
# 1   Площадь объектов, в отношении которых договор ... NaN
# 2   Площадь объектов, в отношении которых договор ... NaN
# 3   О цене договоров участия в долевом строительстве: NaN
# 4                 Вид объекта долевого строительства: NaN
# 5                                    Жилые помещения: NaN
# 6   Суммарная цена договоров, заключенных с исполь... NaN
# 7   Суммарная цена договоров, заключенных при усло... NaN
# 8   Суммарная цена договоров, заключенных с исполь... NaN
# 9                                  Нежилые помещения: NaN
# 10  Суммарная цена договоров, заключенных с исполь... NaN
# 11  Суммарная цена договоров, заключенных при усло... NaN
# 12  Суммарная цена договоров, заключенных с исполь... NaN
# 13                                      Машино-места: NaN
# 14  Суммарная цена договоров, заключенных с исполь... NaN

# %%
type(tables[108][5])
# Out:
# pandas.core.series.Series

# %%
df = pd.DataFrame(list(zip(tables)))

# %%
df[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-78a33f69c558> in <module>
# ----> 1 df[1]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 1

# %%
aa=tables.reverse()

# %%
ww=(tables[108][tables[108][5].str.find('845')>-1][5].to_string())

# %%
len(ww)
# Out:
# 54

# %%
ww
# Out:
# '3    Количество договоров, заключенных с использова...'

# %%
print(tables[108][tables[108][5].str.find('845')>-1][5].to_string)
# Out:
# <bound method Series.to_string of 3    Количество договоров, заключенных с использова...
# Name: 5, dtype: object>

# %%
dffull[dffull['rpdRegionCd']==63]['objId'].unique().to_frame().count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rpdRegionCd'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-5789e612a71f> in <module>
# ----> 1 dffull[dffull['rpdRegionCd']==63]['objId'].unique().to_frame().count()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'rpdRegionCd'

# %%
dffull[dffull['objAddr'].str.lower().str.find('самара')>-1].count()
# Out:
# objId                                        50
# rpdRegionCd                                  50
# objAddr                                      50
# objFloorMin                                  50
# objFloorMax                                  50
# objElemLivingCnt                             50
# objReady100PercDt                            50
# objSquareLiving                              50
# objCompensFundFlg                            50
# objProblemFlg                                50
# latitude                                     50
# longitude                                    50
# problemFlag                                  50
# siteStatus                                   50
# objGuarantyEscrowFlg                         50
# residentialBuildings                         50
# rpdNum                                       50
# pdId                                         50
# buildType                                    50
# objStatus                                    50
# developer.devId                              50
# developer.shortName                          50
# developer.fullName                           50
# developer.groupName                          33
# developer.orgForm.id                         50
# developer.orgForm.fullForm                   50
# developer.orgForm.shortForm                  50
# developer.companyGroup                       33
# developer.devInn                             50
# objCommercNm                                 42
# developer.bankruptStage.bankruptStageCd       0
# developer.bankruptStage.bankruptStageDesc     0
# developer.bankruptStage.bankruptLawUrl        0
# developer.orgBankruptMsgDttm                  0
# complexShortName                             10
# dtype: int64

# %%
df = pd.json_normalize(objects_list)
df[df['objAddr'].str.lower().str.find('самара')>-1]
# Out:
#      objId  rpdRegionCd                                            objAddr  \
# 63   18136           63  г Самара, улица Советской Армии, д. 0, корпус ...
# 184   4024           63         г Самара, район Октябрьский, просека Пятая
# 185   4025           63         г Самара, район Октябрьский, просека Пятая
# 186   4023           63         г Самара, район Октябрьский, просека Пятая
# 187   4026           63         г Самара, район Октябрьский, просека Пятая
# 411  24539           63                              г Самара, Белорусская
# 412  24540           63                              г Самара, Белорусская
#
#      objFloorMin  objFloorMax  objElemLivingCnt objReady100PercDt  \
# 63            27           27               360        2023-06-30
# 184            5            5                16        2023-12-31
# 185            5            5                64        2022-12-31
# 186            5            5                48        2022-12-31
# 187            5            5                64        2022-12-31
# 411           25           25               396        2022-12-31
# 412            1            1                 0        2022-12-31
#
#      objSquareLiving  objCompensFundFlg  objProblemFlg  ...  \
# 63          20664.24                  0              0  ...
# 184           918.77                  1              0  ...
# 185          3675.08                  1              0  ...
# 186          2756.31                  1              0  ...
# 187          3666.28                  1              0  ...
# 411         25228.66                  0              0  ...
# 412             0.00                  0              0  ...
#
#                    developer.orgForm.fullForm  developer.orgForm.shortForm  \
# 63   Общество с ограниченной ответственностью                          ООО
# 184             Закрытое акционерное общество                          ЗАО
# 185             Закрытое акционерное общество                          ЗАО
# 186             Закрытое акционерное общество                          ЗАО
# 187             Закрытое акционерное общество                          ЗАО
# 411  Общество с ограниченной ответственностью                          ООО
# 412  Общество с ограниченной ответственностью                          ООО
#
#     developer.companyGroup developer.devInn  \
# 63                  9176.0       6312173063
# 184                 5847.0       6318136702
# 185                 5847.0       6318136702
# 186                 5847.0       6318136702
# 187                 5847.0       6318136702
# 411                 5874.0       6319225715
# 412                 5874.0       6319225715
#
#                                          objCommercNm  \
# 63                                                NaN
# 184   Жилой комплекс "Акварель" (ЖК "Акварель") дом 9
# 185   Жилой комплекс "Акварель" (ЖК "Акварель") дом 7
# 186   Жилой комплекс "Акварель" (ЖК "Акварель") дом 8
# 187  Жилой комплекс "Акварель" (ЖК "Акварель") дом 10
# 411                                     ЖК "Две реки"
# 412                                     ЖК "Две реки"
#
#      developer.bankruptStage.bankruptStageCd  \
# 63                                       NaN
# 184                                      NaN
# 185                                      NaN
# 186                                      NaN
# 187                                      NaN
# 411                                      NaN
# 412                                      NaN
#
#     developer.bankruptStage.bankruptStageDesc  \
# 63                                        NaN
# 184                                       NaN
# 185                                       NaN
# 186                                       NaN
# 187                                       NaN
# 411                                       NaN
# 412                                       NaN
#
#      developer.bankruptStage.bankruptLawUrl developer.orgBankruptMsgDttm  \
# 63                                      NaN                          NaN
# 184                                     NaN                          NaN
# 185                                     NaN                          NaN
# 186                                     NaN                          NaN
# 187                                     NaN                          NaN
# 411                                     NaN                          NaN
# 412                                     NaN                          NaN
#
#      complexShortName
# 63                NaN
# 184          Акварель
# 185          Акварель
# 186          Акварель
# 187          Акварель
# 411               NaN
# 412               NaN
#
# [7 rows x 35 columns]

# %% [markdown]
# запись в excel

# %%
with pd.ExcelWriter('НашДомРФ.xlsx', mode='w') as writer:
    df.to_excel(writer, sheet_name='НашДомРФ',index=False)

# %% [markdown]
# запись в csv

# %%
file_csv = df.to_csv(sep=',', index=False)

# %% [markdown]
# запись в pickle

# %%
file_pickle = df.to_pickle(path = 'str')

# %% [markdown]
# запись в БД

# %%
from pandas.io import sql
import MySQLdb

con = MySQLdb.connect()

df.to_sql(con=con, name='OurHouse', if_exists='replace', flavor='mysql')
